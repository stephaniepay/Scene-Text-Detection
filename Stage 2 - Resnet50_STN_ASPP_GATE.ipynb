# %%
# !pip install easydict
# !pip install tensorboardX
# !pip install shapely
# !pip install torchsummary

# %%
import torchvision.models.resnet as resnet
import torch.nn as nn
import torch.nn.functional as F

import torch
import torchvision
import torchvision.models as models

import torch.backends.cudnn as cudnn

import warnings
warnings.filterwarnings("ignore")

import os
import time
import argparse
from datetime import datetime

import torch.utils.data as data
from torch.optim import lr_scheduler
from util.shedule import FixLR

from dataset.total_text import TotalText
from dataset.synth_text import SynthText

from util.augmentation import BaseTransform, Augmentation
from util.config import config as cfg, update_config, print_config
from util.misc import AverageMeter
from util.misc import mkdirs, to_device
from util.option import BaseOptions
from util.visualize import visualize_network_output
from util.summary import LogSummary

from easydict import EasyDict
import matplotlib.pyplot as plt

import torch.multiprocessing as mp
from torchvision import models
from torchsummary import summary

warnings.filterwarnings("ignore", message="indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (function expandTensors)")

# %%
torch.cuda.empty_cache()

import gc
gc.collect()
# Out:
# 0

# %%
# class STN(nn.Module):
#     def __init__(self):
#         super(STN, self).__init__()

#         # Localization-network
#         self.localization = nn.Sequential(
#             nn.Conv2d(3, 8, kernel_size=7),
#             nn.MaxPool2d(2, stride=2),
#             nn.ReLU(True),
#             nn.Conv2d(8, 10, kernel_size=5),
#             nn.MaxPool2d(2, stride=2),
#             nn.ReLU(True)
#         )

#         # Regressor for the 3 * 2 affine matrix
#         self.fc_loc = nn.Sequential(
#             nn.Linear(10 * 124 * 124, 32),
#             nn.ReLU(True),
#             nn.Linear(32, 3 * 2)
#         )

#         # Initialize the weights/bias with identity transformation
#         self.fc_loc[2].weight.data.zero_()
#         self.fc_loc[2].bias.data.copy_(torch.tensor([1, 0, 0, 0, 1, 0], dtype=torch.float))

#     # Spatial transformer network forward function
#     def stn(self, x):
#         xs = self.localization(x)
#         xs = xs.view(-1, 10 * 124 * 124)
#         theta = self.fc_loc(xs)
#         theta = theta.view(-1, 2, 3)

#         grid = F.affine_grid(theta, x.size())
#         x = F.grid_sample(x, grid)

#         return x

#     def forward(self, x):
#         x = self.stn(x)
#         return x

class STN(nn.Module):
    def __init__(self):
        super(STN, self).__init__()

        # Localization-network
        self.localization = nn.Sequential(
            nn.Conv2d(3, 8, kernel_size=7),
            nn.MaxPool2d(2, stride=2),
            nn.ReLU(True),
            nn.Conv2d(8, 10, kernel_size=5),
            nn.MaxPool2d(2, stride=2),
            nn.ReLU(True)
        )

        # Regressor for the 3 * 2 affine matrix
        self.fc_loc = nn.Sequential(
            nn.Linear(10 * 124 * 124, 32),
            nn.ReLU(True),
            nn.Linear(32, 3 * 2)
        )

        # Gate layer to determine whether to bypass STN or not
        self.fc_gate = nn.Sequential(
            nn.Linear(10 * 124 * 124, 32),
            nn.ReLU(True),
            nn.Linear(32, 1),
            nn.Sigmoid()
        )

        # Initialize the weights/bias with identity transformation
        self.fc_loc[2].weight.data.zero_()
        self.fc_loc[2].bias.data.copy_(torch.tensor([1, 0, 0, 0, 1, 0], dtype=torch.float))

    # Spatial transformer network forward function
    def stn(self, x):
        xs = self.localization(x)
        xs = xs.view(-1, 10 * 124 * 124)
        theta = self.fc_loc(xs)
        theta = theta.view(-1, 2, 3)

        gate = self.fc_gate(xs)
        gate = gate.view(-1, 1, 1, 1)

        grid = F.affine_grid(theta, x.size())
        x_stn = F.grid_sample(x, grid)

        # Weighted combination of original and STN-transformed images
        x = gate * x_stn + (1 - gate) * x

        return x

    def forward(self, x):
        x = self.stn(x)
        return x

# %%
  
    
class DepthwiseSeparableConv(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size, dilation, padding, bias=False):
        super(DepthwiseSeparableConv, self).__init__()

        self.depthwise = nn.Conv2d(in_channels, in_channels, kernel_size, padding=padding, dilation=dilation, groups=in_channels, bias=bias)
        self.pointwise = nn.Conv2d(in_channels, out_channels, 1, bias=bias)

    def forward(self, x):
        x = self.depthwise(x)
        x = self.pointwise(x)
        return x

class ASPP(nn.Module):
    def __init__(self, in_channels, out_channels, rates=[3, 9, 12, 18]):
        super(ASPP, self).__init__()

        self.aspp_blocks = nn.ModuleList([
            nn.Conv2d(in_channels, out_channels, 1, bias=False),
            DepthwiseSeparableConv(in_channels, out_channels, 3, rates[0], rates[0], bias=False),
            DepthwiseSeparableConv(in_channels, out_channels, 3, rates[1], rates[1], bias=False),
            DepthwiseSeparableConv(in_channels, out_channels, 3, rates[2], rates[2], bias=False),
            DepthwiseSeparableConv(in_channels, out_channels, 3, rates[3], rates[3], bias=False)
        ])

        self.global_avg_pool = nn.Sequential(
            nn.AdaptiveAvgPool2d((1, 1)),
            nn.Conv2d(in_channels, out_channels, 1, bias=False)
        )

        self.output_conv = nn.Conv2d(out_channels * (len(rates) + 2), out_channels, 1, bias=False)

    def forward(self, x):
        x_aspp = [aspp_block(x) for aspp_block in self.aspp_blocks]

        # Apply global average pooling and upsample to match other feature maps
        gap = self.global_avg_pool(x)
        gap = F.interpolate(gap, size=x_aspp[0].shape[2:], mode='bilinear', align_corners=False)

        x_aspp.append(gap)

        x = torch.cat(x_aspp, dim=1)
        x = self.output_conv(x)

        return x

# %%
from torchvision.models import resnet50

class ResNet50(nn.Module):
    def __init__(self, pretrained=True):
        super().__init__()

        base_model = resnet50(pretrained=pretrained)
        
        self.base_layers = list(base_model.children())
        
        self.layer0 = nn.Sequential(*self.base_layers[:3])  # size=(N, 64, h/2, w/2)
        self.layer1 = nn.Sequential(*self.base_layers[3:5]) # size=(N, 64, h/4, w/4)
        self.layer2 = self.base_layers[5]  # size=(N, 128, h/8, w/8)
        self.layer3 = self.base_layers[6]  # size=(N, 256, h/16, w/16)
        self.layer4 = self.base_layers[7]  # size=(N, 512, h/32, w/32)
        
        self.aspp = ASPP(2048, 1024)

    def forward(self, x):
        C1 = self.layer0(x)
        C2 = self.layer1(C1)
        C3 = self.layer2(C2)
        C4 = self.layer3(C3)
        C5 = self.layer4(C4)
        
        #Apply ASPP at stage 5
        C5 = self.aspp(C5)
        
        return C1, C2, C3, C4, C5

    
# input = torch.randn((4, 3, 512, 512))
# net = ResNet50()

# C1, C2, C3, C4, C5 = net(input)
# print(C1.size())
# print(C2.size())
# print(C3.size())
# print(C4.size())
# print(C5.size())

# %%
class Upsample(nn.Module):

    def __init__(self, in_channels, shortcut_channels, out_channels):
        super().__init__()
        self.conv1x1 = nn.Conv2d(in_channels + shortcut_channels, out_channels, kernel_size=1, stride=1, padding=0)
        self.conv3x3 = nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=1, padding=1)
        self.deconv = nn.ConvTranspose2d(out_channels, out_channels, kernel_size=4, stride=2, padding=1)

    def forward(self, upsampled, shortcut):
        upsampled = F.interpolate(upsampled, size=(shortcut.size(2), shortcut.size(3)), mode='bilinear', align_corners=False)
        x = torch.cat([upsampled, shortcut], dim=1)
        x = self.conv1x1(x)
        x = F.relu(x)
        x = self.conv3x3(x)
        x = F.relu(x)
        x = self.deconv(x)
        return x

    

class TextNet(nn.Module):

    def __init__(self, backbone='resnet', output_channel=7, is_training=True):
        super().__init__()

        self.is_training = is_training
        self.backbone_name = backbone
        self.output_channel = output_channel
        
        self.stn = STN()
        
        if backbone == 'resnet':
            self.backbone = ResNet50(pretrained=self.is_training)

            self.deconv5 = nn.ConvTranspose2d(1024, 512, kernel_size=4, stride=2, padding=1)
            self.merge4 = Upsample(512, 1024, 256)
            self.merge3 = Upsample(256, 512, 128)
            self.merge2 = Upsample(128, 256, 64)
            self.merge1 = Upsample(64, 64, 32)
        

            self.predict = nn.Sequential(
                nn.Conv2d(32, 32, kernel_size=3, stride=1, padding=1),
                nn.Conv2d(32, self.output_channel, kernel_size=1, stride=1, padding=0)
            )
        
    def forward(self, x):
        x = self.stn(x)
        C1, C2, C3, C4, C5 = self.backbone(x)
        up5 = self.deconv5(C5)
        up5 = F.relu(up5)

        up4 = self.merge4(C4, up5)
        up4 = F.relu(up4)

        up3 = self.merge3(C3, up4)
        up3 = F.relu(up3)

        up2 = self.merge2(C2, up3)
        up2 = F.relu(up2)

        up1 = self.merge1(C1, up2)
        output = self.predict(up1)
        
        return output

# %%
input = torch.randn((4, 3, 512, 512))
net = TextNet().cuda()
output = net(input.cuda())
print(output.size())



help(summary)
summary(net, (3, 512, 512),4)
# Out:
# torch.Size([4, 7, 512, 512])
# Help on function summary in module torchsummary.torchsummary:
#
# summary(model, input_size, batch_size=-1, device='cuda')
#
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [4, 8, 506, 506]           1,184
#          MaxPool2d-2           [4, 8, 253, 253]               0
#               ReLU-3           [4, 8, 253, 253]               0
#             Conv2d-4          [4, 10, 249, 249]           2,010
#          MaxPool2d-5          [4, 10, 124, 124]               0
#               ReLU-6          [4, 10, 124, 124]               0
#             Linear-7                    [4, 32]       4,920,352
#               ReLU-8                    [4, 32]               0
#             Linear-9                     [4, 6]             198
#            Linear-10                    [4, 32]       4,920,352
#              ReLU-11                    [4, 32]               0
#            Linear-12                     [4, 1]              33
#           Sigmoid-13                     [4, 1]               0
#               STN-14           [4, 3, 512, 512]               0
#            Conv2d-15          [4, 64, 256, 256]           9,408
#       BatchNorm2d-16          [4, 64, 256, 256]             128
#              ReLU-17          [4, 64, 256, 256]               0
#         MaxPool2d-18          [4, 64, 128, 128]               0
#            Conv2d-19          [4, 64, 128, 128]           4,096
#       BatchNorm2d-20          [4, 64, 128, 128]             128
#              ReLU-21          [4, 64, 128, 128]               0
#            Conv2d-22          [4, 64, 128, 128]          36,864
#       BatchNorm2d-23          [4, 64, 128, 128]             128
#              ReLU-24          [4, 64, 128, 128]               0
#            Conv2d-25         [4, 256, 128, 128]          16,384
#       BatchNorm2d-26         [4, 256, 128, 128]             512
#            Conv2d-27         [4, 256, 128, 128]          16,384
#       BatchNorm2d-28         [4, 256, 128, 128]             512
#              ReLU-29         [4, 256, 128, 128]               0
#        Bottleneck-30         [4, 256, 128, 128]               0
#            Conv2d-31          [4, 64, 128, 128]          16,384
#       BatchNorm2d-32          [4, 64, 128, 128]             128
#              ReLU-33          [4, 64, 128, 128]               0
#            Conv2d-34          [4, 64, 128, 128]          36,864
#       BatchNorm2d-35          [4, 64, 128, 128]             128
#              ReLU-36          [4, 64, 128, 128]               0
#            Conv2d-37         [4, 256, 128, 128]          16,384
#       BatchNorm2d-38         [4, 256, 128, 128]             512
#              ReLU-39         [4, 256, 128, 128]               0
#        Bottleneck-40         [4, 256, 128, 128]               0
#            Conv2d-41          [4, 64, 128, 128]          16,384
#       BatchNorm2d-42          [4, 64, 128, 128]             128
#              ReLU-43          [4, 64, 128, 128]               0
#            Conv2d-44          [4, 64, 128, 128]          36,864
#       BatchNorm2d-45          [4, 64, 128, 128]             128
#              ReLU-46          [4, 64, 128, 128]               0
#            Conv2d-47         [4, 256, 128, 128]          16,384
#       BatchNorm2d-48         [4, 256, 128, 128]             512
#              ReLU-49         [4, 256, 128, 128]               0
#        Bottleneck-50         [4, 256, 128, 128]               0
#            Conv2d-51         [4, 128, 128, 128]          32,768
#       BatchNorm2d-52         [4, 128, 128, 128]             256
#              ReLU-53         [4, 128, 128, 128]               0
#            Conv2d-54           [4, 128, 64, 64]         147,456
#       BatchNorm2d-55           [4, 128, 64, 64]             256
#              ReLU-56           [4, 128, 64, 64]               0
#            Conv2d-57           [4, 512, 64, 64]          65,536
#       BatchNorm2d-58           [4, 512, 64, 64]           1,024
#            Conv2d-59           [4, 512, 64, 64]         131,072
#       BatchNorm2d-60           [4, 512, 64, 64]           1,024
#              ReLU-61           [4, 512, 64, 64]               0
#        Bottleneck-62           [4, 512, 64, 64]               0
#            Conv2d-63           [4, 128, 64, 64]          65,536
#       BatchNorm2d-64           [4, 128, 64, 64]             256
#              ReLU-65           [4, 128, 64, 64]               0
#            Conv2d-66           [4, 128, 64, 64]         147,456
#       BatchNorm2d-67           [4, 128, 64, 64]             256
#              ReLU-68           [4, 128, 64, 64]               0
#            Conv2d-69           [4, 512, 64, 64]          65,536
#       BatchNorm2d-70           [4, 512, 64, 64]           1,024
#              ReLU-71           [4, 512, 64, 64]               0
#        Bottleneck-72           [4, 512, 64, 64]               0
#            Conv2d-73           [4, 128, 64, 64]          65,536
#       BatchNorm2d-74           [4, 128, 64, 64]             256
#              ReLU-75           [4, 128, 64, 64]               0
#            Conv2d-76           [4, 128, 64, 64]         147,456
#       BatchNorm2d-77           [4, 128, 64, 64]             256
#              ReLU-78           [4, 128, 64, 64]               0
#            Conv2d-79           [4, 512, 64, 64]          65,536
#       BatchNorm2d-80           [4, 512, 64, 64]           1,024
#              ReLU-81           [4, 512, 64, 64]               0
#        Bottleneck-82           [4, 512, 64, 64]               0
#            Conv2d-83           [4, 128, 64, 64]          65,536
#       BatchNorm2d-84           [4, 128, 64, 64]             256
#              ReLU-85           [4, 128, 64, 64]               0
#            Conv2d-86           [4, 128, 64, 64]         147,456
#       BatchNorm2d-87           [4, 128, 64, 64]             256
#              ReLU-88           [4, 128, 64, 64]               0
#            Conv2d-89           [4, 512, 64, 64]          65,536
#       BatchNorm2d-90           [4, 512, 64, 64]           1,024
#              ReLU-91           [4, 512, 64, 64]               0
#        Bottleneck-92           [4, 512, 64, 64]               0
#            Conv2d-93           [4, 256, 64, 64]         131,072
#       BatchNorm2d-94           [4, 256, 64, 64]             512
#              ReLU-95           [4, 256, 64, 64]               0
#            Conv2d-96           [4, 256, 32, 32]         589,824
#       BatchNorm2d-97           [4, 256, 32, 32]             512
#              ReLU-98           [4, 256, 32, 32]               0
#            Conv2d-99          [4, 1024, 32, 32]         262,144
#      BatchNorm2d-100          [4, 1024, 32, 32]           2,048
#           Conv2d-101          [4, 1024, 32, 32]         524,288
#      BatchNorm2d-102          [4, 1024, 32, 32]           2,048
#             ReLU-103          [4, 1024, 32, 32]               0
#       Bottleneck-104          [4, 1024, 32, 32]               0
#           Conv2d-105           [4, 256, 32, 32]         262,144
#      BatchNorm2d-106           [4, 256, 32, 32]             512
#             ReLU-107           [4, 256, 32, 32]               0
#           Conv2d-108           [4, 256, 32, 32]         589,824
#      BatchNorm2d-109           [4, 256, 32, 32]             512
#             ReLU-110           [4, 256, 32, 32]               0
#           Conv2d-111          [4, 1024, 32, 32]         262,144
#      BatchNorm2d-112          [4, 1024, 32, 32]           2,048
#             ReLU-113          [4, 1024, 32, 32]               0
#       Bottleneck-114          [4, 1024, 32, 32]               0
#           Conv2d-115           [4, 256, 32, 32]         262,144
#      BatchNorm2d-116           [4, 256, 32, 32]             512
#             ReLU-117           [4, 256, 32, 32]               0
#           Conv2d-118           [4, 256, 32, 32]         589,824
#      BatchNorm2d-119           [4, 256, 32, 32]             512
#             ReLU-120           [4, 256, 32, 32]               0
#           Conv2d-121          [4, 1024, 32, 32]         262,144
#      BatchNorm2d-122          [4, 1024, 32, 32]           2,048
#             ReLU-123          [4, 1024, 32, 32]               0
#       Bottleneck-124          [4, 1024, 32, 32]               0
#           Conv2d-125           [4, 256, 32, 32]         262,144
#      BatchNorm2d-126           [4, 256, 32, 32]             512
#             ReLU-127           [4, 256, 32, 32]               0
#           Conv2d-128           [4, 256, 32, 32]         589,824
#      BatchNorm2d-129           [4, 256, 32, 32]             512
#             ReLU-130           [4, 256, 32, 32]               0
#           Conv2d-131          [4, 1024, 32, 32]         262,144
#      BatchNorm2d-132          [4, 1024, 32, 32]           2,048
#             ReLU-133          [4, 1024, 32, 32]               0
#       Bottleneck-134          [4, 1024, 32, 32]               0
#           Conv2d-135           [4, 256, 32, 32]         262,144
#      BatchNorm2d-136           [4, 256, 32, 32]             512
#             ReLU-137           [4, 256, 32, 32]               0
#           Conv2d-138           [4, 256, 32, 32]         589,824
#      BatchNorm2d-139           [4, 256, 32, 32]             512
#             ReLU-140           [4, 256, 32, 32]               0
#           Conv2d-141          [4, 1024, 32, 32]         262,144
#      BatchNorm2d-142          [4, 1024, 32, 32]           2,048
#             ReLU-143          [4, 1024, 32, 32]               0
#       Bottleneck-144          [4, 1024, 32, 32]               0
#           Conv2d-145           [4, 256, 32, 32]         262,144
#      BatchNorm2d-146           [4, 256, 32, 32]             512
#             ReLU-147           [4, 256, 32, 32]               0
#           Conv2d-148           [4, 256, 32, 32]         589,824
#      BatchNorm2d-149           [4, 256, 32, 32]             512
#             ReLU-150           [4, 256, 32, 32]               0
#           Conv2d-151          [4, 1024, 32, 32]         262,144
#      BatchNorm2d-152          [4, 1024, 32, 32]           2,048
#             ReLU-153          [4, 1024, 32, 32]               0
#       Bottleneck-154          [4, 1024, 32, 32]               0
#           Conv2d-155           [4, 512, 32, 32]         524,288
#      BatchNorm2d-156           [4, 512, 32, 32]           1,024
#             ReLU-157           [4, 512, 32, 32]               0
#           Conv2d-158           [4, 512, 16, 16]       2,359,296
#      BatchNorm2d-159           [4, 512, 16, 16]           1,024
#             ReLU-160           [4, 512, 16, 16]               0
#           Conv2d-161          [4, 2048, 16, 16]       1,048,576
#      BatchNorm2d-162          [4, 2048, 16, 16]           4,096
#           Conv2d-163          [4, 2048, 16, 16]       2,097,152
#      BatchNorm2d-164          [4, 2048, 16, 16]           4,096
#             ReLU-165          [4, 2048, 16, 16]               0
#       Bottleneck-166          [4, 2048, 16, 16]               0
#           Conv2d-167           [4, 512, 16, 16]       1,048,576
#      BatchNorm2d-168           [4, 512, 16, 16]           1,024
#             ReLU-169           [4, 512, 16, 16]               0
#           Conv2d-170           [4, 512, 16, 16]       2,359,296
#      BatchNorm2d-171           [4, 512, 16, 16]           1,024
#             ReLU-172           [4, 512, 16, 16]               0
#           Conv2d-173          [4, 2048, 16, 16]       1,048,576
#      BatchNorm2d-174          [4, 2048, 16, 16]           4,096
#             ReLU-175          [4, 2048, 16, 16]               0
#       Bottleneck-176          [4, 2048, 16, 16]               0
#           Conv2d-177           [4, 512, 16, 16]       1,048,576
#      BatchNorm2d-178           [4, 512, 16, 16]           1,024
#             ReLU-179           [4, 512, 16, 16]               0
#           Conv2d-180           [4, 512, 16, 16]       2,359,296
#      BatchNorm2d-181           [4, 512, 16, 16]           1,024
#             ReLU-182           [4, 512, 16, 16]               0
#           Conv2d-183          [4, 2048, 16, 16]       1,048,576
#      BatchNorm2d-184          [4, 2048, 16, 16]           4,096
#             ReLU-185          [4, 2048, 16, 16]               0
#       Bottleneck-186          [4, 2048, 16, 16]               0
#           Conv2d-187          [4, 1024, 16, 16]       2,097,152
#           Conv2d-188          [4, 2048, 16, 16]          18,432
#           Conv2d-189          [4, 1024, 16, 16]       2,097,152
# DepthwiseSeparableConv-190          [4, 1024, 16, 16]               0
#           Conv2d-191          [4, 2048, 16, 16]          18,432
#           Conv2d-192          [4, 1024, 16, 16]       2,097,152
# DepthwiseSeparableConv-193          [4, 1024, 16, 16]               0
#           Conv2d-194          [4, 2048, 16, 16]          18,432
#           Conv2d-195          [4, 1024, 16, 16]       2,097,152
# DepthwiseSeparableConv-196          [4, 1024, 16, 16]               0
#           Conv2d-197          [4, 2048, 16, 16]          18,432
#           Conv2d-198          [4, 1024, 16, 16]       2,097,152
# DepthwiseSeparableConv-199          [4, 1024, 16, 16]               0
# AdaptiveAvgPool2d-200            [4, 2048, 1, 1]               0
#           Conv2d-201            [4, 1024, 1, 1]       2,097,152
#           Conv2d-202          [4, 1024, 16, 16]       6,291,456
#             ASPP-203          [4, 1024, 16, 16]               0
#         ResNet50-204  [[-1, 64, 256, 256], [-1, 256, 128, 128], [-1, 512, 64, 64], [-1, 1024, 32, 32], [-1, 1024, 16, 16]]               0
#  ConvTranspose2d-205           [4, 512, 32, 32]       8,389,120
#           Conv2d-206           [4, 256, 32, 32]         393,472
#           Conv2d-207           [4, 256, 32, 32]         590,080
#  ConvTranspose2d-208           [4, 256, 64, 64]       1,048,832
#         Upsample-209           [4, 256, 64, 64]               0
#           Conv2d-210           [4, 128, 64, 64]          98,432
#           Conv2d-211           [4, 128, 64, 64]         147,584
#  ConvTranspose2d-212         [4, 128, 128, 128]         262,272
#         Upsample-213         [4, 128, 128, 128]               0
#           Conv2d-214          [4, 64, 128, 128]          24,640
#           Conv2d-215          [4, 64, 128, 128]          36,928
#  ConvTranspose2d-216          [4, 64, 256, 256]          65,600
#         Upsample-217          [4, 64, 256, 256]               0
#           Conv2d-218          [4, 32, 256, 256]           4,128
#           Conv2d-219          [4, 32, 256, 256]           9,248
#  ConvTranspose2d-220          [4, 32, 512, 512]          16,416
#         Upsample-221          [4, 32, 512, 512]               0
#           Conv2d-222          [4, 32, 512, 512]           9,248
#           Conv2d-223           [4, 7, 512, 512]             231
# ================================================================
# Total params: 63,396,488
# Trainable params: 63,396,488
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 12.00
# Forward/backward pass size (MB): 7814.17
# Params size (MB): 241.84
# Estimated Total Size (MB): 8068.01
# ----------------------------------------------------------------

# %%
class TextLoss(nn.Module):

    def __init__(self):
        super().__init__()

        
    def ohem(self, predict, target, train_mask, negative_ratio=3.):
        pos = (target * train_mask).bool()
        neg = ((1 - target) * train_mask).bool()

        n_pos = pos.float().sum()

        if n_pos.item() > 0:
            loss_pos = F.cross_entropy(predict[pos], target[pos], reduction='sum')
            loss_neg = F.cross_entropy(predict[neg], target[neg], reduction='none')
            
            n_neg = min(int(neg.float().sum().item()), int(negative_ratio * n_pos.float()))
        else:
            loss_pos = torch.tensor(0.).to(predict.device)
            loss_neg = F.cross_entropy(predict[neg], target[neg].long(), reduction='none')
                        
            n_neg = 100
        loss_neg, _ = torch.topk(loss_neg, n_neg)

        return (loss_pos + loss_neg.sum()) / (n_pos + n_neg).float()

    
    def forward(self, input, tr_mask, tcl_mask, sin_map, cos_map, radii_map, train_mask):
        tr_pred = input[:, :2].permute(0, 2, 3, 1).contiguous().view(-1, 2)
        tcl_pred = input[:, 2:4].permute(0, 2, 3, 1).contiguous().view(-1, 2)
        sin_pred = input[:, 4].contiguous().view(-1)
        cos_pred = input[:, 5].contiguous().view(-1)

        scale = torch.sqrt(1.0 / (sin_pred ** 2 + cos_pred ** 2))
        sin_pred = sin_pred * scale
        cos_pred = cos_pred * scale

        radii_pred = input[:, 6].contiguous().view(-1)

        batch_size = tr_pred.size(0)
        height, width = tr_mask.size(-2), tr_mask.size(-1)

        train_mask = train_mask.view(-1)
        tr_mask = tr_mask.view(-1)
        tcl_mask = tcl_mask.view(-1)
        sin_map = sin_map.view(-1)
        cos_map = cos_map.view(-1)
        radii_map = radii_map.view(-1)

        loss_tr = self.ohem(tr_pred, tr_mask, train_mask)
        

        loss_tcl = 0.
        tr_train_mask = train_mask * tr_mask
        if tr_train_mask.sum().item() > 0:
            loss_tcl = F.cross_entropy(tcl_pred[tr_train_mask], tcl_mask[tr_train_mask].long())

        loss_radii, loss_sin, loss_cos = 0., 0., 0.
        tcl_train_mask = train_mask * tcl_mask
        if tcl_train_mask.sum().item() > 0:
            ones = radii_map.new(radii_pred[tcl_train_mask].size()).fill_(1.).float()
            loss_radii = F.smooth_l1_loss(radii_pred[tcl_train_mask] / radii_map[tcl_train_mask], ones)
            loss_sin = F.smooth_l1_loss(sin_pred[tcl_train_mask], sin_map[tcl_train_mask])
            loss_cos = F.smooth_l1_loss(cos_pred[tcl_train_mask], cos_map[tcl_train_mask])

        return loss_tr, loss_tcl, loss_radii, loss_sin, loss_cos

# %%
lr=None
train_step=0

def save_model(model, epoch, lr, optimzer):

    save_dir = os.path.join(cfg.save_dir, cfg.exp_name)
    if not os.path.exists(save_dir):
        mkdirs(save_dir)

    save_path = os.path.join(save_dir, 'textsnake_{}_{}.pth'.format(model.backbone_name, epoch))
    print('Saving to {}.'.format(save_path))
    state_dict = {
        'lr': lr,
        'epoch': epoch,
        'model': model.state_dict() if not cfg.mgpu else model.module.state_dict(),
        'optimizer': optimzer.state_dict()
    }
    torch.save(state_dict, save_path)

# %%
def load_model(model, model_path):
    print('Loading from {}'.format(model_path))
    state_dict = torch.load(model_path)
    model.load_state_dict(state_dict['model'])

# %%
def plot_losses(train_losses, val_losses):
    plt.figure(figsize=(10, 5))
    plt.title("Training and Validation Losses")
    plt.plot(train_losses, label="Training Loss")
    plt.plot(val_losses, label="Validation Loss")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.show()

# %%
def train(model, train_loader, criterion, scheduler, optimizer, epoch, logger):

    global train_step

    losses = AverageMeter()
    batch_time = AverageMeter()
    data_time = AverageMeter()
    end = time.time()
    model.train()
    scheduler.step()

    print('Epoch: {} : LR = {}'.format(epoch, lr))

    for i, (img, train_mask, tr_mask, tcl_mask, radius_map, sin_map, cos_map, meta) in enumerate(train_loader):
        data_time.update(time.time() - end)

        train_step += 1

        img, train_mask, tr_mask, tcl_mask, radius_map, sin_map, cos_map = to_device(
            img, train_mask, tr_mask, tcl_mask, radius_map, sin_map, cos_map)
        
        output = model(img)
        tr_loss, tcl_loss, sin_loss, cos_loss, radii_loss = \
            criterion(output, tr_mask, tcl_mask, sin_map, cos_map, radius_map, train_mask)
        loss = tr_loss + tcl_loss + sin_loss + cos_loss + radii_loss

        # backward
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        losses.update(loss.item())
        # measure elapsed time
        batch_time.update(time.time() - end)
        end = time.time()

        if cfg.viz and i % cfg.viz_freq == 0:
            visualize_network_output(output, tr_mask, tcl_mask, mode='train')

        if i % cfg.display_freq == 0:
            print('({:d} / {:d}) - Loss: {:.4f} - tr_loss: {:.4f} - tcl_loss: {:.4f} - sin_loss: {:.4f} - cos_loss: {:.4f} - radii_loss: {:.4f}'.format(
                i, len(train_loader), loss.item(), tr_loss.item(), tcl_loss.item(), sin_loss.item(), cos_loss.item(), radii_loss.item())
            )

        if i % cfg.log_freq == 0:
            logger.write_scalars({
                'loss': loss.item(),
                'tr_loss': tr_loss.item(),
                'tcl_loss': tcl_loss.item(),
                'sin_loss': sin_loss.item(),
                'cos_loss': cos_loss.item(),
                'radii_loss': radii_loss.item()
            }, tag='train', n_iter=train_step)

    if epoch % cfg.save_freq == 0:
        save_model(model, epoch, scheduler.get_lr(), optimizer)

    print('Training Loss: {}'.format(losses.avg))
    return losses.avg

# %%
def validation(model, valid_loader, criterion, epoch, logger):
    
    with torch.no_grad():
        model.eval()
        losses = AverageMeter()
        tr_losses = AverageMeter()
        tcl_losses = AverageMeter()
        sin_losses = AverageMeter()
        cos_losses = AverageMeter()
        radii_losses = AverageMeter()

        for i, (img, train_mask, tr_mask, tcl_mask, radius_map, sin_map, cos_map, meta) in enumerate(valid_loader):

            img, train_mask, tr_mask, tcl_mask, radius_map, sin_map, cos_map = to_device(
                img, train_mask, tr_mask, tcl_mask, radius_map, sin_map, cos_map)
            
            output = model(img)

            tr_loss, tcl_loss, sin_loss, cos_loss, radii_loss = \
                criterion(output, tr_mask, tcl_mask, sin_map, cos_map, radius_map, train_mask)
            loss = tr_loss + tcl_loss + sin_loss + cos_loss + radii_loss

            # update losses
            losses.update(loss.item())
            tr_losses.update(tr_loss.item())
            tcl_losses.update(tcl_loss.item())
            sin_losses.update(sin_loss.item())
            cos_losses.update(cos_loss.item())
            radii_losses.update(radii_loss.item())

            if cfg.viz and i % cfg.viz_freq == 0:
                visualize_network_output(output, tr_mask, tcl_mask, mode='val')

            if i % cfg.display_freq == 0:
                print(
                    'Validation: - Loss: {:.4f} - tr_loss: {:.4f} - tcl_loss: {:.4f} - sin_loss: {:.4f} - cos_loss: {:.4f} - radii_loss: {:.4f}'.format(
                        loss.item(), tr_loss.item(), tcl_loss.item(), sin_loss.item(),
                        cos_loss.item(), radii_loss.item())
                )

        logger.write_scalars({
            'loss': losses.avg,
            'tr_loss': tr_losses.avg,
            'tcl_loss': tcl_losses.avg,
            'sin_loss': sin_losses.avg,
            'cos_loss': cos_losses.avg,
            'radii_loss': radii_losses.avg
        }, tag='val', n_iter=epoch)

        print('Validation Loss: {}'.format(losses.avg))
        return losses.avg

# %%
def main():
    
    if mp.get_start_method(allow_none=True) != 'spawn':
        mp.set_start_method('spawn', force=True)
        
    train_losses = []
    val_losses = []
        
    global lr
    print(cfg.dataset)
    
    if cfg.dataset == 'total-text':

        trainset = TotalText(
            data_root='data/total-text',
            ignore_list=None,
            is_training=True,
            transform=Augmentation(size=cfg.input_size, mean=cfg.means, std=cfg.stds)
        )

        valset = TotalText(
            data_root='data/total-text',
            ignore_list=None,
            is_training=False,
            transform=BaseTransform(size=cfg.input_size, mean=cfg.means, std=cfg.stds)
        )

    elif cfg.dataset == 'synth-text':
        trainset = SynthText(
            data_root='data/SynthText',
            is_training=True,
            transform=Augmentation(size=cfg.input_size, mean=cfg.means, std=cfg.stds)
        )
        valset = None
    else:
        pass

    train_loader = data.DataLoader(trainset, batch_size=cfg.batch_size, shuffle=True, num_workers=cfg.num_workers)
    if valset:
        val_loader = data.DataLoader(valset, batch_size=cfg.batch_size, shuffle=False, num_workers=cfg.num_workers)
    else:
        valset = None

    log_dir = os.path.join(cfg.log_dir, datetime.now().strftime('%b%d_%H-%M-%S_') + cfg.exp_name)
    logger = LogSummary(log_dir)

    # Model
    model = TextNet(is_training=True, backbone='resnet', output_channel=7)
        
    if cfg.mgpu:
        model = nn.DataParallel(model)

    model = model.to(cfg.device)

    
    if cfg.cuda:
        cudnn.benchmark = True

    if cfg.resume:
        load_model(model, cfg.resume)

    criterion = TextLoss()
    lr = cfg.lr
    optimizer = torch.optim.Adam(model.parameters(), lr=cfg.lr)

    if cfg.dataset == 'synth-text':
        scheduler = FixLR(optimizer)
    else:
        scheduler = lr_scheduler.StepLR(optimizer, step_size=100, gamma=0.1)

    print('Start training TextSnake.')
    
    for epoch in range(cfg.start_epoch, cfg.max_epoch):
        # train(model, train_loader, criterion, scheduler, optimizer, epoch, logger)
        train_loss=train(model, train_loader, criterion, scheduler, optimizer, epoch, logger)
        train_losses.append(train_loss)
        
        if valset:
            # validation(model, val_loader, criterion, epoch, logger)
            val_loss=validation(model, val_loader, criterion, epoch, logger)
            val_losses.append(val_loss)
            
    print('End.')
    
    plot_losses(train_losses, val_losses)

# %%
option = BaseOptions()
command_line_args = ["resnet_ASPP_LATE_GATE", "--viz", "--net", "resnet", "--cuda", "True"]


args = option.initialize(command_line_args)


update_config(cfg, args)
print_config(cfg)


main()
# Out:
# total-text
# ==========Options============
# num_workers: 8
# batch_size: 4
# max_epoch: 201
# start_epoch: 0
# lr: 0.0001
# cuda: True
# n_disk: 15
# output_dir: output
# input_size: 512
# max_annotation: 200
# max_points: 20
# use_hard: True
# tr_thresh: 0.6
# tcl_thresh: 0.4
# post_process_expand: 0.3
# post_process_merge: False
# dataset: total-text
# device: cuda
# vis_dir: ./vis/
# save_dir: ./save/
# data_custom: False
# data_root: data/total-text
# exp_name: resnet_ASPP_LATE_GATE
# net: resnet
# resume: None
# mgpu: False
# log_dir: ./logs/
# loss: CrossEntropyLoss
# input_channel: 1
# pretrain: False
# verbose: True
# viz: True
# start_iter: 0
# lr_adjust: fix
# stepvalues: []
# weight_decay: 0.0
# gamma: 0.1
# momentum: 0.9
# optim: SGD
# display_freq: 50
# viz_freq: 50
# save_freq: 50
# log_freq: 100
# val_freq: 100
# rescale: 255.0
# means: [0.485, 0.456, 0.406]
# stds: [0.229, 0.224, 0.225]
# checkepoch: -1
# img_root: None
# =============End=============
# total-text
# Start training TextSnake.
# Epoch: 0 : LR = 0.0001
# (0 / 314) - Loss: 2.4468 - tr_loss: 0.7190 - tcl_loss: 0.6736 - sin_loss: 0.5007 - cos_loss: 0.3868 - radii_loss: 0.1667
# (50 / 314) - Loss: 2.2397 - tr_loss: 0.6860 - tcl_loss: 0.6188 - sin_loss: 0.4950 - cos_loss: 0.1663 - radii_loss: 0.2736
# (100 / 314) - Loss: 1.7942 - tr_loss: 0.5510 - tcl_loss: 0.5669 - sin_loss: 0.4633 - cos_loss: 0.0457 - radii_loss: 0.1673
# (150 / 314) - Loss: 2.0762 - tr_loss: 0.5064 - tcl_loss: 0.5423 - sin_loss: 0.4456 - cos_loss: 0.0494 - radii_loss: 0.5325
# (200 / 314) - Loss: 2.7266 - tr_loss: 0.4439 - tcl_loss: 0.5294 - sin_loss: 0.4216 - cos_loss: 0.1322 - radii_loss: 1.1995
# (250 / 314) - Loss: 1.8636 - tr_loss: 0.4819 - tcl_loss: 0.5511 - sin_loss: 0.2403 - cos_loss: 0.0159 - radii_loss: 0.5743
# (300 / 314) - Loss: 2.0529 - tr_loss: 0.5238 - tcl_loss: 0.5631 - sin_loss: 0.2159 - cos_loss: 0.1430 - radii_loss: 0.6071
# Saving to ./save/resnet_ASPP_LATE_GATE/textsnake_resnet_0.pth.
# Training Loss: 2.3489638593546145
# Validation: - Loss: 2.4366 - tr_loss: 0.5380 - tcl_loss: 0.5509 - sin_loss: 0.0908 - cos_loss: 0.0851 - radii_loss: 1.1718
# Validation: - Loss: 1.8402 - tr_loss: 0.5603 - tcl_loss: 0.5529 - sin_loss: 0.0583 - cos_loss: 0.2466 - radii_loss: 0.4221
# Validation Loss: 2.4019036928812665
# Epoch: 1 : LR = 0.0001
# (0 / 314) - Loss: 1.8970 - tr_loss: 0.4804 - tcl_loss: 0.5586 - sin_loss: 0.1014 - cos_loss: 0.1988 - radii_loss: 0.5578
# (50 / 314) - Loss: 1.9654 - tr_loss: 0.4470 - tcl_loss: 0.5457 - sin_loss: 0.1320 - cos_loss: 0.1790 - radii_loss: 0.6616
# (100 / 314) - Loss: 1.5836 - tr_loss: 0.5349 - tcl_loss: 0.5985 - sin_loss: 0.2231 - cos_loss: 0.1277 - radii_loss: 0.0993
# (150 / 314) - Loss: 2.0816 - tr_loss: 0.5419 - tcl_loss: 0.5712 - sin_loss: 0.0764 - cos_loss: 0.0318 - radii_loss: 0.8603
# (200 / 314) - Loss: 2.5277 - tr_loss: 0.4700 - tcl_loss: 0.5503 - sin_loss: 0.0790 - cos_loss: 0.0812 - radii_loss: 1.3472
# (250 / 314) - Loss: 2.9811 - tr_loss: 0.8466 - tcl_loss: 0.6226 - sin_loss: 0.1440 - cos_loss: 0.0963 - radii_loss: 1.2716
# (300 / 314) - Loss: 2.1653 - tr_loss: 0.4759 - tcl_loss: 0.5330 - sin_loss: 0.0848 - cos_loss: 0.1231 - radii_loss: 0.9485
# Training Loss: 2.0092813015743425
# Validation: - Loss: 2.3449 - tr_loss: 0.4972 - tcl_loss: 0.5702 - sin_loss: 0.0206 - cos_loss: 0.0826 - radii_loss: 1.1744
# Validation: - Loss: 1.8581 - tr_loss: 0.5431 - tcl_loss: 0.5590 - sin_loss: 0.0904 - cos_loss: 0.2421 - radii_loss: 0.4236
# Validation Loss: 2.362891174952189
# Epoch: 2 : LR = 0.0001
# (0 / 314) - Loss: 1.9465 - tr_loss: 0.5030 - tcl_loss: 0.5731 - sin_loss: 0.1280 - cos_loss: 0.1297 - radii_loss: 0.6128
# (50 / 314) - Loss: 2.8439 - tr_loss: 0.5689 - tcl_loss: 0.6224 - sin_loss: 0.2408 - cos_loss: 0.1277 - radii_loss: 1.2841
# (100 / 314) - Loss: 2.1411 - tr_loss: 0.5352 - tcl_loss: 0.5603 - sin_loss: 0.0896 - cos_loss: 0.0747 - radii_loss: 0.8812
# (150 / 314) - Loss: 2.4752 - tr_loss: 0.4515 - tcl_loss: 0.5357 - sin_loss: 0.0980 - cos_loss: 0.1248 - radii_loss: 1.2652
# (200 / 314) - Loss: 2.1953 - tr_loss: 0.5251 - tcl_loss: 0.6000 - sin_loss: 0.0942 - cos_loss: 0.1737 - radii_loss: 0.8023
# (250 / 314) - Loss: 1.3437 - tr_loss: 0.4189 - tcl_loss: 0.5184 - sin_loss: 0.1087 - cos_loss: 0.1746 - radii_loss: 0.1230
# (300 / 314) - Loss: 1.9788 - tr_loss: 0.4003 - tcl_loss: 0.5533 - sin_loss: 0.1591 - cos_loss: 0.0643 - radii_loss: 0.8019
# Training Loss: 1.958370007147455
# Validation: - Loss: 2.2791 - tr_loss: 0.4099 - tcl_loss: 0.5539 - sin_loss: 0.0574 - cos_loss: 0.0753 - radii_loss: 1.1826
# Validation: - Loss: 1.7764 - tr_loss: 0.5353 - tcl_loss: 0.5151 - sin_loss: 0.0758 - cos_loss: 0.2212 - radii_loss: 0.4291
# Validation Loss: 2.2823040866851807
# Epoch: 3 : LR = 0.0001
# (0 / 314) - Loss: 2.0968 - tr_loss: 0.4777 - tcl_loss: 0.5385 - sin_loss: 0.0762 - cos_loss: 0.3197 - radii_loss: 0.6848
# (50 / 314) - Loss: 2.3892 - tr_loss: 0.4659 - tcl_loss: 0.5661 - sin_loss: 0.1384 - cos_loss: 0.1260 - radii_loss: 1.0928
# (100 / 314) - Loss: 2.1226 - tr_loss: 0.3661 - tcl_loss: 0.5195 - sin_loss: 0.1008 - cos_loss: 0.1042 - radii_loss: 1.0320
# (150 / 314) - Loss: 1.3656 - tr_loss: 0.3649 - tcl_loss: 0.5407 - sin_loss: 0.1403 - cos_loss: 0.0595 - radii_loss: 0.2601
# (200 / 314) - Loss: 2.4880 - tr_loss: 0.4698 - tcl_loss: 0.5846 - sin_loss: 0.0665 - cos_loss: 0.0529 - radii_loss: 1.3142
# (250 / 314) - Loss: 2.0505 - tr_loss: 0.3594 - tcl_loss: 0.5450 - sin_loss: 0.0566 - cos_loss: 0.1254 - radii_loss: 0.9640
# (300 / 314) - Loss: 2.5795 - tr_loss: 0.5097 - tcl_loss: 0.5357 - sin_loss: 0.1975 - cos_loss: 0.0860 - radii_loss: 1.2506
# Training Loss: 1.919128354567631
# Validation: - Loss: 2.0683 - tr_loss: 0.2782 - tcl_loss: 0.4908 - sin_loss: 0.0414 - cos_loss: 0.0752 - radii_loss: 1.1827
# Validation: - Loss: 1.5415 - tr_loss: 0.3210 - tcl_loss: 0.4737 - sin_loss: 0.0970 - cos_loss: 0.2205 - radii_loss: 0.4292
# Validation Loss: 2.1985371685028077
# Epoch: 4 : LR = 0.0001
# (0 / 314) - Loss: 2.2110 - tr_loss: 0.3789 - tcl_loss: 0.5004 - sin_loss: 0.1457 - cos_loss: 0.0136 - radii_loss: 1.1725
# (50 / 314) - Loss: 1.6318 - tr_loss: 0.3845 - tcl_loss: 0.5430 - sin_loss: 0.2014 - cos_loss: 0.1448 - radii_loss: 0.3582
# (100 / 314) - Loss: 2.0721 - tr_loss: 0.5155 - tcl_loss: 0.5568 - sin_loss: 0.1601 - cos_loss: 0.0818 - radii_loss: 0.7580
# (150 / 314) - Loss: 1.2182 - tr_loss: 0.3051 - tcl_loss: 0.4540 - sin_loss: 0.0486 - cos_loss: 0.1058 - radii_loss: 0.3047
# (200 / 314) - Loss: 1.9333 - tr_loss: 0.4664 - tcl_loss: 0.5242 - sin_loss: 0.0734 - cos_loss: 0.1629 - radii_loss: 0.7064
# (250 / 314) - Loss: 1.8712 - tr_loss: 0.3475 - tcl_loss: 0.3913 - sin_loss: 0.0364 - cos_loss: 0.0305 - radii_loss: 1.0655
# (300 / 314) - Loss: 0.9767 - tr_loss: 0.3005 - tcl_loss: 0.4682 - sin_loss: 0.0619 - cos_loss: 0.1106 - radii_loss: 0.0355
# Training Loss: 1.747107831725649
# Validation: - Loss: 1.9228 - tr_loss: 0.2314 - tcl_loss: 0.4137 - sin_loss: 0.0193 - cos_loss: 0.0754 - radii_loss: 1.1830
# Validation: - Loss: 1.5065 - tr_loss: 0.3677 - tcl_loss: 0.4536 - sin_loss: 0.0384 - cos_loss: 0.2175 - radii_loss: 0.4293
# Validation Loss: 2.0540152994791665
# Epoch: 5 : LR = 0.0001
# (0 / 314) - Loss: 1.1897 - tr_loss: 0.2909 - tcl_loss: 0.4614 - sin_loss: 0.1550 - cos_loss: 0.0834 - radii_loss: 0.1990
# (50 / 314) - Loss: 1.8443 - tr_loss: 0.3631 - tcl_loss: 0.4190 - sin_loss: 0.0651 - cos_loss: 0.1866 - radii_loss: 0.8105
# (100 / 314) - Loss: 1.1371 - tr_loss: 0.3250 - tcl_loss: 0.4076 - sin_loss: 0.0606 - cos_loss: 0.1732 - radii_loss: 0.1707
# (150 / 314) - Loss: 1.3156 - tr_loss: 0.3125 - tcl_loss: 0.4673 - sin_loss: 0.0585 - cos_loss: 0.0595 - radii_loss: 0.4178
# (200 / 314) - Loss: 2.4128 - tr_loss: 0.3313 - tcl_loss: 0.5953 - sin_loss: 0.1162 - cos_loss: 0.0957 - radii_loss: 1.2742
# (250 / 314) - Loss: 1.8496 - tr_loss: 0.3203 - tcl_loss: 0.5059 - sin_loss: 0.0531 - cos_loss: 0.0570 - radii_loss: 0.9133
# (300 / 314) - Loss: 2.2058 - tr_loss: 0.3417 - tcl_loss: 0.4923 - sin_loss: 0.1223 - cos_loss: 0.1543 - radii_loss: 1.0953
# Training Loss: 1.6789420368565116
# Validation: - Loss: 1.9115 - tr_loss: 0.2420 - tcl_loss: 0.3588 - sin_loss: 0.0534 - cos_loss: 0.0756 - radii_loss: 1.1818
# Validation: - Loss: 1.3727 - tr_loss: 0.2906 - tcl_loss: 0.3806 - sin_loss: 0.0432 - cos_loss: 0.2315 - radii_loss: 0.4268
# Validation Loss: 1.989006420771281
# Epoch: 6 : LR = 0.0001
# (0 / 314) - Loss: 2.1235 - tr_loss: 0.2527 - tcl_loss: 0.3646 - sin_loss: 0.0980 - cos_loss: 0.0458 - radii_loss: 1.3625
# (50 / 314) - Loss: 1.8107 - tr_loss: 0.2588 - tcl_loss: 0.3585 - sin_loss: 0.0546 - cos_loss: 0.1119 - radii_loss: 1.0268
# (100 / 314) - Loss: 2.2856 - tr_loss: 0.3445 - tcl_loss: 0.4579 - sin_loss: 0.0586 - cos_loss: 0.0850 - radii_loss: 1.3397
# (150 / 314) - Loss: 1.6816 - tr_loss: 0.3827 - tcl_loss: 0.3861 - sin_loss: 0.0554 - cos_loss: 0.0735 - radii_loss: 0.7839
# (200 / 314) - Loss: 1.3941 - tr_loss: 0.3581 - tcl_loss: 0.4241 - sin_loss: 0.0835 - cos_loss: 0.1657 - radii_loss: 0.3627
# (250 / 314) - Loss: 2.2942 - tr_loss: 0.2893 - tcl_loss: 0.4521 - sin_loss: 0.1758 - cos_loss: 0.1508 - radii_loss: 1.2262
# (300 / 314) - Loss: 1.9943 - tr_loss: 0.3407 - tcl_loss: 0.4369 - sin_loss: 0.0799 - cos_loss: 0.1923 - radii_loss: 0.9446
# Training Loss: 1.7430151327020804
# Validation: - Loss: 1.8060 - tr_loss: 0.2093 - tcl_loss: 0.3111 - sin_loss: 0.0286 - cos_loss: 0.0773 - radii_loss: 1.1797
# Validation: - Loss: 1.3455 - tr_loss: 0.3015 - tcl_loss: 0.3498 - sin_loss: 0.0319 - cos_loss: 0.2381 - radii_loss: 0.4242
# Validation Loss: 1.9269375801086426
# Epoch: 7 : LR = 0.0001
# (0 / 314) - Loss: 1.9224 - tr_loss: 0.3975 - tcl_loss: 0.4293 - sin_loss: 0.0970 - cos_loss: 0.1610 - radii_loss: 0.8376
# (50 / 314) - Loss: 1.7010 - tr_loss: 0.2235 - tcl_loss: 0.3683 - sin_loss: 0.0467 - cos_loss: 0.0684 - radii_loss: 0.9941
# (100 / 314) - Loss: 2.2215 - tr_loss: 0.4409 - tcl_loss: 0.5086 - sin_loss: 0.1813 - cos_loss: 0.0698 - radii_loss: 1.0209
# (150 / 314) - Loss: 1.5277 - tr_loss: 0.2606 - tcl_loss: 0.3695 - sin_loss: 0.1090 - cos_loss: 0.1960 - radii_loss: 0.5925
# (200 / 314) - Loss: 2.2276 - tr_loss: 0.3352 - tcl_loss: 0.4149 - sin_loss: 0.1329 - cos_loss: 0.0361 - radii_loss: 1.3085
# (250 / 314) - Loss: 1.1455 - tr_loss: 0.3267 - tcl_loss: 0.3716 - sin_loss: 0.0645 - cos_loss: 0.1679 - radii_loss: 0.2148
# (300 / 314) - Loss: 1.7849 - tr_loss: 0.2547 - tcl_loss: 0.3340 - sin_loss: 0.0262 - cos_loss: 0.0515 - radii_loss: 1.1185
# Training Loss: 1.6409752112664995
# Validation: - Loss: 1.7182 - tr_loss: 0.1744 - tcl_loss: 0.2687 - sin_loss: 0.0177 - cos_loss: 0.0764 - radii_loss: 1.1810
# Validation: - Loss: 1.3598 - tr_loss: 0.3179 - tcl_loss: 0.3475 - sin_loss: 0.0374 - cos_loss: 0.2309 - radii_loss: 0.4261
# Validation Loss: 1.8961229610443116
# Epoch: 8 : LR = 0.0001
# (0 / 314) - Loss: 1.7989 - tr_loss: 0.2249 - tcl_loss: 0.4247 - sin_loss: 0.0991 - cos_loss: 0.1784 - radii_loss: 0.8718
# (50 / 314) - Loss: 1.6535 - tr_loss: 0.4127 - tcl_loss: 0.4646 - sin_loss: 0.0635 - cos_loss: 0.2042 - radii_loss: 0.5086
# (100 / 314) - Loss: 2.3057 - tr_loss: 0.6785 - tcl_loss: 0.5320 - sin_loss: 0.1835 - cos_loss: 0.2286 - radii_loss: 0.6831
# (150 / 314) - Loss: 1.3585 - tr_loss: 0.2103 - tcl_loss: 0.2719 - sin_loss: 0.0221 - cos_loss: 0.0508 - radii_loss: 0.8035
# (200 / 314) - Loss: 1.3451 - tr_loss: 0.2872 - tcl_loss: 0.4306 - sin_loss: 0.0317 - cos_loss: 0.1442 - radii_loss: 0.4514
# (250 / 314) - Loss: 0.7949 - tr_loss: 0.2148 - tcl_loss: 0.4434 - sin_loss: 0.0410 - cos_loss: 0.0214 - radii_loss: 0.0743
# (300 / 314) - Loss: 1.6940 - tr_loss: 0.2311 - tcl_loss: 0.2979 - sin_loss: 0.0218 - cos_loss: 0.0531 - radii_loss: 1.0902
# Training Loss: 1.5655342454363586
# Validation: - Loss: 1.7659 - tr_loss: 0.1914 - tcl_loss: 0.2908 - sin_loss: 0.0251 - cos_loss: 0.0761 - radii_loss: 1.1824
# Validation: - Loss: 1.3264 - tr_loss: 0.2663 - tcl_loss: 0.3538 - sin_loss: 0.0560 - cos_loss: 0.2237 - radii_loss: 0.4267
# Validation Loss: 1.9952764447530111
# Epoch: 9 : LR = 0.0001
# (0 / 314) - Loss: 2.2831 - tr_loss: 0.4221 - tcl_loss: 0.4782 - sin_loss: 0.1869 - cos_loss: 0.1143 - radii_loss: 1.0816
# (50 / 314) - Loss: 1.8857 - tr_loss: 0.2781 - tcl_loss: 0.4207 - sin_loss: 0.0518 - cos_loss: 0.0339 - radii_loss: 1.1013
# (100 / 314) - Loss: 2.0131 - tr_loss: 0.2446 - tcl_loss: 0.2650 - sin_loss: 0.0356 - cos_loss: 0.0578 - radii_loss: 1.4101
# (150 / 314) - Loss: 1.7912 - tr_loss: 0.1513 - tcl_loss: 0.2312 - sin_loss: 0.0177 - cos_loss: 0.0357 - radii_loss: 1.3554
# (200 / 314) - Loss: 2.5177 - tr_loss: 0.6609 - tcl_loss: 0.5258 - sin_loss: 0.0238 - cos_loss: 0.0593 - radii_loss: 1.2478
# (250 / 314) - Loss: 1.1856 - tr_loss: 0.2280 - tcl_loss: 0.3613 - sin_loss: 0.0707 - cos_loss: 0.1142 - radii_loss: 0.4115
# (300 / 314) - Loss: 1.0059 - tr_loss: 0.2637 - tcl_loss: 0.4227 - sin_loss: 0.0776 - cos_loss: 0.1266 - radii_loss: 0.1153
# Training Loss: 1.5345997557898237
# Validation: - Loss: 1.7680 - tr_loss: 0.2085 - tcl_loss: 0.2763 - sin_loss: 0.0243 - cos_loss: 0.0768 - radii_loss: 1.1822
# Validation: - Loss: 1.4143 - tr_loss: 0.3744 - tcl_loss: 0.3416 - sin_loss: 0.0520 - cos_loss: 0.2187 - radii_loss: 0.4276
# Validation Loss: 1.9035344092051187
# Epoch: 10 : LR = 0.0001
# (0 / 314) - Loss: 0.6435 - tr_loss: 0.2394 - tcl_loss: 0.3249 - sin_loss: 0.0340 - cos_loss: 0.0407 - radii_loss: 0.0046
# (50 / 314) - Loss: 1.1244 - tr_loss: 0.1905 - tcl_loss: 0.2968 - sin_loss: 0.0467 - cos_loss: 0.0488 - radii_loss: 0.5416
# (100 / 314) - Loss: 1.4928 - tr_loss: 0.2299 - tcl_loss: 0.3422 - sin_loss: 0.0324 - cos_loss: 0.0927 - radii_loss: 0.7956
# (150 / 314) - Loss: 1.3020 - tr_loss: 0.2439 - tcl_loss: 0.3592 - sin_loss: 0.0482 - cos_loss: 0.1507 - radii_loss: 0.5000
# (200 / 314) - Loss: 1.3840 - tr_loss: 0.3039 - tcl_loss: 0.3152 - sin_loss: 0.0325 - cos_loss: 0.0940 - radii_loss: 0.6383
# (250 / 314) - Loss: 1.6869 - tr_loss: 0.2784 - tcl_loss: 0.3382 - sin_loss: 0.1061 - cos_loss: 0.2069 - radii_loss: 0.7574
# (300 / 314) - Loss: 1.0663 - tr_loss: 0.2843 - tcl_loss: 0.3718 - sin_loss: 0.0715 - cos_loss: 0.0444 - radii_loss: 0.2943
# Training Loss: 1.5467116982693885
# Validation: - Loss: 1.7501 - tr_loss: 0.1961 - tcl_loss: 0.2696 - sin_loss: 0.0274 - cos_loss: 0.0780 - radii_loss: 1.1790
# Validation: - Loss: 1.5023 - tr_loss: 0.3987 - tcl_loss: 0.3817 - sin_loss: 0.0613 - cos_loss: 0.2493 - radii_loss: 0.4113
# Validation Loss: 1.949302493731181
# Epoch: 11 : LR = 0.0001
# (0 / 314) - Loss: 1.7325 - tr_loss: 0.2427 - tcl_loss: 0.4333 - sin_loss: 0.0524 - cos_loss: 0.1084 - radii_loss: 0.8957
# (50 / 314) - Loss: 1.9045 - tr_loss: 0.3218 - tcl_loss: 0.3303 - sin_loss: 0.0922 - cos_loss: 0.1609 - radii_loss: 0.9993
# (100 / 314) - Loss: 1.4232 - tr_loss: 0.2085 - tcl_loss: 0.3207 - sin_loss: 0.0268 - cos_loss: 0.1384 - radii_loss: 0.7288
# (150 / 314) - Loss: 0.8952 - tr_loss: 0.1953 - tcl_loss: 0.3852 - sin_loss: 0.0897 - cos_loss: 0.0779 - radii_loss: 0.1471
# (200 / 314) - Loss: 1.4426 - tr_loss: 0.4666 - tcl_loss: 0.4044 - sin_loss: 0.1041 - cos_loss: 0.1634 - radii_loss: 0.3041
# (250 / 314) - Loss: 1.5319 - tr_loss: 0.4497 - tcl_loss: 0.3962 - sin_loss: 0.1476 - cos_loss: 0.1552 - radii_loss: 0.3832
# (300 / 314) - Loss: 1.6026 - tr_loss: 0.2912 - tcl_loss: 0.4604 - sin_loss: 0.0676 - cos_loss: 0.1243 - radii_loss: 0.6591
# Training Loss: 1.565742356951829
# Validation: - Loss: 1.7603 - tr_loss: 0.1946 - tcl_loss: 0.2794 - sin_loss: 0.0279 - cos_loss: 0.0758 - radii_loss: 1.1826
# Validation: - Loss: 1.2810 - tr_loss: 0.2587 - tcl_loss: 0.3471 - sin_loss: 0.0273 - cos_loss: 0.2203 - radii_loss: 0.4276
# Validation Loss: 1.874719492594401
# Epoch: 12 : LR = 0.0001
# (0 / 314) - Loss: 1.5052 - tr_loss: 0.5378 - tcl_loss: 0.4399 - sin_loss: 0.0623 - cos_loss: 0.1960 - radii_loss: 0.2692
# (50 / 314) - Loss: 1.0292 - tr_loss: 0.1948 - tcl_loss: 0.3331 - sin_loss: 0.0528 - cos_loss: 0.1551 - radii_loss: 0.2935
# (100 / 314) - Loss: 1.7854 - tr_loss: 0.2108 - tcl_loss: 0.3756 - sin_loss: 0.0300 - cos_loss: 0.0803 - radii_loss: 1.0887
# (150 / 314) - Loss: 0.8240 - tr_loss: 0.1763 - tcl_loss: 0.3338 - sin_loss: 0.0234 - cos_loss: 0.1006 - radii_loss: 0.1899
# (200 / 314) - Loss: 1.8071 - tr_loss: 0.1901 - tcl_loss: 0.3001 - sin_loss: 0.0606 - cos_loss: 0.0472 - radii_loss: 1.2091
# (250 / 314) - Loss: 0.8392 - tr_loss: 0.1733 - tcl_loss: 0.2785 - sin_loss: 0.0219 - cos_loss: 0.0954 - radii_loss: 0.2700
# (300 / 314) - Loss: 1.2215 - tr_loss: 0.2478 - tcl_loss: 0.3211 - sin_loss: 0.0263 - cos_loss: 0.1738 - radii_loss: 0.4525
# Training Loss: 1.4839439965357446
# Validation: - Loss: 1.6619 - tr_loss: 0.1566 - tcl_loss: 0.2371 - sin_loss: 0.0114 - cos_loss: 0.0750 - radii_loss: 1.1818
# Validation: - Loss: 1.2083 - tr_loss: 0.2234 - tcl_loss: 0.3074 - sin_loss: 0.0269 - cos_loss: 0.2239 - radii_loss: 0.4266
# Validation Loss: 1.8225647068023683
# Epoch: 13 : LR = 0.0001
# (0 / 314) - Loss: 1.3214 - tr_loss: 0.1941 - tcl_loss: 0.3343 - sin_loss: 0.0127 - cos_loss: 0.1325 - radii_loss: 0.6478
# (50 / 314) - Loss: 1.8206 - tr_loss: 0.2976 - tcl_loss: 0.4075 - sin_loss: 0.0656 - cos_loss: 0.0981 - radii_loss: 0.9520
# (100 / 314) - Loss: 1.1053 - tr_loss: 0.2034 - tcl_loss: 0.3763 - sin_loss: 0.0777 - cos_loss: 0.0940 - radii_loss: 0.3539
# (150 / 314) - Loss: 1.5357 - tr_loss: 0.4024 - tcl_loss: 0.5185 - sin_loss: 0.1499 - cos_loss: 0.1153 - radii_loss: 0.3495
# (200 / 314) - Loss: 1.4513 - tr_loss: 0.2501 - tcl_loss: 0.3299 - sin_loss: 0.0239 - cos_loss: 0.0745 - radii_loss: 0.7729
# (250 / 314) - Loss: 1.8152 - tr_loss: 0.3835 - tcl_loss: 0.4491 - sin_loss: 0.1189 - cos_loss: 0.1035 - radii_loss: 0.7602
# (300 / 314) - Loss: 1.7194 - tr_loss: 0.3273 - tcl_loss: 0.3490 - sin_loss: 0.0565 - cos_loss: 0.1114 - radii_loss: 0.8751
# Training Loss: 1.5061350457227913
# Validation: - Loss: 1.6617 - tr_loss: 0.1443 - tcl_loss: 0.2476 - sin_loss: 0.0111 - cos_loss: 0.0763 - radii_loss: 1.1825
# Validation: - Loss: 1.2115 - tr_loss: 0.2069 - tcl_loss: 0.3197 - sin_loss: 0.0363 - cos_loss: 0.2229 - radii_loss: 0.4256
# Validation Loss: 1.8099308904012044
# Epoch: 14 : LR = 0.0001
# (0 / 314) - Loss: 1.8444 - tr_loss: 0.1395 - tcl_loss: 0.2736 - sin_loss: 0.0251 - cos_loss: 0.0316 - radii_loss: 1.3746
# (50 / 314) - Loss: 0.7918 - tr_loss: 0.1473 - tcl_loss: 0.3135 - sin_loss: 0.0199 - cos_loss: 0.0275 - radii_loss: 0.2836
# (100 / 314) - Loss: 0.9715 - tr_loss: 0.1402 - tcl_loss: 0.2293 - sin_loss: 0.0172 - cos_loss: 0.1043 - radii_loss: 0.4805
# (150 / 314) - Loss: 1.5727 - tr_loss: 0.3075 - tcl_loss: 0.3037 - sin_loss: 0.0302 - cos_loss: 0.2347 - radii_loss: 0.6965
# (200 / 314) - Loss: 1.3682 - tr_loss: 0.1720 - tcl_loss: 0.2398 - sin_loss: 0.0193 - cos_loss: 0.1516 - radii_loss: 0.7855
# (250 / 314) - Loss: 1.3178 - tr_loss: 0.2300 - tcl_loss: 0.2794 - sin_loss: 0.0158 - cos_loss: 0.0333 - radii_loss: 0.7594
# (300 / 314) - Loss: 2.0028 - tr_loss: 0.2339 - tcl_loss: 0.3820 - sin_loss: 0.0259 - cos_loss: 0.0781 - radii_loss: 1.2830
# Training Loss: 1.4883217254451886
# Validation: - Loss: 1.6275 - tr_loss: 0.1319 - tcl_loss: 0.2251 - sin_loss: 0.0136 - cos_loss: 0.0768 - radii_loss: 1.1800
# Validation: - Loss: 1.1761 - tr_loss: 0.1986 - tcl_loss: 0.3017 - sin_loss: 0.0247 - cos_loss: 0.2276 - radii_loss: 0.4236
# Validation Loss: 1.796993727684021
# Epoch: 15 : LR = 0.0001
# (0 / 314) - Loss: 1.5123 - tr_loss: 0.2844 - tcl_loss: 0.3365 - sin_loss: 0.0319 - cos_loss: 0.0976 - radii_loss: 0.7621
# (50 / 314) - Loss: 1.8625 - tr_loss: 0.2189 - tcl_loss: 0.2429 - sin_loss: 0.0234 - cos_loss: 0.0789 - radii_loss: 1.2984
# (100 / 314) - Loss: 1.0538 - tr_loss: 0.1711 - tcl_loss: 0.2780 - sin_loss: 0.0380 - cos_loss: 0.1857 - radii_loss: 0.3811
# (150 / 314) - Loss: 0.7588 - tr_loss: 0.2350 - tcl_loss: 0.2453 - sin_loss: 0.0204 - cos_loss: 0.0377 - radii_loss: 0.2204
# (200 / 314) - Loss: 2.1830 - tr_loss: 0.2499 - tcl_loss: 0.4599 - sin_loss: 0.0458 - cos_loss: 0.0130 - radii_loss: 1.4144
# (250 / 314) - Loss: 1.7058 - tr_loss: 0.2044 - tcl_loss: 0.3517 - sin_loss: 0.0273 - cos_loss: 0.0745 - radii_loss: 1.0479
# (300 / 314) - Loss: 1.5580 - tr_loss: 0.1763 - tcl_loss: 0.3537 - sin_loss: 0.0126 - cos_loss: 0.1342 - radii_loss: 0.8813
# Training Loss: 1.5043367658071458
# Validation: - Loss: 1.6577 - tr_loss: 0.1524 - tcl_loss: 0.2218 - sin_loss: 0.0242 - cos_loss: 0.0774 - radii_loss: 1.1819
# Validation: - Loss: 1.1806 - tr_loss: 0.2042 - tcl_loss: 0.2920 - sin_loss: 0.0422 - cos_loss: 0.2169 - radii_loss: 0.4253
# Validation Loss: 1.8058087158203124
# Epoch: 16 : LR = 0.0001
# (0 / 314) - Loss: 1.2931 - tr_loss: 0.1983 - tcl_loss: 0.3141 - sin_loss: 0.0411 - cos_loss: 0.1631 - radii_loss: 0.5765
# (50 / 314) - Loss: 1.3429 - tr_loss: 0.2402 - tcl_loss: 0.2603 - sin_loss: 0.0356 - cos_loss: 0.0834 - radii_loss: 0.7234
# (100 / 314) - Loss: 1.3670 - tr_loss: 0.2472 - tcl_loss: 0.3545 - sin_loss: 0.0228 - cos_loss: 0.1617 - radii_loss: 0.5808
# (150 / 314) - Loss: 1.2045 - tr_loss: 0.2854 - tcl_loss: 0.3361 - sin_loss: 0.0366 - cos_loss: 0.2378 - radii_loss: 0.3088
# (200 / 314) - Loss: 1.2227 - tr_loss: 0.3739 - tcl_loss: 0.3011 - sin_loss: 0.0189 - cos_loss: 0.0792 - radii_loss: 0.4497
# (250 / 314) - Loss: 0.8063 - tr_loss: 0.2102 - tcl_loss: 0.3326 - sin_loss: 0.0297 - cos_loss: 0.1186 - radii_loss: 0.1152
# (300 / 314) - Loss: 0.7607 - tr_loss: 0.1379 - tcl_loss: 0.2588 - sin_loss: 0.0320 - cos_loss: 0.0549 - radii_loss: 0.2773
# Training Loss: 1.4573726672085987
# Validation: - Loss: 1.6436 - tr_loss: 0.1434 - tcl_loss: 0.2261 - sin_loss: 0.0168 - cos_loss: 0.0756 - radii_loss: 1.1817
# Validation: - Loss: 1.2371 - tr_loss: 0.2427 - tcl_loss: 0.3127 - sin_loss: 0.0250 - cos_loss: 0.2297 - radii_loss: 0.4270
# Validation Loss: 1.7981421216328939
# Epoch: 17 : LR = 0.0001
# (0 / 314) - Loss: 1.0450 - tr_loss: 0.2474 - tcl_loss: 0.3411 - sin_loss: 0.1006 - cos_loss: 0.0542 - radii_loss: 0.3017
# (50 / 314) - Loss: 0.7348 - tr_loss: 0.2275 - tcl_loss: 0.3348 - sin_loss: 0.0723 - cos_loss: 0.0393 - radii_loss: 0.0609
# (100 / 314) - Loss: 1.0934 - tr_loss: 0.1605 - tcl_loss: 0.2560 - sin_loss: 0.0180 - cos_loss: 0.0885 - radii_loss: 0.5704
# (150 / 314) - Loss: 1.2667 - tr_loss: 0.1610 - tcl_loss: 0.2650 - sin_loss: 0.0155 - cos_loss: 0.0734 - radii_loss: 0.7518
# (200 / 314) - Loss: 1.8974 - tr_loss: 0.2681 - tcl_loss: 0.3728 - sin_loss: 0.0924 - cos_loss: 0.1144 - radii_loss: 1.0497
# (250 / 314) - Loss: 2.0777 - tr_loss: 0.1874 - tcl_loss: 0.3652 - sin_loss: 0.0284 - cos_loss: 0.0244 - radii_loss: 1.4723
# (300 / 314) - Loss: 1.1736 - tr_loss: 0.1689 - tcl_loss: 0.2303 - sin_loss: 0.0227 - cos_loss: 0.0329 - radii_loss: 0.7188
# Training Loss: 1.4117506018299966
# Validation: - Loss: 1.7846 - tr_loss: 0.2800 - tcl_loss: 0.2264 - sin_loss: 0.0208 - cos_loss: 0.0757 - radii_loss: 1.1818
# Validation: - Loss: 1.3529 - tr_loss: 0.3319 - tcl_loss: 0.3205 - sin_loss: 0.0483 - cos_loss: 0.2248 - radii_loss: 0.4274
# Validation Loss: 1.8724909655253092
# Epoch: 18 : LR = 0.0001
# (0 / 314) - Loss: 1.6651 - tr_loss: 0.2593 - tcl_loss: 0.2678 - sin_loss: 0.0180 - cos_loss: 0.0540 - radii_loss: 1.0660
# (50 / 314) - Loss: 1.4192 - tr_loss: 0.1173 - tcl_loss: 0.2764 - sin_loss: 0.0184 - cos_loss: 0.0497 - radii_loss: 0.9574
# (100 / 314) - Loss: 2.3080 - tr_loss: 0.2487 - tcl_loss: 0.4084 - sin_loss: 0.1417 - cos_loss: 0.0927 - radii_loss: 1.4166
# (150 / 314) - Loss: 1.7432 - tr_loss: 0.2942 - tcl_loss: 0.2996 - sin_loss: 0.0207 - cos_loss: 0.0982 - radii_loss: 1.0305
# (200 / 314) - Loss: 1.5841 - tr_loss: 0.2200 - tcl_loss: 0.3263 - sin_loss: 0.0568 - cos_loss: 0.0989 - radii_loss: 0.8822
# (250 / 314) - Loss: 0.7676 - tr_loss: 0.2311 - tcl_loss: 0.3067 - sin_loss: 0.0752 - cos_loss: 0.1208 - radii_loss: 0.0338
# (300 / 314) - Loss: 1.4008 - tr_loss: 0.1721 - tcl_loss: 0.2802 - sin_loss: 0.0655 - cos_loss: 0.0566 - radii_loss: 0.8265
# Training Loss: 1.4243716012900043
# Validation: - Loss: 1.6347 - tr_loss: 0.1541 - tcl_loss: 0.2053 - sin_loss: 0.0165 - cos_loss: 0.0787 - radii_loss: 1.1801
# Validation: - Loss: 1.1627 - tr_loss: 0.1931 - tcl_loss: 0.2924 - sin_loss: 0.0337 - cos_loss: 0.2182 - radii_loss: 0.4254
# Validation Loss: 1.7798857990900676
# Epoch: 19 : LR = 0.0001
# (0 / 314) - Loss: 0.8321 - tr_loss: 0.1370 - tcl_loss: 0.2338 - sin_loss: 0.0208 - cos_loss: 0.1059 - radii_loss: 0.3346
# (50 / 314) - Loss: 1.7603 - tr_loss: 0.1841 - tcl_loss: 0.3333 - sin_loss: 0.0251 - cos_loss: 0.1567 - radii_loss: 1.0612
# (100 / 314) - Loss: 1.2572 - tr_loss: 0.2136 - tcl_loss: 0.3158 - sin_loss: 0.0508 - cos_loss: 0.2548 - radii_loss: 0.4223
# (150 / 314) - Loss: 0.9751 - tr_loss: 0.1471 - tcl_loss: 0.2369 - sin_loss: 0.0143 - cos_loss: 0.0321 - radii_loss: 0.5447
# (200 / 314) - Loss: 1.4058 - tr_loss: 0.1695 - tcl_loss: 0.2499 - sin_loss: 0.0101 - cos_loss: 0.0249 - radii_loss: 0.9514
# (250 / 314) - Loss: 0.9620 - tr_loss: 0.1888 - tcl_loss: 0.3316 - sin_loss: 0.0356 - cos_loss: 0.1261 - radii_loss: 0.2800
# (300 / 314) - Loss: 1.7021 - tr_loss: 0.3062 - tcl_loss: 0.4373 - sin_loss: 0.0452 - cos_loss: 0.1689 - radii_loss: 0.7445
# Training Loss: 1.4381968376173335
# Validation: - Loss: 1.6327 - tr_loss: 0.1419 - tcl_loss: 0.2183 - sin_loss: 0.0140 - cos_loss: 0.0766 - radii_loss: 1.1819
# Validation: - Loss: 1.2034 - tr_loss: 0.2223 - tcl_loss: 0.3094 - sin_loss: 0.0263 - cos_loss: 0.2206 - radii_loss: 0.4248
# Validation Loss: 1.7788393306732178
# Epoch: 20 : LR = 0.0001
# (0 / 314) - Loss: 0.9705 - tr_loss: 0.2780 - tcl_loss: 0.3701 - sin_loss: 0.0923 - cos_loss: 0.1330 - radii_loss: 0.0971
# (50 / 314) - Loss: 2.0535 - tr_loss: 0.5829 - tcl_loss: 0.3778 - sin_loss: 0.0935 - cos_loss: 0.0737 - radii_loss: 0.9256
# (100 / 314) - Loss: 0.8531 - tr_loss: 0.3410 - tcl_loss: 0.2950 - sin_loss: 0.0266 - cos_loss: 0.0473 - radii_loss: 0.1431
# (150 / 314) - Loss: 0.6783 - tr_loss: 0.1697 - tcl_loss: 0.3211 - sin_loss: 0.0185 - cos_loss: 0.0883 - radii_loss: 0.0807
# (200 / 314) - Loss: 1.1733 - tr_loss: 0.1272 - tcl_loss: 0.2630 - sin_loss: 0.0177 - cos_loss: 0.0724 - radii_loss: 0.6931
# (250 / 314) - Loss: 1.6251 - tr_loss: 0.2502 - tcl_loss: 0.2544 - sin_loss: 0.0264 - cos_loss: 0.3158 - radii_loss: 0.7782
# (300 / 314) - Loss: 1.4453 - tr_loss: 0.2496 - tcl_loss: 0.2939 - sin_loss: 0.0162 - cos_loss: 0.1098 - radii_loss: 0.7758
# Training Loss: 1.397205181087658
# Validation: - Loss: 1.6292 - tr_loss: 0.1340 - tcl_loss: 0.2189 - sin_loss: 0.0189 - cos_loss: 0.0777 - radii_loss: 1.1796
# Validation: - Loss: 1.2628 - tr_loss: 0.2753 - tcl_loss: 0.2942 - sin_loss: 0.0378 - cos_loss: 0.2297 - radii_loss: 0.4258
# Validation Loss: 1.799907553990682
# Epoch: 21 : LR = 0.0001
# (0 / 314) - Loss: 1.8191 - tr_loss: 0.1894 - tcl_loss: 0.3425 - sin_loss: 0.0325 - cos_loss: 0.1836 - radii_loss: 1.0712
# (50 / 314) - Loss: 1.1669 - tr_loss: 0.1414 - tcl_loss: 0.2640 - sin_loss: 0.0112 - cos_loss: 0.2004 - radii_loss: 0.5498
# (100 / 314) - Loss: 1.7097 - tr_loss: 0.2002 - tcl_loss: 0.2508 - sin_loss: 0.0208 - cos_loss: 0.0884 - radii_loss: 1.1495
# (150 / 314) - Loss: 1.7424 - tr_loss: 0.2432 - tcl_loss: 0.2744 - sin_loss: 0.0549 - cos_loss: 0.0535 - radii_loss: 1.1164
# (200 / 314) - Loss: 1.3123 - tr_loss: 0.3934 - tcl_loss: 0.3444 - sin_loss: 0.1457 - cos_loss: 0.1047 - radii_loss: 0.3240
# (250 / 314) - Loss: 1.5774 - tr_loss: 0.2469 - tcl_loss: 0.3450 - sin_loss: 0.0665 - cos_loss: 0.2142 - radii_loss: 0.7047
# (300 / 314) - Loss: 0.8527 - tr_loss: 0.2813 - tcl_loss: 0.2892 - sin_loss: 0.0195 - cos_loss: 0.0250 - radii_loss: 0.2377
# Training Loss: 1.361719789778351
# Validation: - Loss: 1.5976 - tr_loss: 0.1166 - tcl_loss: 0.2099 - sin_loss: 0.0121 - cos_loss: 0.0763 - radii_loss: 1.1827
# Validation: - Loss: 1.2151 - tr_loss: 0.2359 - tcl_loss: 0.3148 - sin_loss: 0.0219 - cos_loss: 0.2175 - radii_loss: 0.4250
# Validation Loss: 1.7629981660842895
# Epoch: 22 : LR = 0.0001
# (0 / 314) - Loss: 1.4133 - tr_loss: 0.3209 - tcl_loss: 0.3675 - sin_loss: 0.0805 - cos_loss: 0.1020 - radii_loss: 0.5425
# (50 / 314) - Loss: 1.5055 - tr_loss: 0.1743 - tcl_loss: 0.2902 - sin_loss: 0.0149 - cos_loss: 0.2779 - radii_loss: 0.7481
# (100 / 314) - Loss: 2.4633 - tr_loss: 0.2155 - tcl_loss: 0.7006 - sin_loss: 0.2403 - cos_loss: 0.0502 - radii_loss: 1.2567
# (150 / 314) - Loss: 1.0133 - tr_loss: 0.1662 - tcl_loss: 0.2401 - sin_loss: 0.0180 - cos_loss: 0.0363 - radii_loss: 0.5526
# (200 / 314) - Loss: 1.8239 - tr_loss: 0.3290 - tcl_loss: 0.3647 - sin_loss: 0.0449 - cos_loss: 0.0908 - radii_loss: 0.9946
# (250 / 314) - Loss: 1.4155 - tr_loss: 0.1333 - tcl_loss: 0.2629 - sin_loss: 0.0310 - cos_loss: 0.1433 - radii_loss: 0.8450
# (300 / 314) - Loss: 2.3262 - tr_loss: 0.3715 - tcl_loss: 0.4272 - sin_loss: 0.1217 - cos_loss: 0.1276 - radii_loss: 1.2782
# Training Loss: 1.4541941421806432
# Validation: - Loss: 1.6311 - tr_loss: 0.1332 - tcl_loss: 0.2113 - sin_loss: 0.0288 - cos_loss: 0.0753 - radii_loss: 1.1825
# Validation: - Loss: 1.2288 - tr_loss: 0.2540 - tcl_loss: 0.3011 - sin_loss: 0.0274 - cos_loss: 0.2209 - radii_loss: 0.4253
# Validation Loss: 1.7973250818252564
# Epoch: 23 : LR = 0.0001
# (0 / 314) - Loss: 1.4527 - tr_loss: 0.2007 - tcl_loss: 0.2508 - sin_loss: 0.0447 - cos_loss: 0.0545 - radii_loss: 0.9020
# (50 / 314) - Loss: 1.5922 - tr_loss: 0.2931 - tcl_loss: 0.3395 - sin_loss: 0.0452 - cos_loss: 0.1618 - radii_loss: 0.7525
# (100 / 314) - Loss: 0.8092 - tr_loss: 0.1589 - tcl_loss: 0.2830 - sin_loss: 0.0195 - cos_loss: 0.0928 - radii_loss: 0.2550
# (150 / 314) - Loss: 1.8998 - tr_loss: 0.1673 - tcl_loss: 0.3211 - sin_loss: 0.0592 - cos_loss: 0.0796 - radii_loss: 1.2726
# (200 / 314) - Loss: 0.9536 - tr_loss: 0.1483 - tcl_loss: 0.2627 - sin_loss: 0.0168 - cos_loss: 0.0726 - radii_loss: 0.4532
# (250 / 314) - Loss: 2.1779 - tr_loss: 0.2696 - tcl_loss: 0.3966 - sin_loss: 0.1471 - cos_loss: 0.1458 - radii_loss: 1.2187
# (300 / 314) - Loss: 1.9114 - tr_loss: 0.2818 - tcl_loss: 0.3607 - sin_loss: 0.0372 - cos_loss: 0.2131 - radii_loss: 1.0186
# Training Loss: 1.3482089374855066
# Validation: - Loss: 1.6358 - tr_loss: 0.1452 - tcl_loss: 0.2185 - sin_loss: 0.0144 - cos_loss: 0.0761 - radii_loss: 1.1817
# Validation: - Loss: 1.1734 - tr_loss: 0.2031 - tcl_loss: 0.2991 - sin_loss: 0.0205 - cos_loss: 0.2273 - radii_loss: 0.4234
# Validation Loss: 1.772325078646342
# Epoch: 24 : LR = 0.0001
# (0 / 314) - Loss: 1.6055 - tr_loss: 0.2191 - tcl_loss: 0.3288 - sin_loss: 0.0359 - cos_loss: 0.0301 - radii_loss: 0.9915
# (50 / 314) - Loss: 0.9222 - tr_loss: 0.1683 - tcl_loss: 0.3005 - sin_loss: 0.0183 - cos_loss: 0.0908 - radii_loss: 0.3444
# (100 / 314) - Loss: 1.6762 - tr_loss: 0.3489 - tcl_loss: 0.4526 - sin_loss: 0.0548 - cos_loss: 0.2236 - radii_loss: 0.5963
# (150 / 314) - Loss: 1.2766 - tr_loss: 0.2012 - tcl_loss: 0.2796 - sin_loss: 0.0182 - cos_loss: 0.0306 - radii_loss: 0.7469
# (200 / 314) - Loss: 0.8116 - tr_loss: 0.2504 - tcl_loss: 0.3197 - sin_loss: 0.0661 - cos_loss: 0.0621 - radii_loss: 0.1133
# (250 / 314) - Loss: 1.8609 - tr_loss: 0.1462 - tcl_loss: 0.2571 - sin_loss: 0.0372 - cos_loss: 0.0321 - radii_loss: 1.3883
# (300 / 314) - Loss: 1.3589 - tr_loss: 0.2509 - tcl_loss: 0.3229 - sin_loss: 0.0424 - cos_loss: 0.0763 - radii_loss: 0.6664
# Training Loss: 1.3705660934281196
# Validation: - Loss: 1.6205 - tr_loss: 0.1147 - tcl_loss: 0.2356 - sin_loss: 0.0128 - cos_loss: 0.0750 - radii_loss: 1.1824
# Validation: - Loss: 1.1589 - tr_loss: 0.1800 - tcl_loss: 0.3055 - sin_loss: 0.0209 - cos_loss: 0.2332 - radii_loss: 0.4194
# Validation Loss: 1.801065486272176
# Epoch: 25 : LR = 0.0001
# (0 / 314) - Loss: 1.0707 - tr_loss: 0.3094 - tcl_loss: 0.3131 - sin_loss: 0.0202 - cos_loss: 0.0654 - radii_loss: 0.3625
# (50 / 314) - Loss: 1.6144 - tr_loss: 0.2141 - tcl_loss: 0.3376 - sin_loss: 0.0283 - cos_loss: 0.0970 - radii_loss: 0.9375
# (100 / 314) - Loss: 2.2175 - tr_loss: 0.4403 - tcl_loss: 0.3047 - sin_loss: 0.0441 - cos_loss: 0.1368 - radii_loss: 1.2916
# (150 / 314) - Loss: 1.2177 - tr_loss: 0.2136 - tcl_loss: 0.2780 - sin_loss: 0.0354 - cos_loss: 0.1738 - radii_loss: 0.5168
# (200 / 314) - Loss: 1.6996 - tr_loss: 0.1238 - tcl_loss: 0.2259 - sin_loss: 0.0078 - cos_loss: 0.1673 - radii_loss: 1.1748
# (250 / 314) - Loss: 0.9683 - tr_loss: 0.2418 - tcl_loss: 0.3687 - sin_loss: 0.0317 - cos_loss: 0.0405 - radii_loss: 0.2857
# (300 / 314) - Loss: 1.2237 - tr_loss: 0.2653 - tcl_loss: 0.3522 - sin_loss: 0.0191 - cos_loss: 0.1871 - radii_loss: 0.3999
# Training Loss: 1.4067069077567689
# Validation: - Loss: 1.5842 - tr_loss: 0.1006 - tcl_loss: 0.2135 - sin_loss: 0.0126 - cos_loss: 0.0750 - radii_loss: 1.1825
# Validation: - Loss: 1.1466 - tr_loss: 0.1958 - tcl_loss: 0.2846 - sin_loss: 0.0174 - cos_loss: 0.2233 - radii_loss: 0.4255
# Validation Loss: 1.7716835657755534
# Epoch: 26 : LR = 0.0001
# (0 / 314) - Loss: 1.9168 - tr_loss: 0.1624 - tcl_loss: 0.2758 - sin_loss: 0.0234 - cos_loss: 0.0717 - radii_loss: 1.3834
# (50 / 314) - Loss: 1.0349 - tr_loss: 0.1702 - tcl_loss: 0.2963 - sin_loss: 0.0135 - cos_loss: 0.1371 - radii_loss: 0.4179
# (100 / 314) - Loss: 0.8125 - tr_loss: 0.1925 - tcl_loss: 0.3196 - sin_loss: 0.0492 - cos_loss: 0.0998 - radii_loss: 0.1514
# (150 / 314) - Loss: 1.7599 - tr_loss: 0.1375 - tcl_loss: 0.2442 - sin_loss: 0.0087 - cos_loss: 0.0860 - radii_loss: 1.2835
# (200 / 314) - Loss: 1.6801 - tr_loss: 0.3694 - tcl_loss: 0.2882 - sin_loss: 0.0168 - cos_loss: 0.0976 - radii_loss: 0.9081
# (250 / 314) - Loss: 1.4588 - tr_loss: 0.2429 - tcl_loss: 0.3451 - sin_loss: 0.0144 - cos_loss: 0.0917 - radii_loss: 0.7647
# (300 / 314) - Loss: 1.5276 - tr_loss: 0.1730 - tcl_loss: 0.2584 - sin_loss: 0.0164 - cos_loss: 0.0670 - radii_loss: 1.0128
# Training Loss: 1.347712166559924
# Validation: - Loss: 1.6514 - tr_loss: 0.1262 - tcl_loss: 0.2523 - sin_loss: 0.0143 - cos_loss: 0.0760 - radii_loss: 1.1827
# Validation: - Loss: 1.2371 - tr_loss: 0.2634 - tcl_loss: 0.3119 - sin_loss: 0.0172 - cos_loss: 0.2194 - radii_loss: 0.4252
# Validation Loss: 1.8210164324442546
# Epoch: 27 : LR = 0.0001
# (0 / 314) - Loss: 1.1160 - tr_loss: 0.2446 - tcl_loss: 0.2631 - sin_loss: 0.0173 - cos_loss: 0.1082 - radii_loss: 0.4829
# (50 / 314) - Loss: 0.7558 - tr_loss: 0.1821 - tcl_loss: 0.2727 - sin_loss: 0.0407 - cos_loss: 0.1680 - radii_loss: 0.0923
# (100 / 314) - Loss: 2.2191 - tr_loss: 0.4504 - tcl_loss: 0.4401 - sin_loss: 0.0812 - cos_loss: 0.1967 - radii_loss: 1.0507
# (150 / 314) - Loss: 0.9066 - tr_loss: 0.2059 - tcl_loss: 0.4601 - sin_loss: 0.0198 - cos_loss: 0.0781 - radii_loss: 0.1428
# (200 / 314) - Loss: 1.3230 - tr_loss: 0.1616 - tcl_loss: 0.2527 - sin_loss: 0.0237 - cos_loss: 0.0582 - radii_loss: 0.8268
# (250 / 314) - Loss: 1.4446 - tr_loss: 0.1653 - tcl_loss: 0.3839 - sin_loss: 0.0365 - cos_loss: 0.1182 - radii_loss: 0.7406
# (300 / 314) - Loss: 0.9889 - tr_loss: 0.2258 - tcl_loss: 0.3029 - sin_loss: 0.0342 - cos_loss: 0.2286 - radii_loss: 0.1974
# Training Loss: 1.3849775092616963
# Validation: - Loss: 1.5911 - tr_loss: 0.1095 - tcl_loss: 0.2109 - sin_loss: 0.0142 - cos_loss: 0.0739 - radii_loss: 1.1825
# Validation: - Loss: 1.1721 - tr_loss: 0.1959 - tcl_loss: 0.3011 - sin_loss: 0.0258 - cos_loss: 0.2263 - radii_loss: 0.4229
# Validation Loss: 1.7655186605453492
# Epoch: 28 : LR = 0.0001
# (0 / 314) - Loss: 1.9400 - tr_loss: 0.2201 - tcl_loss: 0.3299 - sin_loss: 0.0214 - cos_loss: 0.1335 - radii_loss: 1.2350
# (50 / 314) - Loss: 1.1314 - tr_loss: 0.2794 - tcl_loss: 0.3435 - sin_loss: 0.0216 - cos_loss: 0.1337 - radii_loss: 0.3532
# (100 / 314) - Loss: 0.6955 - tr_loss: 0.2208 - tcl_loss: 0.2561 - sin_loss: 0.0207 - cos_loss: 0.1485 - radii_loss: 0.0495
# (150 / 314) - Loss: 0.9451 - tr_loss: 0.2343 - tcl_loss: 0.2860 - sin_loss: 0.0375 - cos_loss: 0.0679 - radii_loss: 0.3194
# (200 / 314) - Loss: 1.4089 - tr_loss: 0.2370 - tcl_loss: 0.4345 - sin_loss: 0.0773 - cos_loss: 0.0911 - radii_loss: 0.5691
# (250 / 314) - Loss: 1.2652 - tr_loss: 0.1747 - tcl_loss: 0.3007 - sin_loss: 0.0413 - cos_loss: 0.0934 - radii_loss: 0.6551
# (300 / 314) - Loss: 1.3368 - tr_loss: 0.2519 - tcl_loss: 0.3831 - sin_loss: 0.0758 - cos_loss: 0.2166 - radii_loss: 0.4094
# Training Loss: 1.4080734510140813
# Validation: - Loss: 1.6052 - tr_loss: 0.1163 - tcl_loss: 0.2230 - sin_loss: 0.0090 - cos_loss: 0.0822 - radii_loss: 1.1747
# Validation: - Loss: 1.2962 - tr_loss: 0.3491 - tcl_loss: 0.3797 - sin_loss: 0.0254 - cos_loss: 0.2767 - radii_loss: 0.2653
# Validation Loss: 1.7864276933670045
# Epoch: 29 : LR = 0.0001
# (0 / 314) - Loss: 1.7145 - tr_loss: 0.1856 - tcl_loss: 0.2954 - sin_loss: 0.0257 - cos_loss: 0.1775 - radii_loss: 1.0304
# (50 / 314) - Loss: 1.9387 - tr_loss: 0.2941 - tcl_loss: 0.4057 - sin_loss: 0.1541 - cos_loss: 0.2144 - radii_loss: 0.8704
# (100 / 314) - Loss: 1.4700 - tr_loss: 0.2813 - tcl_loss: 0.3824 - sin_loss: 0.0408 - cos_loss: 0.1646 - radii_loss: 0.6009
# (150 / 314) - Loss: 2.2014 - tr_loss: 0.5130 - tcl_loss: 0.4202 - sin_loss: 0.0363 - cos_loss: 0.3934 - radii_loss: 0.8385
# (200 / 314) - Loss: 1.7084 - tr_loss: 0.3110 - tcl_loss: 0.3464 - sin_loss: 0.0825 - cos_loss: 0.0911 - radii_loss: 0.8773
# (250 / 314) - Loss: 1.6907 - tr_loss: 0.2665 - tcl_loss: 0.3713 - sin_loss: 0.0334 - cos_loss: 0.1777 - radii_loss: 0.8417
# (300 / 314) - Loss: 1.5420 - tr_loss: 0.2475 - tcl_loss: 0.2930 - sin_loss: 0.0176 - cos_loss: 0.0656 - radii_loss: 0.9182
# Training Loss: 1.4090707331516181
# Validation: - Loss: 1.6510 - tr_loss: 0.1603 - tcl_loss: 0.2183 - sin_loss: 0.0176 - cos_loss: 0.0748 - radii_loss: 1.1800
# Validation: - Loss: 1.1618 - tr_loss: 0.1868 - tcl_loss: 0.3041 - sin_loss: 0.0323 - cos_loss: 0.2431 - radii_loss: 0.3955
# Validation Loss: 1.754468264579773
# Epoch: 30 : LR = 0.0001
# (0 / 314) - Loss: 1.0858 - tr_loss: 0.3283 - tcl_loss: 0.3625 - sin_loss: 0.0123 - cos_loss: 0.2022 - radii_loss: 0.1805
# (50 / 314) - Loss: 1.4970 - tr_loss: 0.2837 - tcl_loss: 0.3858 - sin_loss: 0.0205 - cos_loss: 0.2357 - radii_loss: 0.5714
# (100 / 314) - Loss: 1.4577 - tr_loss: 0.1816 - tcl_loss: 0.2663 - sin_loss: 0.0107 - cos_loss: 0.1738 - radii_loss: 0.8253
# (150 / 314) - Loss: 1.4085 - tr_loss: 0.3118 - tcl_loss: 0.3303 - sin_loss: 0.0308 - cos_loss: 0.1068 - radii_loss: 0.6288
# (200 / 314) - Loss: 0.8239 - tr_loss: 0.2105 - tcl_loss: 0.2681 - sin_loss: 0.0241 - cos_loss: 0.1196 - radii_loss: 0.2016
# (250 / 314) - Loss: 1.1462 - tr_loss: 0.2126 - tcl_loss: 0.3144 - sin_loss: 0.0148 - cos_loss: 0.1388 - radii_loss: 0.4656
# (300 / 314) - Loss: 1.5150 - tr_loss: 0.2129 - tcl_loss: 0.2263 - sin_loss: 0.0133 - cos_loss: 0.0719 - radii_loss: 0.9905
# Training Loss: 1.4056221509625197
# Validation: - Loss: 1.6093 - tr_loss: 0.1236 - tcl_loss: 0.2181 - sin_loss: 0.0122 - cos_loss: 0.0752 - radii_loss: 1.1801
# Validation: - Loss: 1.1834 - tr_loss: 0.1997 - tcl_loss: 0.3145 - sin_loss: 0.0299 - cos_loss: 0.2485 - radii_loss: 0.3909
# Validation Loss: 1.780193074544271
# Epoch: 31 : LR = 0.0001
# (0 / 314) - Loss: 1.0746 - tr_loss: 0.2519 - tcl_loss: 0.2777 - sin_loss: 0.0180 - cos_loss: 0.1608 - radii_loss: 0.3662
# (50 / 314) - Loss: 1.7122 - tr_loss: 0.4769 - tcl_loss: 0.4335 - sin_loss: 0.0813 - cos_loss: 0.3210 - radii_loss: 0.3994
# (100 / 314) - Loss: 1.0142 - tr_loss: 0.1568 - tcl_loss: 0.2784 - sin_loss: 0.0111 - cos_loss: 0.0875 - radii_loss: 0.4804
# (150 / 314) - Loss: 1.0716 - tr_loss: 0.1936 - tcl_loss: 0.2778 - sin_loss: 0.0247 - cos_loss: 0.0415 - radii_loss: 0.5339
# (200 / 314) - Loss: 1.7615 - tr_loss: 0.2620 - tcl_loss: 0.3290 - sin_loss: 0.0369 - cos_loss: 0.1898 - radii_loss: 0.9438
# (250 / 314) - Loss: 1.5510 - tr_loss: 0.3036 - tcl_loss: 0.3683 - sin_loss: 0.0659 - cos_loss: 0.2944 - radii_loss: 0.5188
# (300 / 314) - Loss: 1.0517 - tr_loss: 0.1901 - tcl_loss: 0.2489 - sin_loss: 0.0182 - cos_loss: 0.1122 - radii_loss: 0.4823
# Training Loss: 1.357606194581196
# Validation: - Loss: 1.5943 - tr_loss: 0.1128 - tcl_loss: 0.2056 - sin_loss: 0.0180 - cos_loss: 0.0771 - radii_loss: 1.1808
# Validation: - Loss: 1.1536 - tr_loss: 0.2041 - tcl_loss: 0.2915 - sin_loss: 0.0218 - cos_loss: 0.2281 - radii_loss: 0.4081
# Validation Loss: 1.7367969274520874
# Epoch: 32 : LR = 0.0001
# (0 / 314) - Loss: 1.1147 - tr_loss: 0.1581 - tcl_loss: 0.3226 - sin_loss: 0.0295 - cos_loss: 0.1925 - radii_loss: 0.4120
# (50 / 314) - Loss: 1.8192 - tr_loss: 0.1696 - tcl_loss: 0.3007 - sin_loss: 0.0421 - cos_loss: 0.1046 - radii_loss: 1.2021
# (100 / 314) - Loss: 1.1432 - tr_loss: 0.2902 - tcl_loss: 0.3266 - sin_loss: 0.0247 - cos_loss: 0.0797 - radii_loss: 0.4220
# (150 / 314) - Loss: 1.2370 - tr_loss: 0.1746 - tcl_loss: 0.2537 - sin_loss: 0.0093 - cos_loss: 0.1833 - radii_loss: 0.6161
# (200 / 314) - Loss: 1.3802 - tr_loss: 0.2287 - tcl_loss: 0.3898 - sin_loss: 0.0863 - cos_loss: 0.1707 - radii_loss: 0.5047
# (250 / 314) - Loss: 1.2105 - tr_loss: 0.4085 - tcl_loss: 0.5074 - sin_loss: 0.1069 - cos_loss: 0.1000 - radii_loss: 0.0877
# (300 / 314) - Loss: 0.9896 - tr_loss: 0.1770 - tcl_loss: 0.2984 - sin_loss: 0.0138 - cos_loss: 0.0773 - radii_loss: 0.4231
# Training Loss: 1.3894574898443404
# Validation: - Loss: 1.5758 - tr_loss: 0.1104 - tcl_loss: 0.2023 - sin_loss: 0.0105 - cos_loss: 0.0767 - radii_loss: 1.1759
# Validation: - Loss: 1.1482 - tr_loss: 0.1919 - tcl_loss: 0.2807 - sin_loss: 0.0196 - cos_loss: 0.2413 - radii_loss: 0.4147
# Validation Loss: 1.7090251429875691
# Epoch: 33 : LR = 0.0001
# (0 / 314) - Loss: 1.9221 - tr_loss: 0.2033 - tcl_loss: 0.3193 - sin_loss: 0.0564 - cos_loss: 0.2135 - radii_loss: 1.1295
# (50 / 314) - Loss: 1.2041 - tr_loss: 0.1863 - tcl_loss: 0.2980 - sin_loss: 0.0156 - cos_loss: 0.1819 - radii_loss: 0.5223
# (100 / 314) - Loss: 1.5764 - tr_loss: 0.2100 - tcl_loss: 0.3224 - sin_loss: 0.0378 - cos_loss: 0.0581 - radii_loss: 0.9480
# (150 / 314) - Loss: 2.1298 - tr_loss: 0.8397 - tcl_loss: 0.3460 - sin_loss: 0.0315 - cos_loss: 0.1690 - radii_loss: 0.7437
# (200 / 314) - Loss: 1.9609 - tr_loss: 0.2326 - tcl_loss: 0.3888 - sin_loss: 0.0577 - cos_loss: 0.1696 - radii_loss: 1.1121
# (250 / 314) - Loss: 1.6833 - tr_loss: 0.2112 - tcl_loss: 0.2536 - sin_loss: 0.0174 - cos_loss: 0.1275 - radii_loss: 1.0736
# (300 / 314) - Loss: 1.2684 - tr_loss: 0.1349 - tcl_loss: 0.3364 - sin_loss: 0.0151 - cos_loss: 0.1556 - radii_loss: 0.6263
# Training Loss: 1.4102317618716294
# Validation: - Loss: 1.6402 - tr_loss: 0.1312 - tcl_loss: 0.2298 - sin_loss: 0.0193 - cos_loss: 0.0774 - radii_loss: 1.1825
# Validation: - Loss: 1.1726 - tr_loss: 0.2188 - tcl_loss: 0.2962 - sin_loss: 0.0244 - cos_loss: 0.2163 - radii_loss: 0.4170
# Validation Loss: 1.7410850048065185
# Epoch: 34 : LR = 0.0001
# (0 / 314) - Loss: 1.5602 - tr_loss: 0.2639 - tcl_loss: 0.2904 - sin_loss: 0.0288 - cos_loss: 0.0750 - radii_loss: 0.9022
# (50 / 314) - Loss: 0.6692 - tr_loss: 0.1712 - tcl_loss: 0.3121 - sin_loss: 0.0087 - cos_loss: 0.0962 - radii_loss: 0.0810
# (100 / 314) - Loss: 1.1074 - tr_loss: 0.1804 - tcl_loss: 0.2865 - sin_loss: 0.0413 - cos_loss: 0.0711 - radii_loss: 0.5281
# (150 / 314) - Loss: 1.8462 - tr_loss: 0.3072 - tcl_loss: 0.2918 - sin_loss: 0.0659 - cos_loss: 0.0662 - radii_loss: 1.1150
# (200 / 314) - Loss: 1.8743 - tr_loss: 0.2103 - tcl_loss: 0.4011 - sin_loss: 0.2340 - cos_loss: 0.0961 - radii_loss: 0.9329
# (250 / 314) - Loss: 1.1349 - tr_loss: 0.2894 - tcl_loss: 0.3175 - sin_loss: 0.0239 - cos_loss: 0.0730 - radii_loss: 0.4311
# (300 / 314) - Loss: 1.3796 - tr_loss: 0.1385 - tcl_loss: 0.3232 - sin_loss: 0.0538 - cos_loss: 0.1609 - radii_loss: 0.7032
# Training Loss: 1.3361644608199976
# Validation: - Loss: 1.5750 - tr_loss: 0.1082 - tcl_loss: 0.2020 - sin_loss: 0.0081 - cos_loss: 0.0754 - radii_loss: 1.1813
# Validation: - Loss: 1.1495 - tr_loss: 0.1963 - tcl_loss: 0.2881 - sin_loss: 0.0340 - cos_loss: 0.2228 - radii_loss: 0.4085
# Validation Loss: 1.7178083086013793
# Epoch: 35 : LR = 0.0001
# (0 / 314) - Loss: 1.5970 - tr_loss: 0.2039 - tcl_loss: 0.3240 - sin_loss: 0.0126 - cos_loss: 0.1131 - radii_loss: 0.9433
# (50 / 314) - Loss: 1.4793 - tr_loss: 0.2854 - tcl_loss: 0.5241 - sin_loss: 0.0750 - cos_loss: 0.2157 - radii_loss: 0.3790
# (100 / 314) - Loss: 1.4091 - tr_loss: 0.1479 - tcl_loss: 0.2706 - sin_loss: 0.0194 - cos_loss: 0.0325 - radii_loss: 0.9388
# (150 / 314) - Loss: 0.7557 - tr_loss: 0.2804 - tcl_loss: 0.2792 - sin_loss: 0.0091 - cos_loss: 0.0870 - radii_loss: 0.1000
# (200 / 314) - Loss: 1.1236 - tr_loss: 0.2456 - tcl_loss: 0.3193 - sin_loss: 0.0338 - cos_loss: 0.0982 - radii_loss: 0.4267
# (250 / 314) - Loss: 1.5550 - tr_loss: 0.2825 - tcl_loss: 0.3960 - sin_loss: 0.0596 - cos_loss: 0.2052 - radii_loss: 0.6117
# (300 / 314) - Loss: 1.4063 - tr_loss: 0.2176 - tcl_loss: 0.4178 - sin_loss: 0.0525 - cos_loss: 0.0979 - radii_loss: 0.6205
# Training Loss: 1.4284730819380207
# Validation: - Loss: 1.6448 - tr_loss: 0.1496 - tcl_loss: 0.2192 - sin_loss: 0.0271 - cos_loss: 0.0803 - radii_loss: 1.1687
# Validation: - Loss: 1.2497 - tr_loss: 0.2542 - tcl_loss: 0.3133 - sin_loss: 0.0387 - cos_loss: 0.2421 - radii_loss: 0.4014
# Validation Loss: 1.7327259111404418
# Epoch: 36 : LR = 0.0001
# (0 / 314) - Loss: 1.4839 - tr_loss: 0.3273 - tcl_loss: 0.3487 - sin_loss: 0.0422 - cos_loss: 0.2104 - radii_loss: 0.5554
# (50 / 314) - Loss: 1.7914 - tr_loss: 0.1949 - tcl_loss: 0.2932 - sin_loss: 0.0197 - cos_loss: 0.0485 - radii_loss: 1.2350
# (100 / 314) - Loss: 1.5405 - tr_loss: 0.2565 - tcl_loss: 0.3622 - sin_loss: 0.0600 - cos_loss: 0.2585 - radii_loss: 0.6033
# (150 / 314) - Loss: 1.2182 - tr_loss: 0.2332 - tcl_loss: 0.3426 - sin_loss: 0.0371 - cos_loss: 0.2372 - radii_loss: 0.3681
# (200 / 314) - Loss: 1.9236 - tr_loss: 0.2556 - tcl_loss: 0.2557 - sin_loss: 0.0183 - cos_loss: 0.2729 - radii_loss: 1.1212
# (250 / 314) - Loss: 0.9458 - tr_loss: 0.2182 - tcl_loss: 0.2805 - sin_loss: 0.0463 - cos_loss: 0.0927 - radii_loss: 0.3080
# (300 / 314) - Loss: 1.6915 - tr_loss: 0.3283 - tcl_loss: 0.2817 - sin_loss: 0.0908 - cos_loss: 0.2353 - radii_loss: 0.7554
# Training Loss: 1.408597981569114
# Validation: - Loss: 1.6042 - tr_loss: 0.1206 - tcl_loss: 0.2125 - sin_loss: 0.0142 - cos_loss: 0.0761 - radii_loss: 1.1808
# Validation: - Loss: 1.1723 - tr_loss: 0.2132 - tcl_loss: 0.3000 - sin_loss: 0.0254 - cos_loss: 0.2207 - radii_loss: 0.4130
# Validation Loss: 1.7084059731165568
# Epoch: 37 : LR = 0.0001
# (0 / 314) - Loss: 1.7234 - tr_loss: 0.2308 - tcl_loss: 0.3259 - sin_loss: 0.0512 - cos_loss: 0.2251 - radii_loss: 0.8904
# (50 / 314) - Loss: 1.6536 - tr_loss: 0.2307 - tcl_loss: 0.3460 - sin_loss: 0.0329 - cos_loss: 0.0920 - radii_loss: 0.9520
# (100 / 314) - Loss: 0.8705 - tr_loss: 0.2105 - tcl_loss: 0.2780 - sin_loss: 0.0320 - cos_loss: 0.0651 - radii_loss: 0.2849
# (150 / 314) - Loss: 0.6683 - tr_loss: 0.1419 - tcl_loss: 0.2830 - sin_loss: 0.0213 - cos_loss: 0.0614 - radii_loss: 0.1607
# (200 / 314) - Loss: 1.3368 - tr_loss: 0.2102 - tcl_loss: 0.3375 - sin_loss: 0.0296 - cos_loss: 0.1569 - radii_loss: 0.6026
# (250 / 314) - Loss: 1.7497 - tr_loss: 0.2018 - tcl_loss: 0.2565 - sin_loss: 0.0414 - cos_loss: 0.0585 - radii_loss: 1.1915
# (300 / 314) - Loss: 1.4358 - tr_loss: 0.1993 - tcl_loss: 0.4174 - sin_loss: 0.0595 - cos_loss: 0.1762 - radii_loss: 0.5835
# Training Loss: 1.3920329978131945
# Validation: - Loss: 1.6066 - tr_loss: 0.1299 - tcl_loss: 0.2073 - sin_loss: 0.0119 - cos_loss: 0.0750 - radii_loss: 1.1825
# Validation: - Loss: 1.1535 - tr_loss: 0.2268 - tcl_loss: 0.2815 - sin_loss: 0.0168 - cos_loss: 0.2244 - radii_loss: 0.4040
# Validation Loss: 1.7220321337381999
# Epoch: 38 : LR = 0.0001
# (0 / 314) - Loss: 1.2539 - tr_loss: 0.1373 - tcl_loss: 0.2007 - sin_loss: 0.0104 - cos_loss: 0.0456 - radii_loss: 0.8599
# (50 / 314) - Loss: 1.0505 - tr_loss: 0.1613 - tcl_loss: 0.2515 - sin_loss: 0.0217 - cos_loss: 0.1277 - radii_loss: 0.4883
# (100 / 314) - Loss: 1.1937 - tr_loss: 0.5351 - tcl_loss: 0.2668 - sin_loss: 0.0519 - cos_loss: 0.0985 - radii_loss: 0.2413
# (150 / 314) - Loss: 1.2394 - tr_loss: 0.3672 - tcl_loss: 0.3077 - sin_loss: 0.0501 - cos_loss: 0.0985 - radii_loss: 0.4159
# (200 / 314) - Loss: 1.3880 - tr_loss: 0.1605 - tcl_loss: 0.2726 - sin_loss: 0.0105 - cos_loss: 0.0533 - radii_loss: 0.8911
# (250 / 314) - Loss: 0.9122 - tr_loss: 0.1972 - tcl_loss: 0.2827 - sin_loss: 0.0146 - cos_loss: 0.1320 - radii_loss: 0.2857
# (300 / 314) - Loss: 1.6442 - tr_loss: 0.3338 - tcl_loss: 0.3404 - sin_loss: 0.0678 - cos_loss: 0.2793 - radii_loss: 0.6229
# Training Loss: 1.3294087935025525
# Validation: - Loss: 1.5835 - tr_loss: 0.1121 - tcl_loss: 0.2045 - sin_loss: 0.0101 - cos_loss: 0.0761 - radii_loss: 1.1807
# Validation: - Loss: 1.1425 - tr_loss: 0.1815 - tcl_loss: 0.3074 - sin_loss: 0.0223 - cos_loss: 0.2316 - radii_loss: 0.3997
# Validation Loss: 1.7056164280573527
# Epoch: 39 : LR = 0.0001
# (0 / 314) - Loss: 1.5837 - tr_loss: 0.1757 - tcl_loss: 0.2563 - sin_loss: 0.0173 - cos_loss: 0.1027 - radii_loss: 1.0317
# (50 / 314) - Loss: 1.1209 - tr_loss: 0.1626 - tcl_loss: 0.2941 - sin_loss: 0.0259 - cos_loss: 0.1294 - radii_loss: 0.5089
# ...
# Training Loss: 0.9426373684672034
# Validation: - Loss: 0.5885 - tr_loss: 0.1004 - tcl_loss: 0.2074 - sin_loss: 0.0116 - cos_loss: 0.0749 - radii_loss: 0.1941
# Validation: - Loss: 1.2377 - tr_loss: 0.1643 - tcl_loss: 0.2884 - sin_loss: 0.0191 - cos_loss: 0.2414 - radii_loss: 0.5244
# Validation Loss: 0.9376830712954203
# Epoch: 188 : LR = 0.0001
# (0 / 314) - Loss: 1.2145 - tr_loss: 0.2824 - tcl_loss: 0.2899 - sin_loss: 0.0291 - cos_loss: 0.1867 - radii_loss: 0.4264
# (50 / 314) - Loss: 0.9750 - tr_loss: 0.1411 - tcl_loss: 0.1925 - sin_loss: 0.0067 - cos_loss: 0.1127 - radii_loss: 0.5222
# (100 / 314) - Loss: 0.5845 - tr_loss: 0.2518 - tcl_loss: 0.2354 - sin_loss: 0.0195 - cos_loss: 0.0425 - radii_loss: 0.0353
# (150 / 314) - Loss: 1.0070 - tr_loss: 0.1160 - tcl_loss: 0.2783 - sin_loss: 0.0175 - cos_loss: 0.0920 - radii_loss: 0.5032
# (200 / 314) - Loss: 1.1363 - tr_loss: 0.1874 - tcl_loss: 0.2955 - sin_loss: 0.0357 - cos_loss: 0.2404 - radii_loss: 0.3774
# (250 / 314) - Loss: 0.6035 - tr_loss: 0.1218 - tcl_loss: 0.2678 - sin_loss: 0.0290 - cos_loss: 0.0466 - radii_loss: 0.1383
# (300 / 314) - Loss: 0.5182 - tr_loss: 0.1153 - tcl_loss: 0.2176 - sin_loss: 0.0108 - cos_loss: 0.0312 - radii_loss: 0.1433
# Training Loss: 0.9385731083572291
# Validation: - Loss: 0.5669 - tr_loss: 0.0998 - tcl_loss: 0.2088 - sin_loss: 0.0099 - cos_loss: 0.0742 - radii_loss: 0.1742
# Validation: - Loss: 1.0231 - tr_loss: 0.1618 - tcl_loss: 0.2814 - sin_loss: 0.0183 - cos_loss: 0.2228 - radii_loss: 0.3387
# Validation Loss: 0.9713027000427246
# Epoch: 189 : LR = 0.0001
# (0 / 314) - Loss: 0.8285 - tr_loss: 0.1789 - tcl_loss: 0.3092 - sin_loss: 0.0167 - cos_loss: 0.0643 - radii_loss: 0.2595
# (50 / 314) - Loss: 0.5634 - tr_loss: 0.1280 - tcl_loss: 0.2255 - sin_loss: 0.0154 - cos_loss: 0.1253 - radii_loss: 0.0692
# (100 / 314) - Loss: 0.4093 - tr_loss: 0.0831 - tcl_loss: 0.2051 - sin_loss: 0.0100 - cos_loss: 0.0656 - radii_loss: 0.0455
# (150 / 314) - Loss: 0.8452 - tr_loss: 0.1559 - tcl_loss: 0.2586 - sin_loss: 0.0126 - cos_loss: 0.0588 - radii_loss: 0.3593
# (200 / 314) - Loss: 1.2264 - tr_loss: 0.2240 - tcl_loss: 0.3079 - sin_loss: 0.0307 - cos_loss: 0.0470 - radii_loss: 0.6167
# (250 / 314) - Loss: 0.5595 - tr_loss: 0.1256 - tcl_loss: 0.2617 - sin_loss: 0.0229 - cos_loss: 0.0638 - radii_loss: 0.0854
# (300 / 314) - Loss: 1.3434 - tr_loss: 0.2331 - tcl_loss: 0.3864 - sin_loss: 0.0922 - cos_loss: 0.0606 - radii_loss: 0.5710
# Training Loss: 0.9217822761482494
# Validation: - Loss: 0.5723 - tr_loss: 0.1011 - tcl_loss: 0.2057 - sin_loss: 0.0110 - cos_loss: 0.0747 - radii_loss: 0.1799
# Validation: - Loss: 1.0939 - tr_loss: 0.1660 - tcl_loss: 0.2859 - sin_loss: 0.0188 - cos_loss: 0.2478 - radii_loss: 0.3754
# Validation Loss: 0.9287326061725616
# Epoch: 190 : LR = 0.0001
# (0 / 314) - Loss: 0.8824 - tr_loss: 0.1646 - tcl_loss: 0.3568 - sin_loss: 0.0274 - cos_loss: 0.1659 - radii_loss: 0.1678
# (50 / 314) - Loss: 0.5321 - tr_loss: 0.1348 - tcl_loss: 0.2056 - sin_loss: 0.0103 - cos_loss: 0.1044 - radii_loss: 0.0770
# (100 / 314) - Loss: 1.2591 - tr_loss: 0.1262 - tcl_loss: 0.2332 - sin_loss: 0.0145 - cos_loss: 0.1279 - radii_loss: 0.7573
# (150 / 314) - Loss: 1.1058 - tr_loss: 0.1451 - tcl_loss: 0.2643 - sin_loss: 0.0256 - cos_loss: 0.0895 - radii_loss: 0.5813
# (200 / 314) - Loss: 0.7214 - tr_loss: 0.1515 - tcl_loss: 0.2370 - sin_loss: 0.0247 - cos_loss: 0.0644 - radii_loss: 0.2438
# (250 / 314) - Loss: 0.7965 - tr_loss: 0.1105 - tcl_loss: 0.2266 - sin_loss: 0.0103 - cos_loss: 0.1047 - radii_loss: 0.3445
# (300 / 314) - Loss: 0.6874 - tr_loss: 0.1798 - tcl_loss: 0.3091 - sin_loss: 0.0248 - cos_loss: 0.0801 - radii_loss: 0.0937
# Training Loss: 0.9246293188660009
# Validation: - Loss: 0.5611 - tr_loss: 0.0977 - tcl_loss: 0.2037 - sin_loss: 0.0092 - cos_loss: 0.0749 - radii_loss: 0.1756
# Validation: - Loss: 1.0021 - tr_loss: 0.1707 - tcl_loss: 0.2822 - sin_loss: 0.0192 - cos_loss: 0.2325 - radii_loss: 0.2976
# Validation Loss: 0.977283373673757
# Epoch: 191 : LR = 0.0001
# (0 / 314) - Loss: 0.9353 - tr_loss: 0.1955 - tcl_loss: 0.3174 - sin_loss: 0.0453 - cos_loss: 0.1390 - radii_loss: 0.2380
# (50 / 314) - Loss: 0.7446 - tr_loss: 0.1667 - tcl_loss: 0.2779 - sin_loss: 0.0174 - cos_loss: 0.0974 - radii_loss: 0.1853
# (100 / 314) - Loss: 0.9580 - tr_loss: 0.1425 - tcl_loss: 0.2253 - sin_loss: 0.0100 - cos_loss: 0.1189 - radii_loss: 0.4612
# (150 / 314) - Loss: 0.7837 - tr_loss: 0.1514 - tcl_loss: 0.2087 - sin_loss: 0.0101 - cos_loss: 0.1507 - radii_loss: 0.2628
# (200 / 314) - Loss: 0.7963 - tr_loss: 0.1865 - tcl_loss: 0.2733 - sin_loss: 0.0168 - cos_loss: 0.0712 - radii_loss: 0.2484
# (250 / 314) - Loss: 0.6881 - tr_loss: 0.1640 - tcl_loss: 0.3014 - sin_loss: 0.0171 - cos_loss: 0.0256 - radii_loss: 0.1799
# (300 / 314) - Loss: 0.8481 - tr_loss: 0.1553 - tcl_loss: 0.2293 - sin_loss: 0.0070 - cos_loss: 0.0645 - radii_loss: 0.3919
# Training Loss: 0.9488724637183414
# Validation: - Loss: 0.5457 - tr_loss: 0.0972 - tcl_loss: 0.2025 - sin_loss: 0.0090 - cos_loss: 0.0726 - radii_loss: 0.1645
# Validation: - Loss: 1.3132 - tr_loss: 0.1698 - tcl_loss: 0.2878 - sin_loss: 0.0188 - cos_loss: 0.2342 - radii_loss: 0.6026
# Validation Loss: 0.9443992630640665
# Epoch: 192 : LR = 0.0001
# (0 / 314) - Loss: 1.7954 - tr_loss: 0.2660 - tcl_loss: 0.3860 - sin_loss: 0.0143 - cos_loss: 0.1328 - radii_loss: 0.9963
# (50 / 314) - Loss: 0.8286 - tr_loss: 0.1581 - tcl_loss: 0.2025 - sin_loss: 0.0152 - cos_loss: 0.0765 - radii_loss: 0.3763
# (100 / 314) - Loss: 0.8689 - tr_loss: 0.1813 - tcl_loss: 0.2605 - sin_loss: 0.0096 - cos_loss: 0.0873 - radii_loss: 0.3302
# (150 / 314) - Loss: 1.4905 - tr_loss: 0.2174 - tcl_loss: 0.2984 - sin_loss: 0.0367 - cos_loss: 0.1602 - radii_loss: 0.7778
# (200 / 314) - Loss: 0.8057 - tr_loss: 0.2185 - tcl_loss: 0.2629 - sin_loss: 0.0106 - cos_loss: 0.1868 - radii_loss: 0.1269
# (250 / 314) - Loss: 0.8675 - tr_loss: 0.1723 - tcl_loss: 0.3498 - sin_loss: 0.0206 - cos_loss: 0.1301 - radii_loss: 0.1947
# (300 / 314) - Loss: 0.4549 - tr_loss: 0.1109 - tcl_loss: 0.2214 - sin_loss: 0.0138 - cos_loss: 0.0395 - radii_loss: 0.0692
# Training Loss: 0.9606267474829011
# Validation: - Loss: 0.5555 - tr_loss: 0.0983 - tcl_loss: 0.2076 - sin_loss: 0.0088 - cos_loss: 0.0733 - radii_loss: 0.1675
# Validation: - Loss: 0.9551 - tr_loss: 0.1724 - tcl_loss: 0.2840 - sin_loss: 0.0180 - cos_loss: 0.2263 - radii_loss: 0.2544
# Validation Loss: 0.9809553865591685
# Epoch: 193 : LR = 0.0001
# (0 / 314) - Loss: 0.6274 - tr_loss: 0.1342 - tcl_loss: 0.2346 - sin_loss: 0.0117 - cos_loss: 0.0546 - radii_loss: 0.1923
# (50 / 314) - Loss: 1.4871 - tr_loss: 0.2706 - tcl_loss: 0.3113 - sin_loss: 0.0522 - cos_loss: 0.1942 - radii_loss: 0.6587
# (100 / 314) - Loss: 0.9422 - tr_loss: 0.1501 - tcl_loss: 0.2853 - sin_loss: 0.0228 - cos_loss: 0.1042 - radii_loss: 0.3799
# (150 / 314) - Loss: 0.8717 - tr_loss: 0.1852 - tcl_loss: 0.2830 - sin_loss: 0.0273 - cos_loss: 0.2083 - radii_loss: 0.1679
# (200 / 314) - Loss: 0.8571 - tr_loss: 0.1478 - tcl_loss: 0.2878 - sin_loss: 0.0245 - cos_loss: 0.0822 - radii_loss: 0.3149
# (250 / 314) - Loss: 1.3820 - tr_loss: 0.2122 - tcl_loss: 0.3378 - sin_loss: 0.0312 - cos_loss: 0.1470 - radii_loss: 0.6538
# (300 / 314) - Loss: 0.7655 - tr_loss: 0.1508 - tcl_loss: 0.2233 - sin_loss: 0.0136 - cos_loss: 0.1106 - radii_loss: 0.2671
# Training Loss: 0.9442231147342427
# Validation: - Loss: 0.5540 - tr_loss: 0.0998 - tcl_loss: 0.2038 - sin_loss: 0.0099 - cos_loss: 0.0739 - radii_loss: 0.1665
# Validation: - Loss: 1.2776 - tr_loss: 0.1658 - tcl_loss: 0.2891 - sin_loss: 0.0180 - cos_loss: 0.2381 - radii_loss: 0.5666
# Validation Loss: 0.9392494241396586
# Epoch: 194 : LR = 0.0001
# (0 / 314) - Loss: 0.8127 - tr_loss: 0.1838 - tcl_loss: 0.3270 - sin_loss: 0.0318 - cos_loss: 0.0447 - radii_loss: 0.2254
# (50 / 314) - Loss: 0.5634 - tr_loss: 0.1365 - tcl_loss: 0.2637 - sin_loss: 0.0177 - cos_loss: 0.0761 - radii_loss: 0.0693
# (100 / 314) - Loss: 0.7678 - tr_loss: 0.1456 - tcl_loss: 0.2568 - sin_loss: 0.0191 - cos_loss: 0.1081 - radii_loss: 0.2382
# (150 / 314) - Loss: 0.7121 - tr_loss: 0.1792 - tcl_loss: 0.2578 - sin_loss: 0.0320 - cos_loss: 0.0325 - radii_loss: 0.2105
# (200 / 314) - Loss: 1.3371 - tr_loss: 0.1943 - tcl_loss: 0.3606 - sin_loss: 0.0273 - cos_loss: 0.2308 - radii_loss: 0.5242
# (250 / 314) - Loss: 1.3710 - tr_loss: 0.2330 - tcl_loss: 0.2542 - sin_loss: 0.0097 - cos_loss: 0.1761 - radii_loss: 0.6979
# (300 / 314) - Loss: 0.9448 - tr_loss: 0.2541 - tcl_loss: 0.4022 - sin_loss: 0.0417 - cos_loss: 0.1028 - radii_loss: 0.1440
# Training Loss: 0.9318648000621492
# Validation: - Loss: 0.5829 - tr_loss: 0.1033 - tcl_loss: 0.2045 - sin_loss: 0.0106 - cos_loss: 0.0752 - radii_loss: 0.1892
# Validation: - Loss: 1.3865 - tr_loss: 0.1697 - tcl_loss: 0.2940 - sin_loss: 0.0200 - cos_loss: 0.2422 - radii_loss: 0.6605
# Validation Loss: 0.9278420102596283
# Epoch: 195 : LR = 0.0001
# (0 / 314) - Loss: 1.4626 - tr_loss: 0.1732 - tcl_loss: 0.3145 - sin_loss: 0.0298 - cos_loss: 0.2021 - radii_loss: 0.7430
# (50 / 314) - Loss: 0.9372 - tr_loss: 0.1927 - tcl_loss: 0.2944 - sin_loss: 0.0336 - cos_loss: 0.1669 - radii_loss: 0.2496
# (100 / 314) - Loss: 0.5876 - tr_loss: 0.1884 - tcl_loss: 0.3087 - sin_loss: 0.0160 - cos_loss: 0.0339 - radii_loss: 0.0406
# (150 / 314) - Loss: 1.0642 - tr_loss: 0.1667 - tcl_loss: 0.3264 - sin_loss: 0.0148 - cos_loss: 0.1465 - radii_loss: 0.4097
# (200 / 314) - Loss: 0.7958 - tr_loss: 0.1779 - tcl_loss: 0.2208 - sin_loss: 0.0127 - cos_loss: 0.0469 - radii_loss: 0.3375
# (250 / 314) - Loss: 1.0476 - tr_loss: 0.1221 - tcl_loss: 0.2376 - sin_loss: 0.0150 - cos_loss: 0.0472 - radii_loss: 0.6257
# (300 / 314) - Loss: 1.3200 - tr_loss: 0.1912 - tcl_loss: 0.4652 - sin_loss: 0.0740 - cos_loss: 0.1925 - radii_loss: 0.3971
# Training Loss: 0.9376316555081659
# Validation: - Loss: 0.5728 - tr_loss: 0.1021 - tcl_loss: 0.2034 - sin_loss: 0.0114 - cos_loss: 0.0756 - radii_loss: 0.1804
# Validation: - Loss: 1.3148 - tr_loss: 0.1671 - tcl_loss: 0.2889 - sin_loss: 0.0208 - cos_loss: 0.2328 - radii_loss: 0.6053
# Validation Loss: 0.9368491053581238
# Epoch: 196 : LR = 0.0001
# (0 / 314) - Loss: 0.9417 - tr_loss: 0.1373 - tcl_loss: 0.2488 - sin_loss: 0.0262 - cos_loss: 0.0764 - radii_loss: 0.4530
# (50 / 314) - Loss: 1.3880 - tr_loss: 0.2414 - tcl_loss: 0.2830 - sin_loss: 0.0303 - cos_loss: 0.1691 - radii_loss: 0.6642
# (100 / 314) - Loss: 1.0194 - tr_loss: 0.1419 - tcl_loss: 0.2462 - sin_loss: 0.0190 - cos_loss: 0.1893 - radii_loss: 0.4231
# (150 / 314) - Loss: 1.1196 - tr_loss: 0.1448 - tcl_loss: 0.4025 - sin_loss: 0.0464 - cos_loss: 0.1070 - radii_loss: 0.4189
# (200 / 314) - Loss: 1.2371 - tr_loss: 0.1262 - tcl_loss: 0.2398 - sin_loss: 0.0102 - cos_loss: 0.1038 - radii_loss: 0.7571
# (250 / 314) - Loss: 0.8308 - tr_loss: 0.1556 - tcl_loss: 0.2522 - sin_loss: 0.0180 - cos_loss: 0.0549 - radii_loss: 0.3501
# (300 / 314) - Loss: 0.4903 - tr_loss: 0.0883 - tcl_loss: 0.2168 - sin_loss: 0.0093 - cos_loss: 0.0854 - radii_loss: 0.0906
# Training Loss: 0.919993498902412
# Validation: - Loss: 0.5562 - tr_loss: 0.0983 - tcl_loss: 0.2051 - sin_loss: 0.0098 - cos_loss: 0.0740 - radii_loss: 0.1690
# Validation: - Loss: 1.0503 - tr_loss: 0.1633 - tcl_loss: 0.2877 - sin_loss: 0.0192 - cos_loss: 0.2358 - radii_loss: 0.3442
# Validation Loss: 0.9779092057545979
# Epoch: 197 : LR = 0.0001
# (0 / 314) - Loss: 1.2417 - tr_loss: 0.1517 - tcl_loss: 0.2919 - sin_loss: 0.0402 - cos_loss: 0.1737 - radii_loss: 0.5842
# (50 / 314) - Loss: 0.6718 - tr_loss: 0.1206 - tcl_loss: 0.1720 - sin_loss: 0.0067 - cos_loss: 0.0986 - radii_loss: 0.2739
# (100 / 314) - Loss: 1.6263 - tr_loss: 0.4731 - tcl_loss: 0.3251 - sin_loss: 0.0292 - cos_loss: 0.0960 - radii_loss: 0.7029
# (150 / 314) - Loss: 1.0849 - tr_loss: 0.1644 - tcl_loss: 0.2742 - sin_loss: 0.0175 - cos_loss: 0.1480 - radii_loss: 0.4809
# (200 / 314) - Loss: 1.4054 - tr_loss: 0.4379 - tcl_loss: 0.3008 - sin_loss: 0.0296 - cos_loss: 0.1219 - radii_loss: 0.5153
# (250 / 314) - Loss: 0.9209 - tr_loss: 0.1675 - tcl_loss: 0.2648 - sin_loss: 0.0117 - cos_loss: 0.0860 - radii_loss: 0.3910
# (300 / 314) - Loss: 1.9162 - tr_loss: 0.4383 - tcl_loss: 0.3532 - sin_loss: 0.0302 - cos_loss: 0.1512 - radii_loss: 0.9433
# Training Loss: 0.9431431538360134
# Validation: - Loss: 0.5591 - tr_loss: 0.0995 - tcl_loss: 0.2068 - sin_loss: 0.0096 - cos_loss: 0.0735 - radii_loss: 0.1696
# Validation: - Loss: 1.0314 - tr_loss: 0.1667 - tcl_loss: 0.2884 - sin_loss: 0.0178 - cos_loss: 0.2255 - radii_loss: 0.3330
# Validation Loss: 0.9593479557832082
# Epoch: 198 : LR = 0.0001
# (0 / 314) - Loss: 1.3238 - tr_loss: 0.1878 - tcl_loss: 0.2743 - sin_loss: 0.0228 - cos_loss: 0.1661 - radii_loss: 0.6728
# (50 / 314) - Loss: 1.3180 - tr_loss: 0.1924 - tcl_loss: 0.3019 - sin_loss: 0.0157 - cos_loss: 0.1514 - radii_loss: 0.6565
# (100 / 314) - Loss: 0.9877 - tr_loss: 0.2765 - tcl_loss: 0.2319 - sin_loss: 0.0098 - cos_loss: 0.0832 - radii_loss: 0.3863
# (150 / 314) - Loss: 0.8165 - tr_loss: 0.1326 - tcl_loss: 0.2820 - sin_loss: 0.0199 - cos_loss: 0.0747 - radii_loss: 0.3073
# (200 / 314) - Loss: 0.9639 - tr_loss: 0.2040 - tcl_loss: 0.3144 - sin_loss: 0.0230 - cos_loss: 0.1236 - radii_loss: 0.2990
# (250 / 314) - Loss: 0.6209 - tr_loss: 0.1627 - tcl_loss: 0.2851 - sin_loss: 0.0110 - cos_loss: 0.0631 - radii_loss: 0.0990
# (300 / 314) - Loss: 0.6714 - tr_loss: 0.2099 - tcl_loss: 0.2845 - sin_loss: 0.0107 - cos_loss: 0.1033 - radii_loss: 0.0630
# Training Loss: 0.9322462826018121
# Validation: - Loss: 0.5512 - tr_loss: 0.0972 - tcl_loss: 0.2034 - sin_loss: 0.0093 - cos_loss: 0.0736 - radii_loss: 0.1677
# Validation: - Loss: 1.0070 - tr_loss: 0.1611 - tcl_loss: 0.2823 - sin_loss: 0.0179 - cos_loss: 0.2308 - radii_loss: 0.3148
# Validation Loss: 0.9938799464702606
# Epoch: 199 : LR = 0.0001
# (0 / 314) - Loss: 1.0386 - tr_loss: 0.2293 - tcl_loss: 0.3155 - sin_loss: 0.0631 - cos_loss: 0.1383 - radii_loss: 0.2924
# (50 / 314) - Loss: 0.8045 - tr_loss: 0.3097 - tcl_loss: 0.3032 - sin_loss: 0.0595 - cos_loss: 0.0412 - radii_loss: 0.0909
# (100 / 314) - Loss: 0.7377 - tr_loss: 0.1574 - tcl_loss: 0.2748 - sin_loss: 0.0225 - cos_loss: 0.0738 - radii_loss: 0.2093
# (150 / 314) - Loss: 0.5609 - tr_loss: 0.1289 - tcl_loss: 0.2016 - sin_loss: 0.0161 - cos_loss: 0.0891 - radii_loss: 0.1252
# (200 / 314) - Loss: 1.1461 - tr_loss: 0.1503 - tcl_loss: 0.3071 - sin_loss: 0.0300 - cos_loss: 0.1983 - radii_loss: 0.4605
# (250 / 314) - Loss: 0.8149 - tr_loss: 0.1346 - tcl_loss: 0.2852 - sin_loss: 0.1136 - cos_loss: 0.1301 - radii_loss: 0.1513
# (300 / 314) - Loss: 0.5407 - tr_loss: 0.1328 - tcl_loss: 0.2064 - sin_loss: 0.0126 - cos_loss: 0.0423 - radii_loss: 0.1467
# Training Loss: 0.9366308369074657
# Validation: - Loss: 0.5517 - tr_loss: 0.0970 - tcl_loss: 0.2028 - sin_loss: 0.0094 - cos_loss: 0.0739 - radii_loss: 0.1686
# Validation: - Loss: 1.0321 - tr_loss: 0.1604 - tcl_loss: 0.2834 - sin_loss: 0.0177 - cos_loss: 0.2331 - radii_loss: 0.3375
# Validation Loss: 0.9729447726408641
# Epoch: 200 : LR = 0.0001
# (0 / 314) - Loss: 1.2075 - tr_loss: 0.2429 - tcl_loss: 0.2725 - sin_loss: 0.0105 - cos_loss: 0.0653 - radii_loss: 0.6163
# (50 / 314) - Loss: 1.2837 - tr_loss: 0.1722 - tcl_loss: 0.3460 - sin_loss: 0.0163 - cos_loss: 0.2490 - radii_loss: 0.5002
# (100 / 314) - Loss: 1.9404 - tr_loss: 0.1387 - tcl_loss: 0.3680 - sin_loss: 0.0437 - cos_loss: 0.1211 - radii_loss: 1.2688
# (150 / 314) - Loss: 1.0189 - tr_loss: 0.1643 - tcl_loss: 0.2492 - sin_loss: 0.0133 - cos_loss: 0.1198 - radii_loss: 0.4723
# (200 / 314) - Loss: 0.9536 - tr_loss: 0.1114 - tcl_loss: 0.2657 - sin_loss: 0.0155 - cos_loss: 0.1038 - radii_loss: 0.4571
# (250 / 314) - Loss: 0.6541 - tr_loss: 0.1518 - tcl_loss: 0.2940 - sin_loss: 0.0149 - cos_loss: 0.0628 - radii_loss: 0.1307
# (300 / 314) - Loss: 1.5789 - tr_loss: 0.1938 - tcl_loss: 0.2969 - sin_loss: 0.0272 - cos_loss: 0.0923 - radii_loss: 0.9687
# Saving to ./save/resnet_ASPP_LATE_GATE/textsnake_resnet_200.pth.
# Training Loss: 0.9049657948647335
# Validation: - Loss: 0.5546 - tr_loss: 0.0964 - tcl_loss: 0.2031 - sin_loss: 0.0090 - cos_loss: 0.0739 - radii_loss: 0.1722
# Validation: - Loss: 1.0300 - tr_loss: 0.1653 - tcl_loss: 0.2824 - sin_loss: 0.0179 - cos_loss: 0.2320 - radii_loss: 0.3325
# Validation Loss: 0.9497058260440826
# End.

# %%
import os
import time
import cv2
import numpy as np
import torch
import subprocess
import torch.backends.cudnn as cudnn
import torch.utils.data as data

import multiprocessing

from util.detection import TextDetector
from util.augmentation import BaseTransform
from util.option import BaseOptions
from util.visualize import visualize_detection
from util.misc import rescale_result

from torchvision.ops import nms
from sklearn.cluster import DBSCAN
from util.config import config as cfg
from util.misc import fill_hole, regularize_sin_cos
from util.misc import norm2, vector_cos, vector_sin
from util.misc import disjoint_merge, merge_polygons

# %%
def write_to_file(contours, file_path):
    # according to total-text evaluation method, output file shoud be formatted to: y0,x0, ..... yn,xn
    with open(file_path, 'w') as f:
        for cont in contours:
            cont = np.stack([cont[:, 1], cont[:, 0]], 1)
            cont = cont.flatten().astype(str).tolist()
            cont = ','.join(cont)
            f.write(cont + '\n')

# %%
def inference(detector, test_loader, output_dir):
    total_time = 0.

    for i, (image, train_mask, tr_mask, tcl_mask, radius_map, sin_map, cos_map, meta) in enumerate(test_loader):

        image, train_mask, tr_mask, tcl_mask, radius_map, sin_map, cos_map = to_device(
            image, train_mask, tr_mask, tcl_mask, radius_map, sin_map, cos_map)

        torch.cuda.synchronize()
        start = time.time()

        idx = 0 # test mode can only run with batch_size == 1

        # get detection result
        contours, output = detector.detect(image)

        torch.cuda.synchronize()
        end = time.time()
        total_time += end - start
        fps = (i + 1) / total_time
        print('detect {} / {} images: {}. ({:.2f} fps)'.format(i + 1, len(test_loader), meta['image_id'][idx], fps))

        # visualization
        tr_pred, tcl_pred = output['tr'], output['tcl']
        img_show = image[idx].permute(1, 2, 0).cpu().numpy()
        img_show = ((img_show * cfg.stds + cfg.means) * 255).astype(np.uint8)

        pred_vis = visualize_detection(img_show, contours, tr_pred[1], tcl_pred[1])
        gt_contour = []
        for annot, n_annot in zip(meta['annotation'][idx], meta['n_annotation'][idx]):
            if n_annot.item() > 0:
                gt_contour.append(annot[:n_annot].int().cpu().numpy())
        gt_vis = visualize_detection(img_show, gt_contour, tr_mask[idx].cpu().numpy(), tcl_mask[idx].cpu().numpy())
        im_vis = np.concatenate([pred_vis, gt_vis], axis=0)
        path = os.path.join(cfg.vis_dir, '{}_test'.format(cfg.exp_name), meta['image_id'][idx])
        cv2.imwrite(path, im_vis)

        H, W = meta['Height'][idx].item(), meta['Width'][idx].item()
        img_show, contours = rescale_result(img_show, contours, H, W)

        # write to file
        mkdirs(output_dir)
        write_to_file(contours, os.path.join(output_dir, meta['image_id'][idx].replace('jpg', 'txt')))

# %%
def main():     
    if multiprocessing.get_start_method(allow_none=True) is None:
        multiprocessing.set_start_method('spawn')
    
    testset = TotalText(
        # data_root='data/total-text',
        data_root=cfg.data_root,
        ignore_list=None,
        is_training=False,
        transform=BaseTransform(size=cfg.input_size, mean=cfg.means, std=cfg.stds),
        data_custom=cfg.data_custom
    )
    test_loader = data.DataLoader(testset, batch_size=1, shuffle=False, num_workers=cfg.num_workers)

    # Model
    model = TextNet(is_training=False, backbone=cfg.net)
    model_path = os.path.join(cfg.save_dir, cfg.exp_name, \
              'textsnake_{}_{}.pth'.format(model.backbone_name, cfg.checkepoch))
    load_model(model,model_path)

    # copy to cuda
    model = model.to(cfg.device)
    if cfg.cuda:
        cudnn.benchmark = True
    detector = TextDetector(model, tr_thresh=cfg.tr_thresh, tcl_thresh=cfg.tcl_thresh)

    print('Start testing TextSnake.')
    output_dir = os.path.join(cfg.output_dir, cfg.exp_name)
    inference(detector, test_loader, output_dir)

    # compute DetEval
    print('Computing DetEval in {}/{}'.format(cfg.output_dir, cfg.exp_name))
    subprocess.call(['python', 'dataset/total_text/Evaluation_Protocol/Python_scripts/Deteval.py', args.exp_name, '--tr', '0.6', '--tp', '0.4'])
    subprocess.call(['python', 'dataset/total_text/Evaluation_Protocol/Python_scripts/Deteval.py', args.exp_name, '--tr', '0.8', '--tp', '0.4'])
    # subprocess.call(['python', 'dataset/total_text/Evaluation_Protocol/Python_scripts/Deteval.py', args.exp_name, '--tr', '0.6', '--tp', '0.4'])
    # subprocess.call(['python', 'dataset/total_text/Evaluation_Protocol/Python_scripts/Deteval.py', args.exp_name, '--tr', '0.6', '--tp', '0.6'])

    print('End.')

# %%
# parse arguments
option = BaseOptions()

command_line_args = ["resnet_ASPP_LATE_GATE", "--net", "resnet", "--checkepoch", "200", "--data_root", "data/total-text", "--img_root", "data/total-text"]  
args = option.initialize(command_line_args)

update_config(cfg, args)
print_config(cfg)

vis_dir = os.path.join(cfg.vis_dir, '{}_test'.format(cfg.exp_name))
if not os.path.exists(vis_dir):
    mkdirs(vis_dir)
# main
main()
# Out:
# total-text
# ==========Options============
# num_workers: 8
# batch_size: 4
# max_epoch: 201
# start_epoch: 0
# lr: 0.0001
# cuda: True
# n_disk: 15
# output_dir: output
# input_size: 512
# max_annotation: 200
# max_points: 20
# use_hard: True
# tr_thresh: 0.6
# tcl_thresh: 0.4
# post_process_expand: 0.3
# post_process_merge: False
# dataset: total-text
# device: cuda
# vis_dir: ./vis/
# save_dir: ./save/
# data_custom: False
# data_root: data/total-text
# exp_name: resnet_ASPP_LATE_GATE
# net: resnet
# resume: None
# mgpu: False
# log_dir: ./logs/
# loss: CrossEntropyLoss
# input_channel: 1
# pretrain: False
# verbose: True
# viz: False
# start_iter: 0
# lr_adjust: fix
# stepvalues: []
# weight_decay: 0.0
# gamma: 0.1
# momentum: 0.9
# optim: SGD
# display_freq: 50
# viz_freq: 50
# save_freq: 50
# log_freq: 100
# val_freq: 100
# rescale: 255.0
# means: [0.485, 0.456, 0.406]
# stds: [0.229, 0.224, 0.225]
# checkepoch: 200
# img_root: data/total-text
# =============End=============
# Loading from ./save/resnet_ASPP_LATE_GATE/textsnake_resnet_200.pth
# Start testing TextSnake.
# detect 1 / 300 images: img541.jpg. (5.01 fps)
# detect 2 / 300 images: img619.jpg. (6.86 fps)
# detect 3 / 300 images: img1547.jpg. (8.72 fps)
# detect 4 / 300 images: img584.jpg. (10.00 fps)
# detect 5 / 300 images: img93.jpg. (10.81 fps)
# detect 6 / 300 images: img994.jpg. (11.98 fps)
# detect 7 / 300 images: img1191.jpg. (12.41 fps)
# detect 8 / 300 images: img1544.jpg. (13.08 fps)
# detect 9 / 300 images: img646.jpg. (13.60 fps)
# detect 10 / 300 images: img893.jpg. (13.45 fps)
# detect 11 / 300 images: img634.jpg. (13.89 fps)
# detect 12 / 300 images: img669.jpg. (14.14 fps)
# detect 13 / 300 images: img1095.jpg. (14.43 fps)
# detect 14 / 300 images: img617.jpg. (14.33 fps)
# detect 15 / 300 images: img5.jpg. (14.76 fps)
# detect 16 / 300 images: img585.jpg. (15.04 fps)
# detect 17 / 300 images: img643.jpg. (14.58 fps)
# detect 18 / 300 images: img676.jpg. (14.61 fps)
# detect 19 / 300 images: img568.jpg. (14.81 fps)
# detect 20 / 300 images: img587.jpg. (14.84 fps)
# detect 21 / 300 images: img649.jpg. (14.94 fps)
# detect 22 / 300 images: img1198.jpg. (15.26 fps)
# detect 23 / 300 images: img294.jpg. (15.55 fps)
# detect 24 / 300 images: img548.jpg. (15.69 fps)
# detect 25 / 300 images: img598.jpg. (15.87 fps)
# detect 26 / 300 images: img1394.jpg. (15.99 fps)
# detect 27 / 300 images: img602.jpg. (15.98 fps)
# detect 28 / 300 images: img1094.jpg. (16.08 fps)
# detect 29 / 300 images: img667.jpg. (16.35 fps)
# detect 30 / 300 images: img193.jpg. (16.45 fps)
# detect 31 / 300 images: img544.jpg. (16.56 fps)
# detect 32 / 300 images: img566.jpg. (16.51 fps)
# detect 33 / 300 images: img1348.jpg. (16.54 fps)
# detect 34 / 300 images: img200.jpg. (16.59 fps)
# detect 35 / 300 images: img1540.jpg. (16.71 fps)
# detect 36 / 300 images: img393.jpg. (16.44 fps)
# detect 37 / 300 images: img554.jpg. (16.19 fps)
# detect 38 / 300 images: img610.jpg. (16.32 fps)
# detect 39 / 300 images: img572.jpg. (16.28 fps)
# detect 40 / 300 images: img674.jpg. (16.18 fps)
# detect 41 / 300 images: img998.jpg. (16.14 fps)
# detect 42 / 300 images: img7.jpg. (16.13 fps)
# detect 43 / 300 images: img1553.jpg. (16.04 fps)
# detect 44 / 300 images: img575.jpg. (16.15 fps)
# detect 45 / 300 images: img612.jpg. (16.21 fps)
# detect 46 / 300 images: img657.jpg. (16.28 fps)
# detect 47 / 300 images: img992.jpg. (16.30 fps)
# detect 48 / 300 images: img1395.jpg. (16.34 fps)
# detect 49 / 300 images: img583.jpg. (16.33 fps)
# detect 50 / 300 images: img629.jpg. (16.35 fps)
# detect 51 / 300 images: img797.jpg. (16.43 fps)
# detect 52 / 300 images: img1393.jpg. (16.48 fps)
# detect 53 / 300 images: img635.jpg. (16.37 fps)
# detect 54 / 300 images: img593.jpg. (16.38 fps)
# detect 55 / 300 images: img603.jpg. (16.49 fps)
# detect 56 / 300 images: img1296.jpg. (16.39 fps)
# detect 57 / 300 images: img642.jpg. (16.37 fps)
# detect 58 / 300 images: img1396.jpg. (16.35 fps)
# detect 59 / 300 images: img398.jpg. (16.38 fps)
# detect 60 / 300 images: img627.jpg. (16.37 fps)
# detect 61 / 300 images: img618.jpg. (16.31 fps)
# detect 62 / 300 images: img100.jpg. (16.40 fps)
# detect 63 / 300 images: img565.jpg. (16.46 fps)
# detect 64 / 300 images: img92.jpg. (16.47 fps)
# detect 65 / 300 images: img1291.jpg. (16.55 fps)
# detect 66 / 300 images: img624.jpg. (16.59 fps)
# detect 67 / 300 images: img582.jpg. (16.63 fps)
# detect 68 / 300 images: img655.jpg. (16.70 fps)
# detect 69 / 300 images: img533.jpg. (16.68 fps)
# detect 70 / 300 images: img570.jpg. (16.69 fps)
# detect 71 / 300 images: img588.jpg. (16.73 fps)
# detect 72 / 300 images: img399.jpg. (16.78 fps)
# detect 73 / 300 images: img559.jpg. (16.65 fps)
# detect 74 / 300 images: img898.jpg. (16.66 fps)
# detect 75 / 300 images: img800.jpg. (16.67 fps)
# detect 76 / 300 images: img538.jpg. (16.75 fps)
# detect 77 / 300 images: img1295.jpg. (16.79 fps)
# detect 78 / 300 images: img1292.jpg. (16.78 fps)
# detect 79 / 300 images: img658.jpg. (16.66 fps)
# detect 80 / 300 images: img91.jpg. (16.72 fps)
# detect 81 / 300 images: img633.jpg. (16.77 fps)
# detect 82 / 300 images: img993.jpg. (16.66 fps)
# detect 83 / 300 images: img1398.jpg. (16.68 fps)
# detect 84 / 300 images: img616.jpg. (16.73 fps)
# detect 85 / 300 images: img391.jpg. (16.75 fps)
# detect 86 / 300 images: img794.jpg. (16.81 fps)
# detect 87 / 300 images: img615.jpg. (16.82 fps)
# detect 88 / 300 images: img607.jpg. (16.85 fps)
# detect 89 / 300 images: img295.jpg. (16.79 fps)
# detect 90 / 300 images: img539.jpg. (16.84 fps)
# detect 91 / 300 images: img637.jpg. (16.90 fps)
# detect 92 / 300 images: img540.jpg. (16.75 fps)
# detect 93 / 300 images: img1299.jpg. (16.77 fps)
# detect 94 / 300 images: img647.jpg. (16.80 fps)
# detect 95 / 300 images: img793.jpg. (16.66 fps)
# detect 96 / 300 images: img1541.jpg. (16.66 fps)
# detect 97 / 300 images: img600.jpg. (16.61 fps)
# detect 98 / 300 images: img534.jpg. (16.64 fps)
# detect 99 / 300 images: img1098.jpg. (16.64 fps)
# detect 100 / 300 images: img1197.jpg. (16.65 fps)
# detect 101 / 300 images: img590.jpg. (16.65 fps)
# detect 102 / 300 images: img891.jpg. (16.61 fps)
# detect 103 / 300 images: img652.jpg. (16.61 fps)
# detect 104 / 300 images: img894.jpg. (16.60 fps)
# detect 105 / 300 images: img595.jpg. (16.57 fps)
# detect 106 / 300 images: img1400.jpg. (16.57 fps)
# detect 107 / 300 images: img604.jpg. (16.61 fps)
# detect 108 / 300 images: img545.jpg. (16.63 fps)
# detect 109 / 300 images: img625.jpg. (16.66 fps)
# detect 110 / 300 images: img677.jpg. (16.70 fps)
# detect 111 / 300 images: img569.jpg. (16.70 fps)
# detect 112 / 300 images: img1300.jpg. (16.75 fps)
# detect 113 / 300 images: img599.jpg. (16.76 fps)
# detect 114 / 300 images: img3.jpg. (16.78 fps)
# detect 115 / 300 images: img195.jpg. (16.79 fps)
# detect 116 / 300 images: img1192.jpg. (16.70 fps)
# detect 117 / 300 images: img671.jpg. (16.69 fps)
# detect 118 / 300 images: img497.jpg. (16.69 fps)
# detect 119 / 300 images: img795.jpg. (15.96 fps)
# detect 120 / 300 images: img622.jpg. (15.91 fps)
# detect 121 / 300 images: img1392.jpg. (15.92 fps)
# detect 122 / 300 images: img552.jpg. (15.95 fps)
# detect 123 / 300 images: img192.jpg. (15.98 fps)
# detect 124 / 300 images: img558.jpg. (15.91 fps)
# detect 125 / 300 images: img1550.jpg. (15.92 fps)
# detect 126 / 300 images: img395.jpg. (15.88 fps)
# detect 127 / 300 images: img576.jpg. (15.90 fps)
# detect 128 / 300 images: img560.jpg. (15.89 fps)
# detect 129 / 300 images: img1297.jpg. (15.91 fps)
# detect 130 / 300 images: img198.jpg. (15.94 fps)
# detect 131 / 300 images: img892.jpg. (15.94 fps)
# detect 132 / 300 images: img641.jpg. (15.97 fps)
# detect 133 / 300 images: img549.jpg. (15.91 fps)
# detect 134 / 300 images: img1546.jpg. (15.91 fps)
# detect 135 / 300 images: img659.jpg. (15.90 fps)
# detect 136 / 300 images: img95.jpg. (15.91 fps)
# detect 137 / 300 images: img596.jpg. (15.95 fps)
# detect 138 / 300 images: img494.jpg. (15.98 fps)
# detect 139 / 300 images: img96.jpg. (15.96 fps)
# detect 140 / 300 images: img1097.jpg. (15.96 fps)
# detect 141 / 300 images: img1092.jpg. (15.93 fps)
# detect 142 / 300 images: img555.jpg. (15.80 fps)
# detect 143 / 300 images: img614.jpg. (15.80 fps)
# detect 144 / 300 images: img609.jpg. (15.78 fps)
# detect 145 / 300 images: img651.jpg. (15.75 fps)
# detect 146 / 300 images: img798.jpg. (15.77 fps)
# detect 147 / 300 images: img866.jpg. (15.80 fps)
# detect 148 / 300 images: img630.jpg. (15.82 fps)
# detect 149 / 300 images: img291.jpg. (15.70 fps)
# detect 150 / 300 images: img298.jpg. (15.72 fps)
# detect 151 / 300 images: img1093.jpg. (15.72 fps)
# detect 152 / 300 images: img897.jpg. (15.74 fps)
# detect 153 / 300 images: img551.jpg. (15.75 fps)
# detect 154 / 300 images: img999.jpg. (15.76 fps)
# detect 155 / 300 images: img574.jpg. (15.70 fps)
# detect 156 / 300 images: img1055.jpg. (15.72 fps)
# detect 157 / 300 images: img498.jpg. (15.75 fps)
# detect 158 / 300 images: img1555.jpg. (15.78 fps)
# detect 159 / 300 images: img899.jpg. (15.82 fps)
# detect 160 / 300 images: img660.jpg. (15.85 fps)
# detect 161 / 300 images: img397.jpg. (15.85 fps)
# detect 162 / 300 images: img293.jpg. (15.86 fps)
# detect 163 / 300 images: img670.jpg. (15.86 fps)
# detect 164 / 300 images: img577.jpg. (15.88 fps)
# detect 165 / 300 images: img903.jpg. (15.86 fps)
# detect 166 / 300 images: img94.jpg. (15.87 fps)
# detect 167 / 300 images: img644.jpg. (15.90 fps)
# detect 168 / 300 images: img611.jpg. (15.91 fps)
# detect 169 / 300 images: img556.jpg. (15.91 fps)
# detect 170 / 300 images: img400.jpg. (15.89 fps)
# detect 171 / 300 images: img594.jpg. (15.90 fps)
# detect 172 / 300 images: img900.jpg. (15.93 fps)
# detect 173 / 300 images: img1.jpg. (15.96 fps)
# detect 174 / 300 images: img542.jpg. (16.00 fps)
# detect 175 / 300 images: img623.jpg. (16.01 fps)
# detect 176 / 300 images: img1554.jpg. (16.04 fps)
# detect 177 / 300 images: img638.jpg. (16.06 fps)
# detect 178 / 300 images: img561.jpg. (16.08 fps)
# detect 179 / 300 images: img194.jpg. (16.05 fps)
# detect 180 / 300 images: img620.jpg. (16.08 fps)
# detect 181 / 300 images: img586.jpg. (16.09 fps)
# detect 182 / 300 images: img537.jpg. (16.10 fps)
# detect 183 / 300 images: img1294.jpg. (16.10 fps)
# detect 184 / 300 images: img1298.jpg. (16.10 fps)
# detect 185 / 300 images: img199.jpg. (16.08 fps)
# detect 186 / 300 images: img1552.jpg. (16.04 fps)
# detect 187 / 300 images: img601.jpg. (16.07 fps)
# detect 188 / 300 images: img613.jpg. (16.09 fps)
# detect 189 / 300 images: img1091.jpg. (16.10 fps)
# detect 190 / 300 images: img605.jpg. (16.12 fps)
# detect 191 / 300 images: img535.jpg. (16.13 fps)
# detect 192 / 300 images: img500.jpg. (16.15 fps)
# detect 193 / 300 images: img1391.jpg. (16.15 fps)
# detect 194 / 300 images: img591.jpg. (16.17 fps)
# detect 195 / 300 images: img567.jpg. (16.17 fps)
# detect 196 / 300 images: img196.jpg. (16.19 fps)
# detect 197 / 300 images: img99.jpg. (16.22 fps)
# detect 198 / 300 images: img661.jpg. (16.21 fps)
# detect 199 / 300 images: img581.jpg. (16.22 fps)
# detect 200 / 300 images: img579.jpg. (16.21 fps)
# detect 201 / 300 images: img10.jpg. (16.23 fps)
# detect 202 / 300 images: img296.jpg. (16.24 fps)
# detect 203 / 300 images: img639.jpg. (16.25 fps)
# detect 204 / 300 images: img1193.jpg. (16.27 fps)
# detect 205 / 300 images: img496.jpg. (16.29 fps)
# detect 206 / 300 images: img672.jpg. (16.26 fps)
# detect 207 / 300 images: img632.jpg. (16.27 fps)
# detect 208 / 300 images: img995.jpg. (16.28 fps)
# detect 209 / 300 images: img2.jpg. (16.29 fps)
# detect 210 / 300 images: img550.jpg. (16.30 fps)
# detect 211 / 300 images: img668.jpg. (16.30 fps)
# detect 212 / 300 images: img299.jpg. (16.33 fps)
# detect 213 / 300 images: img896.jpg. (16.33 fps)
# detect 214 / 300 images: img394.jpg. (16.35 fps)
# detect 215 / 300 images: img1539.jpg. (16.38 fps)
# detect 216 / 300 images: img300.jpg. (16.41 fps)
# detect 217 / 300 images: img191.jpg. (16.40 fps)
# detect 218 / 300 images: img1397.jpg. (16.39 fps)
# detect 219 / 300 images: img664.jpg. (16.38 fps)
# detect 220 / 300 images: img640.jpg. (16.38 fps)
# detect 221 / 300 images: img675.jpg. (16.38 fps)
# detect 222 / 300 images: img97.jpg. (16.35 fps)
# detect 223 / 300 images: img650.jpg. (16.36 fps)
# detect 224 / 300 images: img791.jpg. (16.28 fps)
# detect 225 / 300 images: img492.jpg. (16.30 fps)
# detect 226 / 300 images: img679.jpg. (16.32 fps)
# detect 227 / 300 images: img563.jpg. (16.33 fps)
# detect 228 / 300 images: img493.jpg. (16.35 fps)
# detect 229 / 300 images: img626.jpg. (16.35 fps)
# detect 230 / 300 images: img1100.jpg. (16.33 fps)
# detect 231 / 300 images: img580.jpg. (16.35 fps)
# detect 232 / 300 images: img1543.jpg. (16.36 fps)
# detect 233 / 300 images: img543.jpg. (16.36 fps)
# detect 234 / 300 images: img654.jpg. (16.36 fps)
# detect 235 / 300 images: img1549.jpg. (16.30 fps)
# detect 236 / 300 images: img1000.jpg. (16.30 fps)
# detect 237 / 300 images: img573.jpg. (16.29 fps)
# detect 238 / 300 images: img663.jpg. (16.27 fps)
# detect 239 / 300 images: img396.jpg. (16.30 fps)
# detect 240 / 300 images: img1542.jpg. (16.30 fps)
# detect 241 / 300 images: img392.jpg. (16.29 fps)
# detect 242 / 300 images: img796.jpg. (16.30 fps)
# detect 243 / 300 images: img621.jpg. (16.31 fps)
# detect 244 / 300 images: img631.jpg. (16.33 fps)
# detect 245 / 300 images: img997.jpg. (16.33 fps)
# detect 246 / 300 images: img628.jpg. (16.34 fps)
# detect 247 / 300 images: img297.jpg. (16.36 fps)
# detect 248 / 300 images: img895.jpg. (16.37 fps)
# detect 249 / 300 images: img645.jpg. (16.39 fps)
# detect 250 / 300 images: img546.jpg. (16.40 fps)
# detect 251 / 300 images: img197.jpg. (16.42 fps)
# detect 252 / 300 images: img996.jpg. (16.41 fps)
# detect 253 / 300 images: img557.jpg. (16.42 fps)
# detect 254 / 300 images: img1548.jpg. (16.42 fps)
# detect 255 / 300 images: img1399.jpg. (16.43 fps)
# detect 256 / 300 images: img592.jpg. (16.44 fps)
# detect 257 / 300 images: img991.jpg. (16.44 fps)
# detect 258 / 300 images: img792.jpg. (16.43 fps)
# detect 259 / 300 images: img578.jpg. (16.45 fps)
# detect 260 / 300 images: img1194.jpg. (16.47 fps)
# detect 261 / 300 images: img1200.jpg. (16.48 fps)
# detect 262 / 300 images: img589.jpg. (16.49 fps)
# detect 263 / 300 images: img8.jpg. (16.48 fps)
# detect 264 / 300 images: img1099.jpg. (16.48 fps)
# detect 265 / 300 images: img606.jpg. (16.48 fps)
# detect 266 / 300 images: img1196.jpg. (16.48 fps)
# detect 267 / 300 images: img662.jpg. (16.49 fps)
# detect 268 / 300 images: img1195.jpg. (16.49 fps)
# detect 269 / 300 images: img4.jpg. (16.48 fps)
# detect 270 / 300 images: img9.jpg. (16.50 fps)
# detect 271 / 300 images: img608.jpg. (16.49 fps)
# detect 272 / 300 images: img491.jpg. (16.51 fps)
# detect 273 / 300 images: img1551.jpg. (16.52 fps)
# detect 274 / 300 images: img292.jpg. (16.53 fps)
# detect 275 / 300 images: img597.jpg. (16.54 fps)
# detect 276 / 300 images: img536.jpg. (16.56 fps)
# detect 277 / 300 images: img666.jpg. (16.55 fps)
# detect 278 / 300 images: img665.jpg. (16.58 fps)
# detect 279 / 300 images: img1199.jpg. (16.60 fps)
# detect 280 / 300 images: img1096.jpg. (16.56 fps)
# detect 281 / 300 images: img553.jpg. (16.59 fps)
# detect 282 / 300 images: img648.jpg. (16.58 fps)
# detect 283 / 300 images: img562.jpg. (16.58 fps)
# detect 284 / 300 images: img547.jpg. (16.54 fps)
# detect 285 / 300 images: img636.jpg. (16.54 fps)
# detect 286 / 300 images: img564.jpg. (16.51 fps)
# detect 287 / 300 images: img656.jpg. (16.51 fps)
# detect 288 / 300 images: img6.jpg. (16.51 fps)
# detect 289 / 300 images: img673.jpg. (16.51 fps)
# detect 290 / 300 images: img532.jpg. (16.52 fps)
# detect 291 / 300 images: img571.jpg. (16.53 fps)
# detect 292 / 300 images: img495.jpg. (16.54 fps)
# detect 293 / 300 images: img499.jpg. (16.54 fps)
# detect 294 / 300 images: img98.jpg. (16.56 fps)
# detect 295 / 300 images: img531.jpg. (16.55 fps)
# detect 296 / 300 images: img678.jpg. (16.57 fps)
# detect 297 / 300 images: img653.jpg. (16.57 fps)
# detect 298 / 300 images: img1293.jpg. (16.57 fps)
# detect 299 / 300 images: img799.jpg. (16.57 fps)
# detect 300 / 300 images: img1545.jpg. (16.59 fps)
# Computing DetEval in output/resnet_ASPP_LATE_GATE
#   0%|          | 0/300 [00:00<?, ?it/s]/usr/local/lib/python3.9/dist-packages/shapely/set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
#  12%|█▏        | 36/300 [00:03<00:23, 11.38it/s]/notebooks/dataset/total_text/Evaluation_Protocol/Python_scripts/Deteval.py:78: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if (gt[5] == '#') and (gt[1].shape[1] > 1):
# /notebooks/dataset/total_text/Evaluation_Protocol/Python_scripts/Deteval.py:134: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   dc_id = np.where(groundtruths[:, 5] == '#')
# 100%|██████████| 300/300 [00:36<00:00,  8.20it/s]
# Input: output/resnet_ASPP_LATE_GATE
# Config: tr: 0.6 - tp: 0.4
# Precision = 0.8893 - Recall = 0.6501 - Fscore = 0.7511
#
# Done.
#   0%|          | 0/300 [00:00<?, ?it/s]/usr/local/lib/python3.9/dist-packages/shapely/set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
#  12%|█▏        | 36/300 [00:03<00:24, 10.90it/s]/notebooks/dataset/total_text/Evaluation_Protocol/Python_scripts/Deteval.py:78: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if (gt[5] == '#') and (gt[1].shape[1] > 1):
# /notebooks/dataset/total_text/Evaluation_Protocol/Python_scripts/Deteval.py:134: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   dc_id = np.where(groundtruths[:, 5] == '#')
# 100%|██████████| 300/300 [00:34<00:00,  8.67it/s]
# Input: output/resnet_ASPP_LATE_GATE
# Config: tr: 0.8 - tp: 0.4
# Precision = 0.8304 - Recall = 0.6142 - Fscore = 0.7062
#
# Done.
# End.
