# %%
# !pip install easydict
# !pip install tensorboardX
# !pip install shapely

# %%
import torchvision.models.resnet as resnet
import torch.nn as nn
import torch.nn.functional as F

import torch
import torchvision
import torchvision.models as models

import torch.backends.cudnn as cudnn

import warnings
warnings.filterwarnings("ignore")

import os
import time
import argparse
from datetime import datetime

import torch.utils.data as data
from torch.optim import lr_scheduler
from util.shedule import FixLR

from dataset.total_text import TotalText
from dataset.synth_text import SynthText

from util.augmentation import BaseTransform, Augmentation
from util.config import config as cfg, update_config, print_config
from util.misc import AverageMeter
from util.misc import mkdirs, to_device
from util.option import BaseOptions
from util.visualize import visualize_network_output
from util.summary import LogSummary

from easydict import EasyDict
import matplotlib.pyplot as plt

import torch.multiprocessing as mp
from torchvision import models
from torchsummary import summary

warnings.filterwarnings("ignore", message="indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (function expandTensors)")

# %%
torch.cuda.empty_cache()

import gc
gc.collect()
# Out:
# 0

# %%
class ASPP(nn.Module):
    def __init__(self, in_channels, out_channels, dilations):
        super(ASPP, self).__init__()
        self.aspp_blocks = nn.ModuleList()
        for dilation in dilations:
            self.aspp_blocks.append(
                nn.Sequential(
                    nn.Conv2d(in_channels, out_channels, 3, padding=dilation, dilation=dilation, bias=False),
                    nn.BatchNorm2d(out_channels),
                    nn.ReLU(inplace=True)
                )
            )
            
    def forward(self, x):
        return torch.cat([aspp(x) for aspp in self.aspp_blocks], dim=1)

# %%
class STN(nn.Module):
    def __init__(self):
        super(STN, self).__init__()

        # Localization-network
        self.localization = nn.Sequential(
            nn.Conv2d(3, 8, kernel_size=7),
            nn.MaxPool2d(2, stride=2),
            nn.ReLU(True),
            nn.Conv2d(8, 10, kernel_size=5),
            nn.MaxPool2d(2, stride=2),
            nn.ReLU(True)
        )

        # Regressor for the 3 * 2 affine matrix
        self.fc_loc = nn.Sequential(
            nn.Linear(10 * 124 * 124, 32),
            nn.ReLU(True),
            nn.Linear(32, 3 * 2)
        )

        # Initialize the weights/bias with identity transformation
        self.fc_loc[2].weight.data.zero_()
        self.fc_loc[2].bias.data.copy_(torch.tensor([1, 0, 0, 0, 1, 0], dtype=torch.float))

    # Spatial transformer network forward function
    def stn(self, x):
        xs = self.localization(x)
        xs = xs.view(-1, 10 * 124 * 124)
        theta = self.fc_loc(xs)
        theta = theta.view(-1, 2, 3)

        grid = F.affine_grid(theta, x.size())
        x = F.grid_sample(x, grid)

        return x

    def forward(self, x):
        x = self.stn(x)
        return x

# %%
from torchvision.models import resnet50

class ResNet50(nn.Module):
    def __init__(self, pretrained=True):
        super().__init__()

        base_model = resnet50(pretrained=pretrained)
        
        self.base_layers = list(base_model.children())
        # self.aspp = ASPP(512, 256, dilations=[6, 12, 18])
        
        self.layer0 = nn.Sequential(*self.base_layers[:3])  # size=(N, 64, h/2, w/2)
        self.layer1 = nn.Sequential(*self.base_layers[3:5]) # size=(N, 64, h/4, w/4)
        self.layer2 = self.base_layers[5]  # size=(N, 128, h/8, w/8)
        self.layer3 = self.base_layers[6]  # size=(N, 256, h/16, w/16)
        self.layer4 = self.base_layers[7]  # size=(N, 512, h/32, w/32)

    def forward(self, x):
        C1 = self.layer0(x)
        C2 = self.layer1(C1)
        C3 = self.layer2(C2)
        C4 = self.layer3(C3)
        C5 = self.layer4(C4)
        
        return C1, C2, C3, C4, C5
    
input = torch.randn((4, 3, 512, 512))
net = ResNet50()

C1, C2, C3, C4, C5 = net(input)
print(C1.size())
print(C2.size())
print(C3.size())
print(C4.size())
print(C5.size())
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
#   0%|          | 0.00/97.8M [00:00<?, ?B/s]
# torch.Size([4, 64, 256, 256])
# torch.Size([4, 256, 128, 128])
# torch.Size([4, 512, 64, 64])
# torch.Size([4, 1024, 32, 32])
# torch.Size([4, 2048, 16, 16])

# %%
class Upsample(nn.Module):

    def __init__(self, in_channels, shortcut_channels, out_channels):
        super().__init__()
        self.conv1x1 = nn.Conv2d(in_channels + shortcut_channels, out_channels, kernel_size=1, stride=1, padding=0)
        self.conv3x3 = nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=1, padding=1)
        self.deconv = nn.ConvTranspose2d(out_channels, out_channels, kernel_size=4, stride=2, padding=1)

    def forward(self, upsampled, shortcut):
        upsampled = F.interpolate(upsampled, size=(shortcut.size(2), shortcut.size(3)), mode='bilinear', align_corners=False)
        x = torch.cat([upsampled, shortcut], dim=1)
        x = self.conv1x1(x)
        x = F.relu(x)
        x = self.conv3x3(x)
        x = F.relu(x)
        x = self.deconv(x)
        return x

    

class TextNet(nn.Module):

    def __init__(self, backbone='resnet', output_channel=7, is_training=True):
        super().__init__()

        self.is_training = is_training
        self.backbone_name = backbone
        self.output_channel = output_channel
         
        self.stn = STN()
        
        if backbone == 'resnet':
            self.backbone = ResNet50(pretrained=self.is_training)

            self.deconv5 = nn.ConvTranspose2d(2048, 512, kernel_size=4, stride=2, padding=1)
            self.merge4 = Upsample(512, 1024, 256)
            self.merge3 = Upsample(256, 512, 128)
            self.merge2 = Upsample(128, 256, 64)
            self.merge1 = Upsample(64, 64, 32)
        

            self.predict = nn.Sequential(
                nn.Conv2d(32, 32, kernel_size=3, stride=1, padding=1),
                nn.Conv2d(32, self.output_channel, kernel_size=1, stride=1, padding=0)
            )
        
    def forward(self, x):
        
        #STN as the first layer
        x = self.stn(x)
        
        C1, C2, C3, C4, C5 = self.backbone(x)
        up5 = self.deconv5(C5)
        up5 = F.relu(up5)

        up4 = self.merge4(C4, up5)
        up4 = F.relu(up4)

        up3 = self.merge3(C3, up4)
        up3 = F.relu(up3)

        up2 = self.merge2(C2, up3)
        up2 = F.relu(up2)

        up1 = self.merge1(C1, up2)
        output = self.predict(up1)
        
        return output

# %%
input = torch.randn((4, 3, 512, 512))
net = TextNet().cuda()
output = net(input.cuda())
print(output.size())



help(summary)
summary(net, (3, 512, 512),4)
# Out:
# torch.Size([4, 7, 512, 512])
# Help on function summary in module torchsummary.torchsummary:
#
# summary(model, input_size, batch_size=-1, device='cuda')
#
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [4, 8, 506, 506]           1,184
#          MaxPool2d-2           [4, 8, 253, 253]               0
#               ReLU-3           [4, 8, 253, 253]               0
#             Conv2d-4          [4, 10, 249, 249]           2,010
#          MaxPool2d-5          [4, 10, 124, 124]               0
#               ReLU-6          [4, 10, 124, 124]               0
#             Linear-7                    [4, 32]       4,920,352
#               ReLU-8                    [4, 32]               0
#             Linear-9                     [4, 6]             198
#               STN-10           [4, 3, 512, 512]               0
#            Conv2d-11          [4, 64, 256, 256]           9,408
#       BatchNorm2d-12          [4, 64, 256, 256]             128
#              ReLU-13          [4, 64, 256, 256]               0
#         MaxPool2d-14          [4, 64, 128, 128]               0
#            Conv2d-15          [4, 64, 128, 128]           4,096
#       BatchNorm2d-16          [4, 64, 128, 128]             128
#              ReLU-17          [4, 64, 128, 128]               0
#            Conv2d-18          [4, 64, 128, 128]          36,864
#       BatchNorm2d-19          [4, 64, 128, 128]             128
#              ReLU-20          [4, 64, 128, 128]               0
#            Conv2d-21         [4, 256, 128, 128]          16,384
#       BatchNorm2d-22         [4, 256, 128, 128]             512
#            Conv2d-23         [4, 256, 128, 128]          16,384
#       BatchNorm2d-24         [4, 256, 128, 128]             512
#              ReLU-25         [4, 256, 128, 128]               0
#        Bottleneck-26         [4, 256, 128, 128]               0
#            Conv2d-27          [4, 64, 128, 128]          16,384
#       BatchNorm2d-28          [4, 64, 128, 128]             128
#              ReLU-29          [4, 64, 128, 128]               0
#            Conv2d-30          [4, 64, 128, 128]          36,864
#       BatchNorm2d-31          [4, 64, 128, 128]             128
#              ReLU-32          [4, 64, 128, 128]               0
#            Conv2d-33         [4, 256, 128, 128]          16,384
#       BatchNorm2d-34         [4, 256, 128, 128]             512
#              ReLU-35         [4, 256, 128, 128]               0
#        Bottleneck-36         [4, 256, 128, 128]               0
#            Conv2d-37          [4, 64, 128, 128]          16,384
#       BatchNorm2d-38          [4, 64, 128, 128]             128
#              ReLU-39          [4, 64, 128, 128]               0
#            Conv2d-40          [4, 64, 128, 128]          36,864
#       BatchNorm2d-41          [4, 64, 128, 128]             128
#              ReLU-42          [4, 64, 128, 128]               0
#            Conv2d-43         [4, 256, 128, 128]          16,384
#       BatchNorm2d-44         [4, 256, 128, 128]             512
#              ReLU-45         [4, 256, 128, 128]               0
#        Bottleneck-46         [4, 256, 128, 128]               0
#            Conv2d-47         [4, 128, 128, 128]          32,768
#       BatchNorm2d-48         [4, 128, 128, 128]             256
#              ReLU-49         [4, 128, 128, 128]               0
#            Conv2d-50           [4, 128, 64, 64]         147,456
#       BatchNorm2d-51           [4, 128, 64, 64]             256
#              ReLU-52           [4, 128, 64, 64]               0
#            Conv2d-53           [4, 512, 64, 64]          65,536
#       BatchNorm2d-54           [4, 512, 64, 64]           1,024
#            Conv2d-55           [4, 512, 64, 64]         131,072
#       BatchNorm2d-56           [4, 512, 64, 64]           1,024
#              ReLU-57           [4, 512, 64, 64]               0
#        Bottleneck-58           [4, 512, 64, 64]               0
#            Conv2d-59           [4, 128, 64, 64]          65,536
#       BatchNorm2d-60           [4, 128, 64, 64]             256
#              ReLU-61           [4, 128, 64, 64]               0
#            Conv2d-62           [4, 128, 64, 64]         147,456
#       BatchNorm2d-63           [4, 128, 64, 64]             256
#              ReLU-64           [4, 128, 64, 64]               0
#            Conv2d-65           [4, 512, 64, 64]          65,536
#       BatchNorm2d-66           [4, 512, 64, 64]           1,024
#              ReLU-67           [4, 512, 64, 64]               0
#        Bottleneck-68           [4, 512, 64, 64]               0
#            Conv2d-69           [4, 128, 64, 64]          65,536
#       BatchNorm2d-70           [4, 128, 64, 64]             256
#              ReLU-71           [4, 128, 64, 64]               0
#            Conv2d-72           [4, 128, 64, 64]         147,456
#       BatchNorm2d-73           [4, 128, 64, 64]             256
#              ReLU-74           [4, 128, 64, 64]               0
#            Conv2d-75           [4, 512, 64, 64]          65,536
#       BatchNorm2d-76           [4, 512, 64, 64]           1,024
#              ReLU-77           [4, 512, 64, 64]               0
#        Bottleneck-78           [4, 512, 64, 64]               0
#            Conv2d-79           [4, 128, 64, 64]          65,536
#       BatchNorm2d-80           [4, 128, 64, 64]             256
#              ReLU-81           [4, 128, 64, 64]               0
#            Conv2d-82           [4, 128, 64, 64]         147,456
#       BatchNorm2d-83           [4, 128, 64, 64]             256
#              ReLU-84           [4, 128, 64, 64]               0
#            Conv2d-85           [4, 512, 64, 64]          65,536
#       BatchNorm2d-86           [4, 512, 64, 64]           1,024
#              ReLU-87           [4, 512, 64, 64]               0
#        Bottleneck-88           [4, 512, 64, 64]               0
#            Conv2d-89           [4, 256, 64, 64]         131,072
#       BatchNorm2d-90           [4, 256, 64, 64]             512
#              ReLU-91           [4, 256, 64, 64]               0
#            Conv2d-92           [4, 256, 32, 32]         589,824
#       BatchNorm2d-93           [4, 256, 32, 32]             512
#              ReLU-94           [4, 256, 32, 32]               0
#            Conv2d-95          [4, 1024, 32, 32]         262,144
#       BatchNorm2d-96          [4, 1024, 32, 32]           2,048
#            Conv2d-97          [4, 1024, 32, 32]         524,288
#       BatchNorm2d-98          [4, 1024, 32, 32]           2,048
#              ReLU-99          [4, 1024, 32, 32]               0
#       Bottleneck-100          [4, 1024, 32, 32]               0
#           Conv2d-101           [4, 256, 32, 32]         262,144
#      BatchNorm2d-102           [4, 256, 32, 32]             512
#             ReLU-103           [4, 256, 32, 32]               0
#           Conv2d-104           [4, 256, 32, 32]         589,824
#      BatchNorm2d-105           [4, 256, 32, 32]             512
#             ReLU-106           [4, 256, 32, 32]               0
#           Conv2d-107          [4, 1024, 32, 32]         262,144
#      BatchNorm2d-108          [4, 1024, 32, 32]           2,048
#             ReLU-109          [4, 1024, 32, 32]               0
#       Bottleneck-110          [4, 1024, 32, 32]               0
#           Conv2d-111           [4, 256, 32, 32]         262,144
#      BatchNorm2d-112           [4, 256, 32, 32]             512
#             ReLU-113           [4, 256, 32, 32]               0
#           Conv2d-114           [4, 256, 32, 32]         589,824
#      BatchNorm2d-115           [4, 256, 32, 32]             512
#             ReLU-116           [4, 256, 32, 32]               0
#           Conv2d-117          [4, 1024, 32, 32]         262,144
#      BatchNorm2d-118          [4, 1024, 32, 32]           2,048
#             ReLU-119          [4, 1024, 32, 32]               0
#       Bottleneck-120          [4, 1024, 32, 32]               0
#           Conv2d-121           [4, 256, 32, 32]         262,144
#      BatchNorm2d-122           [4, 256, 32, 32]             512
#             ReLU-123           [4, 256, 32, 32]               0
#           Conv2d-124           [4, 256, 32, 32]         589,824
#      BatchNorm2d-125           [4, 256, 32, 32]             512
#             ReLU-126           [4, 256, 32, 32]               0
#           Conv2d-127          [4, 1024, 32, 32]         262,144
#      BatchNorm2d-128          [4, 1024, 32, 32]           2,048
#             ReLU-129          [4, 1024, 32, 32]               0
#       Bottleneck-130          [4, 1024, 32, 32]               0
#           Conv2d-131           [4, 256, 32, 32]         262,144
#      BatchNorm2d-132           [4, 256, 32, 32]             512
#             ReLU-133           [4, 256, 32, 32]               0
#           Conv2d-134           [4, 256, 32, 32]         589,824
#      BatchNorm2d-135           [4, 256, 32, 32]             512
#             ReLU-136           [4, 256, 32, 32]               0
#           Conv2d-137          [4, 1024, 32, 32]         262,144
#      BatchNorm2d-138          [4, 1024, 32, 32]           2,048
#             ReLU-139          [4, 1024, 32, 32]               0
#       Bottleneck-140          [4, 1024, 32, 32]               0
#           Conv2d-141           [4, 256, 32, 32]         262,144
#      BatchNorm2d-142           [4, 256, 32, 32]             512
#             ReLU-143           [4, 256, 32, 32]               0
#           Conv2d-144           [4, 256, 32, 32]         589,824
#      BatchNorm2d-145           [4, 256, 32, 32]             512
#             ReLU-146           [4, 256, 32, 32]               0
#           Conv2d-147          [4, 1024, 32, 32]         262,144
#      BatchNorm2d-148          [4, 1024, 32, 32]           2,048
#             ReLU-149          [4, 1024, 32, 32]               0
#       Bottleneck-150          [4, 1024, 32, 32]               0
#           Conv2d-151           [4, 512, 32, 32]         524,288
#      BatchNorm2d-152           [4, 512, 32, 32]           1,024
#             ReLU-153           [4, 512, 32, 32]               0
#           Conv2d-154           [4, 512, 16, 16]       2,359,296
#      BatchNorm2d-155           [4, 512, 16, 16]           1,024
#             ReLU-156           [4, 512, 16, 16]               0
#           Conv2d-157          [4, 2048, 16, 16]       1,048,576
#      BatchNorm2d-158          [4, 2048, 16, 16]           4,096
#           Conv2d-159          [4, 2048, 16, 16]       2,097,152
#      BatchNorm2d-160          [4, 2048, 16, 16]           4,096
#             ReLU-161          [4, 2048, 16, 16]               0
#       Bottleneck-162          [4, 2048, 16, 16]               0
#           Conv2d-163           [4, 512, 16, 16]       1,048,576
#      BatchNorm2d-164           [4, 512, 16, 16]           1,024
#             ReLU-165           [4, 512, 16, 16]               0
#           Conv2d-166           [4, 512, 16, 16]       2,359,296
#      BatchNorm2d-167           [4, 512, 16, 16]           1,024
#             ReLU-168           [4, 512, 16, 16]               0
#           Conv2d-169          [4, 2048, 16, 16]       1,048,576
#      BatchNorm2d-170          [4, 2048, 16, 16]           4,096
#             ReLU-171          [4, 2048, 16, 16]               0
#       Bottleneck-172          [4, 2048, 16, 16]               0
#           Conv2d-173           [4, 512, 16, 16]       1,048,576
#      BatchNorm2d-174           [4, 512, 16, 16]           1,024
#             ReLU-175           [4, 512, 16, 16]               0
#           Conv2d-176           [4, 512, 16, 16]       2,359,296
#      BatchNorm2d-177           [4, 512, 16, 16]           1,024
#             ReLU-178           [4, 512, 16, 16]               0
#           Conv2d-179          [4, 2048, 16, 16]       1,048,576
#      BatchNorm2d-180          [4, 2048, 16, 16]           4,096
#             ReLU-181          [4, 2048, 16, 16]               0
#       Bottleneck-182          [4, 2048, 16, 16]               0
#         ResNet50-183  [[-1, 64, 256, 256], [-1, 256, 128, 128], [-1, 512, 64, 64], [-1, 1024, 32, 32], [-1, 2048, 16, 16]]               0
#  ConvTranspose2d-184           [4, 512, 32, 32]      16,777,728
#           Conv2d-185           [4, 256, 32, 32]         393,472
#           Conv2d-186           [4, 256, 32, 32]         590,080
#  ConvTranspose2d-187           [4, 256, 64, 64]       1,048,832
#         Upsample-188           [4, 256, 64, 64]               0
#           Conv2d-189           [4, 128, 64, 64]          98,432
#           Conv2d-190           [4, 128, 64, 64]         147,584
#  ConvTranspose2d-191         [4, 128, 128, 128]         262,272
#         Upsample-192         [4, 128, 128, 128]               0
#           Conv2d-193          [4, 64, 128, 128]          24,640
#           Conv2d-194          [4, 64, 128, 128]          36,928
#  ConvTranspose2d-195          [4, 64, 256, 256]          65,600
#         Upsample-196          [4, 64, 256, 256]               0
#           Conv2d-197          [4, 32, 256, 256]           4,128
#           Conv2d-198          [4, 32, 256, 256]           9,248
#  ConvTranspose2d-199          [4, 32, 512, 512]          16,416
#         Upsample-200          [4, 32, 512, 512]               0
#           Conv2d-201          [4, 32, 512, 512]           9,248
#           Conv2d-202           [4, 7, 512, 512]             231
# ================================================================
# Total params: 47,916,615
# Trainable params: 47,916,615
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 12.00
# Forward/backward pass size (MB): 7662.07
# Params size (MB): 182.79
# Estimated Total Size (MB): 7856.86
# ----------------------------------------------------------------

# %%
class TextLoss(nn.Module):

    def __init__(self):
        super().__init__()

        
    def ohem(self, predict, target, train_mask, negative_ratio=3.):
        pos = (target * train_mask).bool()
        neg = ((1 - target) * train_mask).bool()

        n_pos = pos.float().sum()

        if n_pos.item() > 0:
            loss_pos = F.cross_entropy(predict[pos], target[pos], reduction='sum')
            loss_neg = F.cross_entropy(predict[neg], target[neg], reduction='none')
            
            n_neg = min(int(neg.float().sum().item()), int(negative_ratio * n_pos.float()))
        else:
            loss_pos = torch.tensor(0.).to(predict.device)
            loss_neg = F.cross_entropy(predict[neg], target[neg].long(), reduction='none')
                        
            n_neg = 100
        loss_neg, _ = torch.topk(loss_neg, n_neg)

        return (loss_pos + loss_neg.sum()) / (n_pos + n_neg).float()

    
    def forward(self, input, tr_mask, tcl_mask, sin_map, cos_map, radii_map, train_mask):
        tr_pred = input[:, :2].permute(0, 2, 3, 1).contiguous().view(-1, 2)
        tcl_pred = input[:, 2:4].permute(0, 2, 3, 1).contiguous().view(-1, 2)
        sin_pred = input[:, 4].contiguous().view(-1)
        cos_pred = input[:, 5].contiguous().view(-1)

        scale = torch.sqrt(1.0 / (sin_pred ** 2 + cos_pred ** 2))
        sin_pred = sin_pred * scale
        cos_pred = cos_pred * scale

        radii_pred = input[:, 6].contiguous().view(-1)

        batch_size = tr_pred.size(0)
        height, width = tr_mask.size(-2), tr_mask.size(-1)

        train_mask = train_mask.view(-1)
        tr_mask = tr_mask.view(-1)
        tcl_mask = tcl_mask.view(-1)
        sin_map = sin_map.view(-1)
        cos_map = cos_map.view(-1)
        radii_map = radii_map.view(-1)

        loss_tr = self.ohem(tr_pred, tr_mask, train_mask)
        

        loss_tcl = 0.
        tr_train_mask = train_mask * tr_mask
        if tr_train_mask.sum().item() > 0:
            loss_tcl = F.cross_entropy(tcl_pred[tr_train_mask], tcl_mask[tr_train_mask].long())

        loss_radii, loss_sin, loss_cos = 0., 0., 0.
        tcl_train_mask = train_mask * tcl_mask
        if tcl_train_mask.sum().item() > 0:
            ones = radii_map.new(radii_pred[tcl_train_mask].size()).fill_(1.).float()
            loss_radii = F.smooth_l1_loss(radii_pred[tcl_train_mask] / radii_map[tcl_train_mask], ones)
            loss_sin = F.smooth_l1_loss(sin_pred[tcl_train_mask], sin_map[tcl_train_mask])
            loss_cos = F.smooth_l1_loss(cos_pred[tcl_train_mask], cos_map[tcl_train_mask])

        return loss_tr, loss_tcl, loss_radii, loss_sin, loss_cos

# %%
lr=None
train_step=0

def save_model(model, epoch, lr, optimzer):

    save_dir = os.path.join(cfg.save_dir, cfg.exp_name)
    if not os.path.exists(save_dir):
        mkdirs(save_dir)

    save_path = os.path.join(save_dir, 'textsnake_{}_{}.pth'.format(model.backbone_name, epoch))
    print('Saving to {}.'.format(save_path))
    state_dict = {
        'lr': lr,
        'epoch': epoch,
        'model': model.state_dict() if not cfg.mgpu else model.module.state_dict(),
        'optimizer': optimzer.state_dict()
    }
    torch.save(state_dict, save_path)

# %%
def load_model(model, model_path):
    print('Loading from {}'.format(model_path))
    state_dict = torch.load(model_path)
    model.load_state_dict(state_dict['model'])

# %%
def plot_losses(train_losses, val_losses):
    plt.figure(figsize=(10, 5))
    plt.title("Training and Validation Losses")
    plt.plot(train_losses, label="Training Loss")
    plt.plot(val_losses, label="Validation Loss")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.show()

# %%
def train(model, train_loader, criterion, scheduler, optimizer, epoch, logger):

    global train_step

    losses = AverageMeter()
    batch_time = AverageMeter()
    data_time = AverageMeter()
    end = time.time()
    model.train()
    scheduler.step()

    print('Epoch: {} : LR = {}'.format(epoch, lr))

    for i, (img, train_mask, tr_mask, tcl_mask, radius_map, sin_map, cos_map, meta) in enumerate(train_loader):
        data_time.update(time.time() - end)

        train_step += 1

        img, train_mask, tr_mask, tcl_mask, radius_map, sin_map, cos_map = to_device(
            img, train_mask, tr_mask, tcl_mask, radius_map, sin_map, cos_map)
        
        output = model(img)
        tr_loss, tcl_loss, sin_loss, cos_loss, radii_loss = \
            criterion(output, tr_mask, tcl_mask, sin_map, cos_map, radius_map, train_mask)
        loss = tr_loss + tcl_loss + sin_loss + cos_loss + radii_loss

        # backward
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        losses.update(loss.item())
        # measure elapsed time
        batch_time.update(time.time() - end)
        end = time.time()

        if cfg.viz and i % cfg.viz_freq == 0:
            visualize_network_output(output, tr_mask, tcl_mask, mode='train')

        if i % cfg.display_freq == 0:
            print('({:d} / {:d}) - Loss: {:.4f} - tr_loss: {:.4f} - tcl_loss: {:.4f} - sin_loss: {:.4f} - cos_loss: {:.4f} - radii_loss: {:.4f}'.format(
                i, len(train_loader), loss.item(), tr_loss.item(), tcl_loss.item(), sin_loss.item(), cos_loss.item(), radii_loss.item())
            )

        if i % cfg.log_freq == 0:
            logger.write_scalars({
                'loss': loss.item(),
                'tr_loss': tr_loss.item(),
                'tcl_loss': tcl_loss.item(),
                'sin_loss': sin_loss.item(),
                'cos_loss': cos_loss.item(),
                'radii_loss': radii_loss.item()
            }, tag='train', n_iter=train_step)

    if epoch % cfg.save_freq == 0:
        save_model(model, epoch, scheduler.get_lr(), optimizer)

    print('Training Loss: {}'.format(losses.avg))
    return losses.avg

# %%
def validation(model, valid_loader, criterion, epoch, logger):
    
    with torch.no_grad():
        model.eval()
        losses = AverageMeter()
        tr_losses = AverageMeter()
        tcl_losses = AverageMeter()
        sin_losses = AverageMeter()
        cos_losses = AverageMeter()
        radii_losses = AverageMeter()

        for i, (img, train_mask, tr_mask, tcl_mask, radius_map, sin_map, cos_map, meta) in enumerate(valid_loader):

            img, train_mask, tr_mask, tcl_mask, radius_map, sin_map, cos_map = to_device(
                img, train_mask, tr_mask, tcl_mask, radius_map, sin_map, cos_map)
            
            output = model(img)

            tr_loss, tcl_loss, sin_loss, cos_loss, radii_loss = \
                criterion(output, tr_mask, tcl_mask, sin_map, cos_map, radius_map, train_mask)
            loss = tr_loss + tcl_loss + sin_loss + cos_loss + radii_loss

            # update losses
            losses.update(loss.item())
            tr_losses.update(tr_loss.item())
            tcl_losses.update(tcl_loss.item())
            sin_losses.update(sin_loss.item())
            cos_losses.update(cos_loss.item())
            radii_losses.update(radii_loss.item())

            if cfg.viz and i % cfg.viz_freq == 0:
                visualize_network_output(output, tr_mask, tcl_mask, mode='val')

            if i % cfg.display_freq == 0:
                print(
                    'Validation: - Loss: {:.4f} - tr_loss: {:.4f} - tcl_loss: {:.4f} - sin_loss: {:.4f} - cos_loss: {:.4f} - radii_loss: {:.4f}'.format(
                        loss.item(), tr_loss.item(), tcl_loss.item(), sin_loss.item(),
                        cos_loss.item(), radii_loss.item())
                )

        logger.write_scalars({
            'loss': losses.avg,
            'tr_loss': tr_losses.avg,
            'tcl_loss': tcl_losses.avg,
            'sin_loss': sin_losses.avg,
            'cos_loss': cos_losses.avg,
            'radii_loss': radii_losses.avg
        }, tag='val', n_iter=epoch)

        print('Validation Loss: {}'.format(losses.avg))
        return losses.avg

# %%
def main():
    
    if mp.get_start_method(allow_none=True) != 'spawn':
        mp.set_start_method('spawn', force=True)
        
    train_losses = []
    val_losses = []
        
    global lr
    print(cfg.dataset)
    
    if cfg.dataset == 'total-text':

        trainset = TotalText(
            data_root='data/total-text',
            ignore_list=None,
            is_training=True,
            transform=Augmentation(size=cfg.input_size, mean=cfg.means, std=cfg.stds)
        )

        valset = TotalText(
            data_root='data/total-text',
            ignore_list=None,
            is_training=False,
            transform=BaseTransform(size=cfg.input_size, mean=cfg.means, std=cfg.stds)
        )

    elif cfg.dataset == 'synth-text':
        trainset = SynthText(
            data_root='data/SynthText',
            is_training=True,
            transform=Augmentation(size=cfg.input_size, mean=cfg.means, std=cfg.stds)
        )
        valset = None
    else:
        pass

    train_loader = data.DataLoader(trainset, batch_size=cfg.batch_size, shuffle=True, num_workers=cfg.num_workers)
    if valset:
        val_loader = data.DataLoader(valset, batch_size=cfg.batch_size, shuffle=False, num_workers=cfg.num_workers)
    else:
        valset = None

    log_dir = os.path.join(cfg.log_dir, datetime.now().strftime('%b%d_%H-%M-%S_') + cfg.exp_name)
    logger = LogSummary(log_dir)

    # Model
    model = TextNet(is_training=True, backbone='resnet', output_channel=7)
        
    if cfg.mgpu:
        model = nn.DataParallel(model)

    model = model.to(cfg.device)

    
    if cfg.cuda:
        cudnn.benchmark = True

    if cfg.resume:
        load_model(model, cfg.resume)

    criterion = TextLoss()
    lr = cfg.lr
    optimizer = torch.optim.Adam(model.parameters(), lr=cfg.lr)

    if cfg.dataset == 'synth-text':
        scheduler = FixLR(optimizer)
    else:
        scheduler = lr_scheduler.StepLR(optimizer, step_size=100, gamma=0.1)

    print('Start training TextSnake.')
    
    for epoch in range(cfg.start_epoch, cfg.max_epoch):
        # train(model, train_loader, criterion, scheduler, optimizer, epoch, logger)
        train_loss=train(model, train_loader, criterion, scheduler, optimizer, epoch, logger)
        train_losses.append(train_loss)
        
        if valset:
            # validation(model, val_loader, criterion, epoch, logger)
            val_loss=validation(model, val_loader, criterion, epoch, logger)
            val_losses.append(val_loss)
            
    print('End.')
    
    plot_losses(train_losses, val_losses)

# %%
option = BaseOptions()
command_line_args = ["resnet_STN_LATE", "--viz", "--net", "resnet", "--cuda", "True"]


args = option.initialize(command_line_args)


update_config(cfg, args)
print_config(cfg)


main()
# Out:
# total-text
# ==========Options============
# num_workers: 8
# batch_size: 4
# max_epoch: 201
# start_epoch: 0
# lr: 0.0001
# cuda: True
# n_disk: 15
# output_dir: output
# input_size: 512
# max_annotation: 200
# max_points: 20
# use_hard: True
# tr_thresh: 0.6
# tcl_thresh: 0.4
# post_process_expand: 0.3
# post_process_merge: False
# dataset: total-text
# device: cuda
# vis_dir: ./vis/
# save_dir: ./save/
# exp_name: resnet_STN_LATE
# net: resnet
# resume: None
# mgpu: False
# log_dir: ./logs/
# loss: CrossEntropyLoss
# input_channel: 1
# pretrain: False
# verbose: True
# viz: True
# start_iter: 0
# lr_adjust: fix
# stepvalues: []
# weight_decay: 0.0
# gamma: 0.1
# momentum: 0.9
# optim: SGD
# display_freq: 50
# viz_freq: 50
# save_freq: 50
# log_freq: 100
# val_freq: 100
# rescale: 255.0
# means: [0.485, 0.456, 0.406]
# stds: [0.229, 0.224, 0.225]
# checkepoch: -1
# img_root: None
# =============End=============
# total-text
# Start training TextSnake.
# Epoch: 0 : LR = 0.0001
# (0 / 314) - Loss: 2.9989 - tr_loss: 0.6382 - tcl_loss: 0.7132 - sin_loss: 0.4954 - cos_loss: 0.8601 - radii_loss: 0.2919
# (50 / 314) - Loss: 2.7125 - tr_loss: 0.6300 - tcl_loss: 0.6996 - sin_loss: 0.4975 - cos_loss: 0.5140 - radii_loss: 0.3714
# (100 / 314) - Loss: 2.9138 - tr_loss: 0.6249 - tcl_loss: 0.6850 - sin_loss: 0.4977 - cos_loss: 0.8072 - radii_loss: 0.2989
# (150 / 314) - Loss: 3.0770 - tr_loss: 0.6335 - tcl_loss: 0.5761 - sin_loss: 0.4886 - cos_loss: 0.1834 - radii_loss: 1.1954
# (200 / 314) - Loss: 2.3113 - tr_loss: 0.5959 - tcl_loss: 0.5481 - sin_loss: 0.4534 - cos_loss: 0.3617 - radii_loss: 0.3522
# (250 / 314) - Loss: 2.4662 - tr_loss: 0.5011 - tcl_loss: 0.5058 - sin_loss: 0.4570 - cos_loss: 0.0431 - radii_loss: 0.9593
# (300 / 314) - Loss: 2.6705 - tr_loss: 0.5513 - tcl_loss: 0.4801 - sin_loss: 0.4048 - cos_loss: 0.0462 - radii_loss: 1.1881
# Saving to ./save/resnet_STN_LATE/textsnake_resnet_0.pth.
# Training Loss: 2.5454084216409427
# Validation: - Loss: 1.6305 - tr_loss: 0.5144 - tcl_loss: 0.4824 - sin_loss: 0.3169 - cos_loss: 0.0755 - radii_loss: 0.2413
# Validation: - Loss: 2.4008 - tr_loss: 0.5470 - tcl_loss: 0.5170 - sin_loss: 0.2647 - cos_loss: 0.2193 - radii_loss: 0.8529
# Validation Loss: 1.7190420325597127
# Epoch: 1 : LR = 0.0001
# (0 / 314) - Loss: 2.5655 - tr_loss: 0.4840 - tcl_loss: 0.4432 - sin_loss: 0.4202 - cos_loss: 0.0641 - radii_loss: 1.1539
# (50 / 314) - Loss: 1.5273 - tr_loss: 0.4946 - tcl_loss: 0.5356 - sin_loss: 0.1250 - cos_loss: 0.1631 - radii_loss: 0.2091
# (100 / 314) - Loss: 2.6771 - tr_loss: 0.5481 - tcl_loss: 0.5043 - sin_loss: 0.1905 - cos_loss: 0.0387 - radii_loss: 1.3956
# (150 / 314) - Loss: 1.7361 - tr_loss: 0.5090 - tcl_loss: 0.5545 - sin_loss: 0.1408 - cos_loss: 0.0972 - radii_loss: 0.4347
# (200 / 314) - Loss: 1.8042 - tr_loss: 0.5323 - tcl_loss: 0.5264 - sin_loss: 0.0966 - cos_loss: 0.1183 - radii_loss: 0.5306
# (250 / 314) - Loss: 1.9907 - tr_loss: 0.5051 - tcl_loss: 0.5267 - sin_loss: 0.0510 - cos_loss: 0.0759 - radii_loss: 0.8320
# (300 / 314) - Loss: 1.9674 - tr_loss: 0.5743 - tcl_loss: 0.5070 - sin_loss: 0.2516 - cos_loss: 0.1390 - radii_loss: 0.4956
# Training Loss: 2.0315893546790833
# Validation: - Loss: 1.4943 - tr_loss: 0.5732 - tcl_loss: 0.5581 - sin_loss: 0.0465 - cos_loss: 0.0753 - radii_loss: 0.2412
# Validation: - Loss: 2.2789 - tr_loss: 0.5806 - tcl_loss: 0.5708 - sin_loss: 0.0517 - cos_loss: 0.2231 - radii_loss: 0.8528
# Validation Loss: 1.5755213403701782
# Epoch: 2 : LR = 0.0001
# (0 / 314) - Loss: 2.0277 - tr_loss: 0.5006 - tcl_loss: 0.5505 - sin_loss: 0.2517 - cos_loss: 0.1988 - radii_loss: 0.5262
# (50 / 314) - Loss: 1.5686 - tr_loss: 0.5617 - tcl_loss: 0.5070 - sin_loss: 0.0507 - cos_loss: 0.0980 - radii_loss: 0.3511
# (100 / 314) - Loss: 1.3136 - tr_loss: 0.5363 - tcl_loss: 0.5006 - sin_loss: 0.0839 - cos_loss: 0.0860 - radii_loss: 0.1068
# (150 / 314) - Loss: 1.9967 - tr_loss: 0.5191 - tcl_loss: 0.5242 - sin_loss: 0.1243 - cos_loss: 0.1553 - radii_loss: 0.6737
# (200 / 314) - Loss: 1.4847 - tr_loss: 0.5005 - tcl_loss: 0.4974 - sin_loss: 0.0618 - cos_loss: 0.0680 - radii_loss: 0.3570
# (250 / 314) - Loss: 2.2502 - tr_loss: 0.5001 - tcl_loss: 0.5103 - sin_loss: 0.0477 - cos_loss: 0.0448 - radii_loss: 1.1473
# (300 / 314) - Loss: 1.9364 - tr_loss: 0.5412 - tcl_loss: 0.4961 - sin_loss: 0.2909 - cos_loss: 0.1325 - radii_loss: 0.4758
# Training Loss: 1.9719620753245748
# Validation: - Loss: 1.3643 - tr_loss: 0.5421 - tcl_loss: 0.4554 - sin_loss: 0.0487 - cos_loss: 0.0775 - radii_loss: 0.2404
# Validation: - Loss: 2.1859 - tr_loss: 0.5806 - tcl_loss: 0.4816 - sin_loss: 0.0425 - cos_loss: 0.2308 - radii_loss: 0.8504
# Validation Loss: 1.4607485564549765
# Epoch: 3 : LR = 0.0001
# (0 / 314) - Loss: 1.8550 - tr_loss: 0.5067 - tcl_loss: 0.4851 - sin_loss: 0.0967 - cos_loss: 0.1187 - radii_loss: 0.6477
# (50 / 314) - Loss: 2.4062 - tr_loss: 0.5269 - tcl_loss: 0.5147 - sin_loss: 0.2255 - cos_loss: 0.3576 - radii_loss: 0.7815
# (100 / 314) - Loss: 1.4291 - tr_loss: 0.5311 - tcl_loss: 0.4930 - sin_loss: 0.1232 - cos_loss: 0.0494 - radii_loss: 0.2325
# (150 / 314) - Loss: 1.7581 - tr_loss: 0.5128 - tcl_loss: 0.4963 - sin_loss: 0.0634 - cos_loss: 0.1292 - radii_loss: 0.5563
# (200 / 314) - Loss: 1.9842 - tr_loss: 0.4447 - tcl_loss: 0.4531 - sin_loss: 0.0868 - cos_loss: 0.1259 - radii_loss: 0.8737
# (250 / 314) - Loss: 2.0492 - tr_loss: 0.5325 - tcl_loss: 0.4224 - sin_loss: 0.0585 - cos_loss: 0.0924 - radii_loss: 0.9434
# (300 / 314) - Loss: 2.0881 - tr_loss: 0.5193 - tcl_loss: 0.4713 - sin_loss: 0.0900 - cos_loss: 0.1104 - radii_loss: 0.8971
# Training Loss: 1.9207759381859166
# Validation: - Loss: 1.2512 - tr_loss: 0.5040 - tcl_loss: 0.3766 - sin_loss: 0.0532 - cos_loss: 0.0767 - radii_loss: 0.2408
# Validation: - Loss: 2.1248 - tr_loss: 0.5586 - tcl_loss: 0.4299 - sin_loss: 0.0577 - cos_loss: 0.2270 - radii_loss: 0.8516
# Validation Loss: 1.4115470814704896
# Epoch: 4 : LR = 0.0001
# (0 / 314) - Loss: 1.8902 - tr_loss: 0.5116 - tcl_loss: 0.4892 - sin_loss: 0.1157 - cos_loss: 0.2916 - radii_loss: 0.4821
# (50 / 314) - Loss: 2.1390 - tr_loss: 0.5519 - tcl_loss: 0.5475 - sin_loss: 0.2486 - cos_loss: 0.0816 - radii_loss: 0.7094
# (100 / 314) - Loss: 1.4469 - tr_loss: 0.5347 - tcl_loss: 0.4842 - sin_loss: 0.1297 - cos_loss: 0.1810 - radii_loss: 0.1173
# (150 / 314) - Loss: 2.0914 - tr_loss: 0.5095 - tcl_loss: 0.4779 - sin_loss: 0.1058 - cos_loss: 0.0409 - radii_loss: 0.9575
# (200 / 314) - Loss: 2.1837 - tr_loss: 0.5608 - tcl_loss: 0.4899 - sin_loss: 0.2718 - cos_loss: 0.1130 - radii_loss: 0.7482
# (250 / 314) - Loss: 1.7102 - tr_loss: 0.4986 - tcl_loss: 0.3991 - sin_loss: 0.0769 - cos_loss: 0.0368 - radii_loss: 0.6988
# (300 / 314) - Loss: 2.2919 - tr_loss: 0.5192 - tcl_loss: 0.4896 - sin_loss: 0.0361 - cos_loss: 0.0721 - radii_loss: 1.1748
# Training Loss: 1.8570477913139731
# Validation: - Loss: 1.1551 - tr_loss: 0.4650 - tcl_loss: 0.3267 - sin_loss: 0.0449 - cos_loss: 0.0782 - radii_loss: 0.2403
# Validation: - Loss: 2.0137 - tr_loss: 0.4916 - tcl_loss: 0.3831 - sin_loss: 0.0576 - cos_loss: 0.2310 - radii_loss: 0.8504
# Validation Loss: 1.3319694248835245
# Epoch: 5 : LR = 0.0001
# (0 / 314) - Loss: 2.0726 - tr_loss: 0.4214 - tcl_loss: 0.3513 - sin_loss: 0.0525 - cos_loss: 0.0408 - radii_loss: 1.2066
# (50 / 314) - Loss: 2.4866 - tr_loss: 0.4565 - tcl_loss: 0.4374 - sin_loss: 0.1295 - cos_loss: 0.1730 - radii_loss: 1.2903
# (100 / 314) - Loss: 1.8981 - tr_loss: 0.4493 - tcl_loss: 0.4023 - sin_loss: 0.0685 - cos_loss: 0.0971 - radii_loss: 0.8808
# (150 / 314) - Loss: 2.4688 - tr_loss: 0.5934 - tcl_loss: 0.4187 - sin_loss: 0.2395 - cos_loss: 0.0929 - radii_loss: 1.1243
# (200 / 314) - Loss: 2.4385 - tr_loss: 0.5065 - tcl_loss: 0.4516 - sin_loss: 0.0592 - cos_loss: 0.0593 - radii_loss: 1.3619
# (250 / 314) - Loss: 1.7594 - tr_loss: 0.4310 - tcl_loss: 0.4306 - sin_loss: 0.0933 - cos_loss: 0.0713 - radii_loss: 0.7332
# (300 / 314) - Loss: 1.9124 - tr_loss: 0.4535 - tcl_loss: 0.4152 - sin_loss: 0.2213 - cos_loss: 0.0851 - radii_loss: 0.7373
# Training Loss: 1.8272774553602669
# Validation: - Loss: 1.1303 - tr_loss: 0.4471 - tcl_loss: 0.2974 - sin_loss: 0.0682 - cos_loss: 0.0762 - radii_loss: 0.2414
# Validation: - Loss: 2.0062 - tr_loss: 0.5065 - tcl_loss: 0.3709 - sin_loss: 0.0577 - cos_loss: 0.2178 - radii_loss: 0.8533
# Validation Loss: 1.2926313440004984
# Epoch: 6 : LR = 0.0001
# (0 / 314) - Loss: 2.7560 - tr_loss: 0.5094 - tcl_loss: 0.5320 - sin_loss: 0.2575 - cos_loss: 0.1086 - radii_loss: 1.3486
# (50 / 314) - Loss: 2.3960 - tr_loss: 0.4604 - tcl_loss: 0.4278 - sin_loss: 0.1363 - cos_loss: 0.1102 - radii_loss: 1.2613
# (100 / 314) - Loss: 2.2553 - tr_loss: 0.4909 - tcl_loss: 0.4047 - sin_loss: 0.1230 - cos_loss: 0.2650 - radii_loss: 0.9717
# (150 / 314) - Loss: 1.0656 - tr_loss: 0.3484 - tcl_loss: 0.3566 - sin_loss: 0.1225 - cos_loss: 0.0720 - radii_loss: 0.1661
# (200 / 314) - Loss: 1.8452 - tr_loss: 0.3616 - tcl_loss: 0.3270 - sin_loss: 0.0509 - cos_loss: 0.1221 - radii_loss: 0.9835
# (250 / 314) - Loss: 1.5746 - tr_loss: 0.4030 - tcl_loss: 0.4170 - sin_loss: 0.1312 - cos_loss: 0.1366 - radii_loss: 0.4868
# (300 / 314) - Loss: 1.8825 - tr_loss: 0.3376 - tcl_loss: 0.2904 - sin_loss: 0.0445 - cos_loss: 0.1055 - radii_loss: 1.1046
# Training Loss: 1.8183667050425414
# Validation: - Loss: 0.9741 - tr_loss: 0.3017 - tcl_loss: 0.3074 - sin_loss: 0.0481 - cos_loss: 0.0757 - radii_loss: 0.2412
# Validation: - Loss: 1.9200 - tr_loss: 0.4093 - tcl_loss: 0.3529 - sin_loss: 0.0832 - cos_loss: 0.2216 - radii_loss: 0.8530
# Validation Loss: 1.1994439061482747
# Epoch: 7 : LR = 0.0001
# (0 / 314) - Loss: 1.2485 - tr_loss: 0.3590 - tcl_loss: 0.4216 - sin_loss: 0.1848 - cos_loss: 0.0318 - radii_loss: 0.2512
# (50 / 314) - Loss: 1.9579 - tr_loss: 0.3906 - tcl_loss: 0.3718 - sin_loss: 0.1177 - cos_loss: 0.1358 - radii_loss: 0.9419
# (100 / 314) - Loss: 1.5764 - tr_loss: 0.3521 - tcl_loss: 0.3188 - sin_loss: 0.0788 - cos_loss: 0.1600 - radii_loss: 0.6667
# (150 / 314) - Loss: 1.0918 - tr_loss: 0.4055 - tcl_loss: 0.3741 - sin_loss: 0.0288 - cos_loss: 0.0325 - radii_loss: 0.2509
# (200 / 314) - Loss: 2.0918 - tr_loss: 0.4425 - tcl_loss: 0.5245 - sin_loss: 0.1254 - cos_loss: 0.1238 - radii_loss: 0.8757
# (250 / 314) - Loss: 2.2857 - tr_loss: 0.5739 - tcl_loss: 0.3690 - sin_loss: 0.0507 - cos_loss: 0.1106 - radii_loss: 1.1816
# (300 / 314) - Loss: 0.9548 - tr_loss: 0.2492 - tcl_loss: 0.3237 - sin_loss: 0.0378 - cos_loss: 0.1718 - radii_loss: 0.1722
# Training Loss: 1.6383078054637665
# Validation: - Loss: 0.9026 - tr_loss: 0.2483 - tcl_loss: 0.3099 - sin_loss: 0.0254 - cos_loss: 0.0786 - radii_loss: 0.2404
# Validation: - Loss: 1.8460 - tr_loss: 0.3588 - tcl_loss: 0.3677 - sin_loss: 0.0349 - cos_loss: 0.2357 - radii_loss: 0.8490
# Validation Loss: 1.1003659168879192
# Epoch: 8 : LR = 0.0001
# (0 / 314) - Loss: 2.0574 - tr_loss: 0.2173 - tcl_loss: 0.3136 - sin_loss: 0.0692 - cos_loss: 0.0798 - radii_loss: 1.3776
# (50 / 314) - Loss: 1.1241 - tr_loss: 0.3539 - tcl_loss: 0.3818 - sin_loss: 0.0337 - cos_loss: 0.0530 - radii_loss: 0.3017
# (100 / 314) - Loss: 1.8616 - tr_loss: 0.2332 - tcl_loss: 0.3625 - sin_loss: 0.0214 - cos_loss: 0.0465 - radii_loss: 1.1979
# (150 / 314) - Loss: 1.0330 - tr_loss: 0.4143 - tcl_loss: 0.3157 - sin_loss: 0.0292 - cos_loss: 0.0379 - radii_loss: 0.2359
# (200 / 314) - Loss: 1.1563 - tr_loss: 0.2832 - tcl_loss: 0.2998 - sin_loss: 0.0661 - cos_loss: 0.0333 - radii_loss: 0.4739
# (250 / 314) - Loss: 0.8946 - tr_loss: 0.3283 - tcl_loss: 0.4106 - sin_loss: 0.0691 - cos_loss: 0.0320 - radii_loss: 0.0547
# (300 / 314) - Loss: 1.0837 - tr_loss: 0.1987 - tcl_loss: 0.3741 - sin_loss: 0.0402 - cos_loss: 0.1307 - radii_loss: 0.3400
# Training Loss: 1.6465138755026896
# Validation: - Loss: 0.8099 - tr_loss: 0.2075 - tcl_loss: 0.2640 - sin_loss: 0.0212 - cos_loss: 0.0764 - radii_loss: 0.2407
# Validation: - Loss: 1.7412 - tr_loss: 0.2752 - tcl_loss: 0.3389 - sin_loss: 0.0410 - cos_loss: 0.2375 - radii_loss: 0.8485
# Validation Loss: 1.0928352109591166
# Epoch: 9 : LR = 0.0001
# (0 / 314) - Loss: 1.8794 - tr_loss: 0.4355 - tcl_loss: 0.4059 - sin_loss: 0.1324 - cos_loss: 0.0895 - radii_loss: 0.8160
# (50 / 314) - Loss: 1.4735 - tr_loss: 0.2209 - tcl_loss: 0.3450 - sin_loss: 0.0404 - cos_loss: 0.0833 - radii_loss: 0.7838
# (100 / 314) - Loss: 1.8988 - tr_loss: 0.4413 - tcl_loss: 0.5295 - sin_loss: 0.2164 - cos_loss: 0.0876 - radii_loss: 0.6240
# (150 / 314) - Loss: 1.7620 - tr_loss: 0.3387 - tcl_loss: 0.3487 - sin_loss: 0.0294 - cos_loss: 0.1110 - radii_loss: 0.9343
# (200 / 314) - Loss: 2.0872 - tr_loss: 0.4090 - tcl_loss: 0.4005 - sin_loss: 0.0567 - cos_loss: 0.1338 - radii_loss: 1.0872
# (250 / 314) - Loss: 1.9211 - tr_loss: 0.2940 - tcl_loss: 0.3469 - sin_loss: 0.0369 - cos_loss: 0.1276 - radii_loss: 1.1157
# (300 / 314) - Loss: 1.4779 - tr_loss: 0.3806 - tcl_loss: 0.4869 - sin_loss: 0.0749 - cos_loss: 0.0726 - radii_loss: 0.4629
# Training Loss: 1.570896541237072
# Validation: - Loss: 0.8285 - tr_loss: 0.1931 - tcl_loss: 0.2927 - sin_loss: 0.0244 - cos_loss: 0.0774 - radii_loss: 0.2409
# Validation: - Loss: 1.6914 - tr_loss: 0.2585 - tcl_loss: 0.3288 - sin_loss: 0.0246 - cos_loss: 0.2275 - radii_loss: 0.8520
# Validation Loss: 1.0805577953656516
# Epoch: 10 : LR = 0.0001
# (0 / 314) - Loss: 1.1797 - tr_loss: 0.2584 - tcl_loss: 0.3943 - sin_loss: 0.0244 - cos_loss: 0.0661 - radii_loss: 0.4364
# (50 / 314) - Loss: 2.1137 - tr_loss: 0.3683 - tcl_loss: 0.3995 - sin_loss: 0.0654 - cos_loss: 0.0431 - radii_loss: 1.2374
# (100 / 314) - Loss: 1.8458 - tr_loss: 0.2755 - tcl_loss: 0.3010 - sin_loss: 0.0247 - cos_loss: 0.0576 - radii_loss: 1.1870
# (150 / 314) - Loss: 2.0202 - tr_loss: 0.4279 - tcl_loss: 0.3378 - sin_loss: 0.0895 - cos_loss: 0.0524 - radii_loss: 1.1125
# (200 / 314) - Loss: 2.0816 - tr_loss: 0.4363 - tcl_loss: 0.3594 - sin_loss: 0.0441 - cos_loss: 0.0851 - radii_loss: 1.1567
# (250 / 314) - Loss: 1.6210 - tr_loss: 0.6367 - tcl_loss: 0.5081 - sin_loss: 0.1450 - cos_loss: 0.1604 - radii_loss: 0.1708
# (300 / 314) - Loss: 1.6963 - tr_loss: 0.2332 - tcl_loss: 0.3168 - sin_loss: 0.0332 - cos_loss: 0.1046 - radii_loss: 1.0085
# Training Loss: 1.5603317274789141
# Validation: - Loss: 0.7588 - tr_loss: 0.1535 - tcl_loss: 0.2651 - sin_loss: 0.0224 - cos_loss: 0.0768 - radii_loss: 0.2411
# Validation: - Loss: 1.6762 - tr_loss: 0.2187 - tcl_loss: 0.3490 - sin_loss: 0.0294 - cos_loss: 0.2269 - radii_loss: 0.8523
# Validation Loss: 1.035475761493047
# Epoch: 11 : LR = 0.0001
# (0 / 314) - Loss: 1.0326 - tr_loss: 0.2505 - tcl_loss: 0.3095 - sin_loss: 0.0250 - cos_loss: 0.1450 - radii_loss: 0.3025
# (50 / 314) - Loss: 1.8706 - tr_loss: 0.2355 - tcl_loss: 0.3115 - sin_loss: 0.0247 - cos_loss: 0.1223 - radii_loss: 1.1767
# (100 / 314) - Loss: 1.5188 - tr_loss: 0.2098 - tcl_loss: 0.3992 - sin_loss: 0.0265 - cos_loss: 0.1427 - radii_loss: 0.7406
# (150 / 314) - Loss: 1.7440 - tr_loss: 0.6157 - tcl_loss: 0.5270 - sin_loss: 0.2982 - cos_loss: 0.2349 - radii_loss: 0.0683
# (200 / 314) - Loss: 0.9108 - tr_loss: 0.1988 - tcl_loss: 0.2885 - sin_loss: 0.0163 - cos_loss: 0.0483 - radii_loss: 0.3589
# (250 / 314) - Loss: 2.0329 - tr_loss: 0.2337 - tcl_loss: 0.3697 - sin_loss: 0.0572 - cos_loss: 0.1054 - radii_loss: 1.2669
# (300 / 314) - Loss: 1.2377 - tr_loss: 0.1659 - tcl_loss: 0.2856 - sin_loss: 0.0250 - cos_loss: 0.1400 - radii_loss: 0.6211
# Training Loss: 1.5389750597962908
# Validation: - Loss: 0.7377 - tr_loss: 0.1623 - tcl_loss: 0.2433 - sin_loss: 0.0149 - cos_loss: 0.0762 - radii_loss: 0.2410
# Validation: - Loss: 1.6794 - tr_loss: 0.2537 - tcl_loss: 0.3196 - sin_loss: 0.0323 - cos_loss: 0.2212 - radii_loss: 0.8525
# Validation Loss: 0.9908635731538137
# Epoch: 12 : LR = 0.0001
# (0 / 314) - Loss: 1.4574 - tr_loss: 0.2581 - tcl_loss: 0.4022 - sin_loss: 0.0213 - cos_loss: 0.2182 - radii_loss: 0.5577
# (50 / 314) - Loss: 1.9999 - tr_loss: 0.2421 - tcl_loss: 0.3796 - sin_loss: 0.0248 - cos_loss: 0.0503 - radii_loss: 1.3030
# (100 / 314) - Loss: 1.3533 - tr_loss: 0.2984 - tcl_loss: 0.3251 - sin_loss: 0.0323 - cos_loss: 0.0714 - radii_loss: 0.6260
# (150 / 314) - Loss: 1.6292 - tr_loss: 0.2441 - tcl_loss: 0.3818 - sin_loss: 0.1895 - cos_loss: 0.1415 - radii_loss: 0.6723
# (200 / 314) - Loss: 0.8346 - tr_loss: 0.2565 - tcl_loss: 0.2859 - sin_loss: 0.0226 - cos_loss: 0.0572 - radii_loss: 0.2124
# (250 / 314) - Loss: 0.9924 - tr_loss: 0.2464 - tcl_loss: 0.4204 - sin_loss: 0.0255 - cos_loss: 0.1002 - radii_loss: 0.1999
# (300 / 314) - Loss: 1.1585 - tr_loss: 0.4212 - tcl_loss: 0.4223 - sin_loss: 0.1054 - cos_loss: 0.0339 - radii_loss: 0.1757
# Training Loss: 1.5291500717970976
# Validation: - Loss: 0.7440 - tr_loss: 0.1744 - tcl_loss: 0.2368 - sin_loss: 0.0147 - cos_loss: 0.0771 - radii_loss: 0.2409
# Validation: - Loss: 1.6783 - tr_loss: 0.2444 - tcl_loss: 0.3252 - sin_loss: 0.0365 - cos_loss: 0.2197 - radii_loss: 0.8524
# Validation Loss: 0.9938651049137115
# Epoch: 13 : LR = 0.0001
# (0 / 314) - Loss: 2.1368 - tr_loss: 0.2878 - tcl_loss: 0.4310 - sin_loss: 0.0965 - cos_loss: 0.1688 - radii_loss: 1.1527
# (50 / 314) - Loss: 1.6400 - tr_loss: 0.3421 - tcl_loss: 0.3916 - sin_loss: 0.0571 - cos_loss: 0.1926 - radii_loss: 0.6567
# (100 / 314) - Loss: 0.9479 - tr_loss: 0.3012 - tcl_loss: 0.3476 - sin_loss: 0.0387 - cos_loss: 0.1488 - radii_loss: 0.1116
# (150 / 314) - Loss: 1.4102 - tr_loss: 0.2827 - tcl_loss: 0.4884 - sin_loss: 0.0406 - cos_loss: 0.1839 - radii_loss: 0.4145
# (200 / 314) - Loss: 1.1572 - tr_loss: 0.3711 - tcl_loss: 0.3621 - sin_loss: 0.0549 - cos_loss: 0.1217 - radii_loss: 0.2473
# (250 / 314) - Loss: 1.5993 - tr_loss: 0.4521 - tcl_loss: 0.4337 - sin_loss: 0.0421 - cos_loss: 0.1656 - radii_loss: 0.5058
# (300 / 314) - Loss: 1.3398 - tr_loss: 0.3866 - tcl_loss: 0.3096 - sin_loss: 0.0214 - cos_loss: 0.0758 - radii_loss: 0.5464
# Training Loss: 1.495761912909283
# Validation: - Loss: 0.7198 - tr_loss: 0.1555 - tcl_loss: 0.2395 - sin_loss: 0.0080 - cos_loss: 0.0758 - radii_loss: 0.2410
# Validation: - Loss: 1.6227 - tr_loss: 0.2091 - tcl_loss: 0.3136 - sin_loss: 0.0261 - cos_loss: 0.2212 - radii_loss: 0.8526
# Validation Loss: 0.9809510072072347
# Epoch: 14 : LR = 0.0001
# (0 / 314) - Loss: 2.0030 - tr_loss: 0.1694 - tcl_loss: 0.3446 - sin_loss: 0.0160 - cos_loss: 0.0955 - radii_loss: 1.3776
# (50 / 314) - Loss: 1.1895 - tr_loss: 0.2407 - tcl_loss: 0.3915 - sin_loss: 0.0205 - cos_loss: 0.1337 - radii_loss: 0.4031
# (100 / 314) - Loss: 1.0238 - tr_loss: 0.1896 - tcl_loss: 0.3327 - sin_loss: 0.0390 - cos_loss: 0.0550 - radii_loss: 0.4075
# (150 / 314) - Loss: 1.2168 - tr_loss: 0.2204 - tcl_loss: 0.3201 - sin_loss: 0.0122 - cos_loss: 0.2193 - radii_loss: 0.4449
# (200 / 314) - Loss: 1.9468 - tr_loss: 0.5097 - tcl_loss: 0.4274 - sin_loss: 0.0627 - cos_loss: 0.2130 - radii_loss: 0.7341
# (250 / 314) - Loss: 1.7057 - tr_loss: 0.3165 - tcl_loss: 0.4213 - sin_loss: 0.0396 - cos_loss: 0.1800 - radii_loss: 0.7483
# (300 / 314) - Loss: 1.0873 - tr_loss: 0.2093 - tcl_loss: 0.3717 - sin_loss: 0.0248 - cos_loss: 0.1364 - radii_loss: 0.3451
# Training Loss: 1.4680834564433736
# Validation: - Loss: 0.7636 - tr_loss: 0.1771 - tcl_loss: 0.2295 - sin_loss: 0.0357 - cos_loss: 0.0827 - radii_loss: 0.2386
# Validation: - Loss: 1.6995 - tr_loss: 0.2277 - tcl_loss: 0.3191 - sin_loss: 0.0557 - cos_loss: 0.2520 - radii_loss: 0.8451
# Validation Loss: 1.027969757715861
# Epoch: 15 : LR = 0.0001
# (0 / 314) - Loss: 2.2333 - tr_loss: 0.4355 - tcl_loss: 0.4482 - sin_loss: 0.1237 - cos_loss: 0.0384 - radii_loss: 1.1875
# (50 / 314) - Loss: 1.6694 - tr_loss: 0.2203 - tcl_loss: 0.3450 - sin_loss: 0.0405 - cos_loss: 0.0182 - radii_loss: 1.0453
# (100 / 314) - Loss: 1.2923 - tr_loss: 0.2271 - tcl_loss: 0.2583 - sin_loss: 0.0145 - cos_loss: 0.0549 - radii_loss: 0.7375
# (150 / 314) - Loss: 1.6721 - tr_loss: 0.2232 - tcl_loss: 0.2728 - sin_loss: 0.0122 - cos_loss: 0.1498 - radii_loss: 1.0141
# (200 / 314) - Loss: 2.0268 - tr_loss: 0.4636 - tcl_loss: 0.4833 - sin_loss: 0.0710 - cos_loss: 0.0595 - radii_loss: 0.9494
# (250 / 314) - Loss: 1.7426 - tr_loss: 0.3146 - tcl_loss: 0.3180 - sin_loss: 0.0229 - cos_loss: 0.1182 - radii_loss: 0.9689
# (300 / 314) - Loss: 1.4592 - tr_loss: 0.2651 - tcl_loss: 0.4332 - sin_loss: 0.0206 - cos_loss: 0.1295 - radii_loss: 0.6108
# Training Loss: 1.4994069231543572
# Validation: - Loss: 0.7898 - tr_loss: 0.2142 - tcl_loss: 0.2496 - sin_loss: 0.0088 - cos_loss: 0.0763 - radii_loss: 0.2409
# Validation: - Loss: 1.7915 - tr_loss: 0.3661 - tcl_loss: 0.3161 - sin_loss: 0.0310 - cos_loss: 0.2260 - radii_loss: 0.8523
# Validation Loss: 1.041801054875056
# Epoch: 16 : LR = 0.0001
# (0 / 314) - Loss: 1.5321 - tr_loss: 0.2246 - tcl_loss: 0.2810 - sin_loss: 0.0184 - cos_loss: 0.0676 - radii_loss: 0.9404
# (50 / 314) - Loss: 1.4396 - tr_loss: 0.4251 - tcl_loss: 0.3426 - sin_loss: 0.0104 - cos_loss: 0.0501 - radii_loss: 0.6113
# (100 / 314) - Loss: 0.6231 - tr_loss: 0.3144 - tcl_loss: 0.2752 - sin_loss: 0.0140 - cos_loss: 0.0189 - radii_loss: 0.0006
# (150 / 314) - Loss: 1.2619 - tr_loss: 0.2612 - tcl_loss: 0.3727 - sin_loss: 0.0384 - cos_loss: 0.1680 - radii_loss: 0.4217
# (200 / 314) - Loss: 0.7503 - tr_loss: 0.2141 - tcl_loss: 0.3019 - sin_loss: 0.0318 - cos_loss: 0.0889 - radii_loss: 0.1135
# (250 / 314) - Loss: 2.0274 - tr_loss: 0.2732 - tcl_loss: 0.3493 - sin_loss: 0.0909 - cos_loss: 0.1187 - radii_loss: 1.1953
# (300 / 314) - Loss: 1.8563 - tr_loss: 0.2699 - tcl_loss: 0.3291 - sin_loss: 0.0318 - cos_loss: 0.1175 - radii_loss: 1.1080
# Training Loss: 1.4311964435941855
# Validation: - Loss: 0.6995 - tr_loss: 0.1536 - tcl_loss: 0.2183 - sin_loss: 0.0104 - cos_loss: 0.0766 - radii_loss: 0.2405
# Validation: - Loss: 1.6668 - tr_loss: 0.2749 - tcl_loss: 0.2806 - sin_loss: 0.0293 - cos_loss: 0.2319 - radii_loss: 0.8500
# Validation Loss: 0.9337592693169912
# Epoch: 17 : LR = 0.0001
# (0 / 314) - Loss: 0.7578 - tr_loss: 0.3138 - tcl_loss: 0.2523 - sin_loss: 0.0115 - cos_loss: 0.1587 - radii_loss: 0.0215
# (50 / 314) - Loss: 0.8177 - tr_loss: 0.1887 - tcl_loss: 0.3354 - sin_loss: 0.0277 - cos_loss: 0.1850 - radii_loss: 0.0809
# (100 / 314) - Loss: 1.1829 - tr_loss: 0.1982 - tcl_loss: 0.3015 - sin_loss: 0.0630 - cos_loss: 0.1491 - radii_loss: 0.4710
# (150 / 314) - Loss: 1.9090 - tr_loss: 0.2797 - tcl_loss: 0.3197 - sin_loss: 0.0623 - cos_loss: 0.0853 - radii_loss: 1.1619
# (200 / 314) - Loss: 1.5299 - tr_loss: 0.3512 - tcl_loss: 0.3134 - sin_loss: 0.0244 - cos_loss: 0.1139 - radii_loss: 0.7271
# (250 / 314) - Loss: 1.8990 - tr_loss: 0.2280 - tcl_loss: 0.2909 - sin_loss: 0.0194 - cos_loss: 0.1830 - radii_loss: 1.1776
# (300 / 314) - Loss: 1.6304 - tr_loss: 0.1997 - tcl_loss: 0.3459 - sin_loss: 0.0839 - cos_loss: 0.1140 - radii_loss: 0.8869
# Training Loss: 1.426696597011226
# Validation: - Loss: 0.7176 - tr_loss: 0.1494 - tcl_loss: 0.2425 - sin_loss: 0.0094 - cos_loss: 0.0752 - radii_loss: 0.2411
# Validation: - Loss: 1.6110 - tr_loss: 0.1979 - tcl_loss: 0.3147 - sin_loss: 0.0227 - cos_loss: 0.2229 - radii_loss: 0.8528
# Validation Loss: 0.9476529892285664
# Epoch: 18 : LR = 0.0001
# (0 / 314) - Loss: 1.7134 - tr_loss: 0.1837 - tcl_loss: 0.3387 - sin_loss: 0.0413 - cos_loss: 0.1762 - radii_loss: 0.9735
# (50 / 314) - Loss: 1.2391 - tr_loss: 0.1403 - tcl_loss: 0.2649 - sin_loss: 0.0119 - cos_loss: 0.0624 - radii_loss: 0.7595
# (100 / 314) - Loss: 1.8380 - tr_loss: 0.1757 - tcl_loss: 0.3068 - sin_loss: 0.0173 - cos_loss: 0.1173 - radii_loss: 1.2210
# (150 / 314) - Loss: 1.1569 - tr_loss: 0.1848 - tcl_loss: 0.2881 - sin_loss: 0.0218 - cos_loss: 0.0931 - radii_loss: 0.5690
# (200 / 314) - Loss: 0.7592 - tr_loss: 0.1425 - tcl_loss: 0.2285 - sin_loss: 0.0167 - cos_loss: 0.0550 - radii_loss: 0.3165
# (250 / 314) - Loss: 1.0628 - tr_loss: 0.2147 - tcl_loss: 0.2502 - sin_loss: 0.0175 - cos_loss: 0.1442 - radii_loss: 0.4362
# (300 / 314) - Loss: 1.5440 - tr_loss: 0.2172 - tcl_loss: 0.4732 - sin_loss: 0.0453 - cos_loss: 0.0551 - radii_loss: 0.7531
# Training Loss: 1.400674313686456
# Validation: - Loss: 0.7106 - tr_loss: 0.1359 - tcl_loss: 0.2488 - sin_loss: 0.0094 - cos_loss: 0.0755 - radii_loss: 0.2410
# Validation: - Loss: 1.6386 - tr_loss: 0.2225 - tcl_loss: 0.3163 - sin_loss: 0.0220 - cos_loss: 0.2256 - radii_loss: 0.8522
# Validation Loss: 0.9440985643863677
# Epoch: 19 : LR = 0.0001
# (0 / 314) - Loss: 1.9281 - tr_loss: 0.2159 - tcl_loss: 0.3067 - sin_loss: 0.0141 - cos_loss: 0.0457 - radii_loss: 1.3457
# (50 / 314) - Loss: 0.6002 - tr_loss: 0.1917 - tcl_loss: 0.3093 - sin_loss: 0.0144 - cos_loss: 0.0788 - radii_loss: 0.0060
# (100 / 314) - Loss: 1.3449 - tr_loss: 0.2012 - tcl_loss: 0.2820 - sin_loss: 0.0151 - cos_loss: 0.0486 - radii_loss: 0.7981
# (150 / 314) - Loss: 0.8982 - tr_loss: 0.1701 - tcl_loss: 0.2952 - sin_loss: 0.0084 - cos_loss: 0.1298 - radii_loss: 0.2947
# (200 / 314) - Loss: 1.2208 - tr_loss: 0.1821 - tcl_loss: 0.3152 - sin_loss: 0.0297 - cos_loss: 0.0253 - radii_loss: 0.6685
# (250 / 314) - Loss: 1.5215 - tr_loss: 0.1743 - tcl_loss: 0.3175 - sin_loss: 0.0269 - cos_loss: 0.0960 - radii_loss: 0.9069
# (300 / 314) - Loss: 0.8983 - tr_loss: 0.2065 - tcl_loss: 0.2761 - sin_loss: 0.0314 - cos_loss: 0.1117 - radii_loss: 0.2726
# Training Loss: 1.3986677662202507
# Validation: - Loss: 0.7645 - tr_loss: 0.1697 - tcl_loss: 0.2414 - sin_loss: 0.0343 - cos_loss: 0.0786 - radii_loss: 0.2405
# Validation: - Loss: 1.6843 - tr_loss: 0.2804 - tcl_loss: 0.3054 - sin_loss: 0.0278 - cos_loss: 0.2184 - radii_loss: 0.8521
# Validation Loss: 0.9753660321235657
# Epoch: 20 : LR = 0.0001
# (0 / 314) - Loss: 1.3265 - tr_loss: 0.2918 - tcl_loss: 0.3024 - sin_loss: 0.0283 - cos_loss: 0.0803 - radii_loss: 0.6238
# (50 / 314) - Loss: 1.9644 - tr_loss: 0.2105 - tcl_loss: 0.2494 - sin_loss: 0.0246 - cos_loss: 0.0544 - radii_loss: 1.4255
# (100 / 314) - Loss: 1.0209 - tr_loss: 0.2009 - tcl_loss: 0.3162 - sin_loss: 0.0289 - cos_loss: 0.1124 - radii_loss: 0.3625
# (150 / 314) - Loss: 1.0776 - tr_loss: 0.2803 - tcl_loss: 0.3582 - sin_loss: 0.0413 - cos_loss: 0.0333 - radii_loss: 0.3646
# (200 / 314) - Loss: 1.8691 - tr_loss: 0.2908 - tcl_loss: 0.2948 - sin_loss: 0.0319 - cos_loss: 0.0381 - radii_loss: 1.2135
# (250 / 314) - Loss: 1.6477 - tr_loss: 0.3943 - tcl_loss: 0.3524 - sin_loss: 0.0421 - cos_loss: 0.1489 - radii_loss: 0.7100
# (300 / 314) - Loss: 1.5881 - tr_loss: 0.5044 - tcl_loss: 0.3858 - sin_loss: 0.0854 - cos_loss: 0.0635 - radii_loss: 0.5490
# Training Loss: 1.4333576158543302
# Validation: - Loss: 0.6985 - tr_loss: 0.1506 - tcl_loss: 0.2223 - sin_loss: 0.0084 - cos_loss: 0.0759 - radii_loss: 0.2413
# Validation: - Loss: 1.6979 - tr_loss: 0.2922 - tcl_loss: 0.3044 - sin_loss: 0.0246 - cos_loss: 0.2245 - radii_loss: 0.8521
# Validation Loss: 0.9563946851094564
# Epoch: 21 : LR = 0.0001
# (0 / 314) - Loss: 1.2666 - tr_loss: 0.2946 - tcl_loss: 0.4105 - sin_loss: 0.0687 - cos_loss: 0.1936 - radii_loss: 0.2993
# (50 / 314) - Loss: 1.2713 - tr_loss: 0.2089 - tcl_loss: 0.2256 - sin_loss: 0.0064 - cos_loss: 0.0976 - radii_loss: 0.7329
# (100 / 314) - Loss: 1.9595 - tr_loss: 0.2333 - tcl_loss: 0.3941 - sin_loss: 0.0225 - cos_loss: 0.1008 - radii_loss: 1.2088
# (150 / 314) - Loss: 1.9485 - tr_loss: 0.2759 - tcl_loss: 0.4051 - sin_loss: 0.0350 - cos_loss: 0.0753 - radii_loss: 1.1572
# (200 / 314) - Loss: 0.7312 - tr_loss: 0.1991 - tcl_loss: 0.2544 - sin_loss: 0.0313 - cos_loss: 0.0653 - radii_loss: 0.1812
# (250 / 314) - Loss: 0.8463 - tr_loss: 0.1604 - tcl_loss: 0.3104 - sin_loss: 0.0407 - cos_loss: 0.0773 - radii_loss: 0.2576
# (300 / 314) - Loss: 1.5108 - tr_loss: 0.4208 - tcl_loss: 0.3535 - sin_loss: 0.0206 - cos_loss: 0.1370 - radii_loss: 0.5790
# Training Loss: 1.4179580287568887
# Validation: - Loss: 0.9235 - tr_loss: 0.2701 - tcl_loss: 0.3010 - sin_loss: 0.0210 - cos_loss: 0.0945 - radii_loss: 0.2368
# Validation: - Loss: 1.6366 - tr_loss: 0.2161 - tcl_loss: 0.3141 - sin_loss: 0.0239 - cos_loss: 0.2318 - radii_loss: 0.8507
# Validation Loss: 0.9976796646912892
# Epoch: 22 : LR = 0.0001
# (0 / 314) - Loss: 1.6898 - tr_loss: 0.3061 - tcl_loss: 0.3783 - sin_loss: 0.0271 - cos_loss: 0.2244 - radii_loss: 0.7538
# (50 / 314) - Loss: 1.9660 - tr_loss: 0.2105 - tcl_loss: 0.3175 - sin_loss: 0.0372 - cos_loss: 0.0564 - radii_loss: 1.3444
# (100 / 314) - Loss: 1.2461 - tr_loss: 0.1886 - tcl_loss: 0.3977 - sin_loss: 0.0334 - cos_loss: 0.1140 - radii_loss: 0.5124
# (150 / 314) - Loss: 1.5739 - tr_loss: 0.3145 - tcl_loss: 0.3860 - sin_loss: 0.1102 - cos_loss: 0.0936 - radii_loss: 0.6696
# (200 / 314) - Loss: 0.6554 - tr_loss: 0.1829 - tcl_loss: 0.3389 - sin_loss: 0.0182 - cos_loss: 0.0952 - radii_loss: 0.0201
# (250 / 314) - Loss: 1.5097 - tr_loss: 0.2673 - tcl_loss: 0.3886 - sin_loss: 0.0714 - cos_loss: 0.1318 - radii_loss: 0.6506
# (300 / 314) - Loss: 0.9558 - tr_loss: 0.2236 - tcl_loss: 0.3220 - sin_loss: 0.0290 - cos_loss: 0.0817 - radii_loss: 0.2996
# Training Loss: 1.4365114109341506
# Validation: - Loss: 0.7088 - tr_loss: 0.1542 - tcl_loss: 0.2291 - sin_loss: 0.0086 - cos_loss: 0.0758 - radii_loss: 0.2411
# Validation: - Loss: 1.6462 - tr_loss: 0.2457 - tcl_loss: 0.2927 - sin_loss: 0.0276 - cos_loss: 0.2281 - radii_loss: 0.8521
# Validation Loss: 0.9633992107709249
# Epoch: 23 : LR = 0.0001
# (0 / 314) - Loss: 1.1428 - tr_loss: 0.2051 - tcl_loss: 0.3581 - sin_loss: 0.0417 - cos_loss: 0.1300 - radii_loss: 0.4080
# (50 / 314) - Loss: 1.6305 - tr_loss: 0.2243 - tcl_loss: 0.3296 - sin_loss: 0.0230 - cos_loss: 0.2386 - radii_loss: 0.8150
# (100 / 314) - Loss: 2.0428 - tr_loss: 0.1886 - tcl_loss: 0.3877 - sin_loss: 0.0471 - cos_loss: 0.0772 - radii_loss: 1.3422
# (150 / 314) - Loss: 1.0008 - tr_loss: 0.2172 - tcl_loss: 0.3653 - sin_loss: 0.0219 - cos_loss: 0.2106 - radii_loss: 0.1857
# (200 / 314) - Loss: 1.6471 - tr_loss: 0.1596 - tcl_loss: 0.2446 - sin_loss: 0.0229 - cos_loss: 0.0563 - radii_loss: 1.1636
# (250 / 314) - Loss: 2.0089 - tr_loss: 0.2072 - tcl_loss: 0.3913 - sin_loss: 0.0560 - cos_loss: 0.1289 - radii_loss: 1.2255
# (300 / 314) - Loss: 1.8800 - tr_loss: 0.3017 - tcl_loss: 0.3547 - sin_loss: 0.0527 - cos_loss: 0.0264 - radii_loss: 1.1446
# Training Loss: 1.4362074440451944
# Validation: - Loss: 0.6886 - tr_loss: 0.1453 - tcl_loss: 0.2175 - sin_loss: 0.0092 - cos_loss: 0.0756 - radii_loss: 0.2410
# Validation: - Loss: 1.6181 - tr_loss: 0.2229 - tcl_loss: 0.2948 - sin_loss: 0.0198 - cos_loss: 0.2288 - radii_loss: 0.8518
# Validation Loss: 0.9273540782928467
# Epoch: 24 : LR = 0.0001
# (0 / 314) - Loss: 0.7889 - tr_loss: 0.2540 - tcl_loss: 0.2853 - sin_loss: 0.0099 - cos_loss: 0.0438 - radii_loss: 0.1959
# (50 / 314) - Loss: 1.6743 - tr_loss: 0.2614 - tcl_loss: 0.3227 - sin_loss: 0.0510 - cos_loss: 0.2448 - radii_loss: 0.7944
# (100 / 314) - Loss: 1.5217 - tr_loss: 0.5275 - tcl_loss: 0.3413 - sin_loss: 0.0923 - cos_loss: 0.1976 - radii_loss: 0.3630
# (150 / 314) - Loss: 1.6310 - tr_loss: 0.2119 - tcl_loss: 0.3465 - sin_loss: 0.0237 - cos_loss: 0.1559 - radii_loss: 0.8931
# (200 / 314) - Loss: 1.4873 - tr_loss: 0.1953 - tcl_loss: 0.2802 - sin_loss: 0.0342 - cos_loss: 0.0572 - radii_loss: 0.9204
# (250 / 314) - Loss: 1.7152 - tr_loss: 0.1960 - tcl_loss: 0.2940 - sin_loss: 0.0157 - cos_loss: 0.0503 - radii_loss: 1.1592
# (300 / 314) - Loss: 1.1876 - tr_loss: 0.1296 - tcl_loss: 0.3251 - sin_loss: 0.0215 - cos_loss: 0.0447 - radii_loss: 0.6667
# Training Loss: 1.384479563896823
# Validation: - Loss: 0.6581 - tr_loss: 0.1185 - tcl_loss: 0.2110 - sin_loss: 0.0121 - cos_loss: 0.0754 - radii_loss: 0.2410
# Validation: - Loss: 1.6314 - tr_loss: 0.2477 - tcl_loss: 0.2880 - sin_loss: 0.0192 - cos_loss: 0.2245 - radii_loss: 0.8519
# Validation Loss: 0.9209634761015574
# Epoch: 25 : LR = 0.0001
# (0 / 314) - Loss: 1.3042 - tr_loss: 0.1666 - tcl_loss: 0.3526 - sin_loss: 0.0324 - cos_loss: 0.1681 - radii_loss: 0.5846
# (50 / 314) - Loss: 1.0624 - tr_loss: 0.3462 - tcl_loss: 0.2875 - sin_loss: 0.0327 - cos_loss: 0.0947 - radii_loss: 0.3012
# (100 / 314) - Loss: 1.6077 - tr_loss: 0.3814 - tcl_loss: 0.3699 - sin_loss: 0.0365 - cos_loss: 0.0888 - radii_loss: 0.7312
# (150 / 314) - Loss: 2.1188 - tr_loss: 0.4824 - tcl_loss: 0.5162 - sin_loss: 0.0403 - cos_loss: 0.1865 - radii_loss: 0.8933
# (200 / 314) - Loss: 1.4554 - tr_loss: 0.3356 - tcl_loss: 0.3877 - sin_loss: 0.0172 - cos_loss: 0.1145 - radii_loss: 0.6005
# (250 / 314) - Loss: 0.8716 - tr_loss: 0.3485 - tcl_loss: 0.2448 - sin_loss: 0.0278 - cos_loss: 0.0335 - radii_loss: 0.2169
# (300 / 314) - Loss: 0.9932 - tr_loss: 0.1308 - tcl_loss: 0.3171 - sin_loss: 0.0242 - cos_loss: 0.0907 - radii_loss: 0.4304
# Training Loss: 1.4035801229773053
# Validation: - Loss: 0.7131 - tr_loss: 0.1729 - tcl_loss: 0.2140 - sin_loss: 0.0094 - cos_loss: 0.0758 - radii_loss: 0.2410
# Validation: - Loss: 1.6768 - tr_loss: 0.2718 - tcl_loss: 0.3033 - sin_loss: 0.0261 - cos_loss: 0.2229 - radii_loss: 0.8527
# Validation Loss: 0.9768178308010101
# Epoch: 26 : LR = 0.0001
# (0 / 314) - Loss: 1.8114 - tr_loss: 0.2190 - tcl_loss: 0.4719 - sin_loss: 0.0204 - cos_loss: 0.0682 - radii_loss: 1.0321
# (50 / 314) - Loss: 1.6056 - tr_loss: 0.2612 - tcl_loss: 0.4328 - sin_loss: 0.0336 - cos_loss: 0.0679 - radii_loss: 0.8100
# (100 / 314) - Loss: 1.8050 - tr_loss: 0.1606 - tcl_loss: 0.2484 - sin_loss: 0.0360 - cos_loss: 0.1480 - radii_loss: 1.2121
# (150 / 314) - Loss: 1.4256 - tr_loss: 0.1328 - tcl_loss: 0.2848 - sin_loss: 0.0138 - cos_loss: 0.1267 - radii_loss: 0.8675
# (200 / 314) - Loss: 0.9221 - tr_loss: 0.1503 - tcl_loss: 0.2645 - sin_loss: 0.0123 - cos_loss: 0.0952 - radii_loss: 0.3999
# (250 / 314) - Loss: 1.2968 - tr_loss: 0.2211 - tcl_loss: 0.3504 - sin_loss: 0.0325 - cos_loss: 0.1137 - radii_loss: 0.5791
# (300 / 314) - Loss: 0.7864 - tr_loss: 0.1756 - tcl_loss: 0.3175 - sin_loss: 0.0153 - cos_loss: 0.0504 - radii_loss: 0.2276
# Training Loss: 1.3749041115022769
# Validation: - Loss: 0.6738 - tr_loss: 0.1222 - tcl_loss: 0.2214 - sin_loss: 0.0131 - cos_loss: 0.0760 - radii_loss: 0.2412
# Validation: - Loss: 1.5995 - tr_loss: 0.1853 - tcl_loss: 0.2975 - sin_loss: 0.0381 - cos_loss: 0.2265 - radii_loss: 0.8521
# Validation Loss: 0.9297015583515167
# Epoch: 27 : LR = 0.0001
# (0 / 314) - Loss: 1.6089 - tr_loss: 0.1791 - tcl_loss: 0.3350 - sin_loss: 0.0333 - cos_loss: 0.1108 - radii_loss: 0.9507
# (50 / 314) - Loss: 1.3720 - tr_loss: 0.1745 - tcl_loss: 0.3435 - sin_loss: 0.0093 - cos_loss: 0.2858 - radii_loss: 0.5590
# (100 / 314) - Loss: 0.6438 - tr_loss: 0.1703 - tcl_loss: 0.2456 - sin_loss: 0.0071 - cos_loss: 0.0843 - radii_loss: 0.1365
# (150 / 314) - Loss: 1.8558 - tr_loss: 0.2063 - tcl_loss: 0.2725 - sin_loss: 0.0435 - cos_loss: 0.0861 - radii_loss: 1.2474
# (200 / 314) - Loss: 1.8791 - tr_loss: 0.4278 - tcl_loss: 0.4445 - sin_loss: 0.0515 - cos_loss: 0.1122 - radii_loss: 0.8430
# (250 / 314) - Loss: 0.5819 - tr_loss: 0.1080 - tcl_loss: 0.2431 - sin_loss: 0.0153 - cos_loss: 0.0363 - radii_loss: 0.1794
# (300 / 314) - Loss: 1.0184 - tr_loss: 0.2191 - tcl_loss: 0.3505 - sin_loss: 0.0330 - cos_loss: 0.1666 - radii_loss: 0.2493
# Training Loss: 1.347383082102818
# Validation: - Loss: 0.6398 - tr_loss: 0.1105 - tcl_loss: 0.2041 - sin_loss: 0.0080 - cos_loss: 0.0767 - radii_loss: 0.2406
# Validation: - Loss: 1.6059 - tr_loss: 0.2072 - tcl_loss: 0.2975 - sin_loss: 0.0221 - cos_loss: 0.2274 - radii_loss: 0.8517
# Validation Loss: 0.9193958826859792
# Epoch: 28 : LR = 0.0001
# (0 / 314) - Loss: 1.8080 - tr_loss: 0.1383 - tcl_loss: 0.2387 - sin_loss: 0.0102 - cos_loss: 0.0467 - radii_loss: 1.3742
# (50 / 314) - Loss: 1.5022 - tr_loss: 0.3414 - tcl_loss: 0.3837 - sin_loss: 0.0397 - cos_loss: 0.1399 - radii_loss: 0.5975
# (100 / 314) - Loss: 1.0890 - tr_loss: 0.2754 - tcl_loss: 0.2805 - sin_loss: 0.0163 - cos_loss: 0.1073 - radii_loss: 0.4096
# (150 / 314) - Loss: 1.1157 - tr_loss: 0.1841 - tcl_loss: 0.3496 - sin_loss: 0.0323 - cos_loss: 0.1872 - radii_loss: 0.3624
# (200 / 314) - Loss: 0.6145 - tr_loss: 0.1330 - tcl_loss: 0.2597 - sin_loss: 0.0100 - cos_loss: 0.0293 - radii_loss: 0.1825
# (250 / 314) - Loss: 1.8621 - tr_loss: 0.2944 - tcl_loss: 0.2562 - sin_loss: 0.0153 - cos_loss: 0.0605 - radii_loss: 1.2357
# (300 / 314) - Loss: 1.2432 - tr_loss: 0.1880 - tcl_loss: 0.2825 - sin_loss: 0.0219 - cos_loss: 0.0922 - radii_loss: 0.6587
# Training Loss: 1.3518782059667975
# Validation: - Loss: 0.6676 - tr_loss: 0.1343 - tcl_loss: 0.2072 - sin_loss: 0.0088 - cos_loss: 0.0761 - radii_loss: 0.2411
# Validation: - Loss: 1.6155 - tr_loss: 0.2105 - tcl_loss: 0.3034 - sin_loss: 0.0207 - cos_loss: 0.2293 - radii_loss: 0.8516
# Validation Loss: 0.9185726789633433
# Epoch: 29 : LR = 0.0001
# (0 / 314) - Loss: 0.6466 - tr_loss: 0.3388 - tcl_loss: 0.2330 - sin_loss: 0.0099 - cos_loss: 0.0285 - radii_loss: 0.0364
# (50 / 314) - Loss: 1.8253 - tr_loss: 0.2287 - tcl_loss: 0.3266 - sin_loss: 0.0154 - cos_loss: 0.1406 - radii_loss: 1.1140
# (100 / 314) - Loss: 2.1664 - tr_loss: 0.3519 - tcl_loss: 0.3399 - sin_loss: 0.0506 - cos_loss: 0.0534 - radii_loss: 1.3706
# (150 / 314) - Loss: 1.5427 - tr_loss: 0.4992 - tcl_loss: 0.3890 - sin_loss: 0.0653 - cos_loss: 0.1922 - radii_loss: 0.3970
# (200 / 314) - Loss: 0.9239 - tr_loss: 0.1003 - tcl_loss: 0.2035 - sin_loss: 0.0109 - cos_loss: 0.0287 - radii_loss: 0.5804
# (250 / 314) - Loss: 1.2314 - tr_loss: 0.3529 - tcl_loss: 0.4458 - sin_loss: 0.1331 - cos_loss: 0.0695 - radii_loss: 0.2301
# (300 / 314) - Loss: 1.6803 - tr_loss: 0.1729 - tcl_loss: 0.2818 - sin_loss: 0.0204 - cos_loss: 0.1946 - radii_loss: 1.0107
# Training Loss: 1.3942986438228826
# Validation: - Loss: 0.7181 - tr_loss: 0.1691 - tcl_loss: 0.2179 - sin_loss: 0.0154 - cos_loss: 0.0748 - radii_loss: 0.2410
# Validation: - Loss: 1.6605 - tr_loss: 0.2746 - tcl_loss: 0.2864 - sin_loss: 0.0254 - cos_loss: 0.2217 - radii_loss: 0.8524
# Validation Loss: 0.9710976648330688
# Epoch: 30 : LR = 0.0001
# (0 / 314) - Loss: 2.3304 - tr_loss: 0.2115 - tcl_loss: 0.5132 - sin_loss: 0.2034 - cos_loss: 0.0599 - radii_loss: 1.3425
# (50 / 314) - Loss: 1.6069 - tr_loss: 0.2268 - tcl_loss: 0.3963 - sin_loss: 0.0802 - cos_loss: 0.2558 - radii_loss: 0.6479
# (100 / 314) - Loss: 1.2767 - tr_loss: 0.2147 - tcl_loss: 0.2547 - sin_loss: 0.0228 - cos_loss: 0.0765 - radii_loss: 0.7080
# (150 / 314) - Loss: 1.8446 - tr_loss: 0.2813 - tcl_loss: 0.3351 - sin_loss: 0.0155 - cos_loss: 0.1330 - radii_loss: 1.0798
# (200 / 314) - Loss: 0.8084 - tr_loss: 0.1601 - tcl_loss: 0.3359 - sin_loss: 0.0266 - cos_loss: 0.0599 - radii_loss: 0.2260
# (250 / 314) - Loss: 0.8375 - tr_loss: 0.1296 - tcl_loss: 0.2434 - sin_loss: 0.0109 - cos_loss: 0.0885 - radii_loss: 0.3649
# (300 / 314) - Loss: 1.6971 - tr_loss: 0.1681 - tcl_loss: 0.2780 - sin_loss: 0.0184 - cos_loss: 0.1133 - radii_loss: 1.1194
# Training Loss: 1.3726510587771228
# Validation: - Loss: 0.7055 - tr_loss: 0.1653 - tcl_loss: 0.2116 - sin_loss: 0.0101 - cos_loss: 0.0775 - radii_loss: 0.2411
# Validation: - Loss: 1.6035 - tr_loss: 0.2232 - tcl_loss: 0.2902 - sin_loss: 0.0165 - cos_loss: 0.2213 - radii_loss: 0.8524
# Validation Loss: 0.9335197679201762
# Epoch: 31 : LR = 0.0001
# (0 / 314) - Loss: 1.4149 - tr_loss: 0.2500 - tcl_loss: 0.3522 - sin_loss: 0.0464 - cos_loss: 0.2779 - radii_loss: 0.4884
# (50 / 314) - Loss: 1.1694 - tr_loss: 0.1953 - tcl_loss: 0.3717 - sin_loss: 0.0270 - cos_loss: 0.1257 - radii_loss: 0.4496
# (100 / 314) - Loss: 0.9758 - tr_loss: 0.1493 - tcl_loss: 0.3038 - sin_loss: 0.0195 - cos_loss: 0.0552 - radii_loss: 0.4481
# (150 / 314) - Loss: 1.5002 - tr_loss: 0.2827 - tcl_loss: 0.3757 - sin_loss: 0.0867 - cos_loss: 0.0688 - radii_loss: 0.6863
# (200 / 314) - Loss: 1.1164 - tr_loss: 0.2372 - tcl_loss: 0.3634 - sin_loss: 0.0393 - cos_loss: 0.1455 - radii_loss: 0.3312
# (250 / 314) - Loss: 2.1370 - tr_loss: 0.2851 - tcl_loss: 0.4777 - sin_loss: 0.1242 - cos_loss: 0.0622 - radii_loss: 1.1877
# (300 / 314) - Loss: 1.9034 - tr_loss: 0.1787 - tcl_loss: 0.4151 - sin_loss: 0.0882 - cos_loss: 0.1634 - radii_loss: 1.0581
# Training Loss: 1.3781172991937893
# Validation: - Loss: 0.6554 - tr_loss: 0.1193 - tcl_loss: 0.2072 - sin_loss: 0.0106 - cos_loss: 0.0776 - radii_loss: 0.2407
# Validation: - Loss: 1.5699 - tr_loss: 0.1868 - tcl_loss: 0.2847 - sin_loss: 0.0223 - cos_loss: 0.2247 - radii_loss: 0.8514
# Validation Loss: 0.9239366336663564
# Epoch: 32 : LR = 0.0001
# (0 / 314) - Loss: 2.0314 - tr_loss: 0.2179 - tcl_loss: 0.4567 - sin_loss: 0.0436 - cos_loss: 0.0616 - radii_loss: 1.2517
# (50 / 314) - Loss: 1.3160 - tr_loss: 0.1668 - tcl_loss: 0.3433 - sin_loss: 0.0240 - cos_loss: 0.0773 - radii_loss: 0.7046
# (100 / 314) - Loss: 1.5479 - tr_loss: 0.2542 - tcl_loss: 0.3346 - sin_loss: 0.0474 - cos_loss: 0.1248 - radii_loss: 0.7869
# (150 / 314) - Loss: 1.2279 - tr_loss: 0.2137 - tcl_loss: 0.2718 - sin_loss: 0.0376 - cos_loss: 0.1557 - radii_loss: 0.5490
# (200 / 314) - Loss: 1.4314 - tr_loss: 0.2068 - tcl_loss: 0.2641 - sin_loss: 0.0191 - cos_loss: 0.0639 - radii_loss: 0.8776
# (250 / 314) - Loss: 0.6723 - tr_loss: 0.1300 - tcl_loss: 0.2358 - sin_loss: 0.0248 - cos_loss: 0.1026 - radii_loss: 0.1792
# (300 / 314) - Loss: 1.3752 - tr_loss: 0.1607 - tcl_loss: 0.2731 - sin_loss: 0.0226 - cos_loss: 0.0710 - radii_loss: 0.8477
# Training Loss: 1.362849332819319
# Validation: - Loss: 0.6464 - tr_loss: 0.1111 - tcl_loss: 0.2095 - sin_loss: 0.0089 - cos_loss: 0.0757 - radii_loss: 0.2411
# Validation: - Loss: 1.5809 - tr_loss: 0.2001 - tcl_loss: 0.2815 - sin_loss: 0.0202 - cos_loss: 0.2278 - radii_loss: 0.8513
# Validation Loss: 0.8947376243273417
# Epoch: 33 : LR = 0.0001
# (0 / 314) - Loss: 0.6969 - tr_loss: 0.1521 - tcl_loss: 0.3480 - sin_loss: 0.0354 - cos_loss: 0.0704 - radii_loss: 0.0910
# (50 / 314) - Loss: 0.8549 - tr_loss: 0.1008 - tcl_loss: 0.2253 - sin_loss: 0.0170 - cos_loss: 0.1523 - radii_loss: 0.3595
# (100 / 314) - Loss: 1.5794 - tr_loss: 0.0961 - tcl_loss: 0.2683 - sin_loss: 0.0118 - cos_loss: 0.0102 - radii_loss: 1.1931
# (150 / 314) - Loss: 1.3528 - tr_loss: 0.2379 - tcl_loss: 0.3184 - sin_loss: 0.0192 - cos_loss: 0.2380 - radii_loss: 0.5392
# (200 / 314) - Loss: 1.7161 - tr_loss: 0.2270 - tcl_loss: 0.3369 - sin_loss: 0.0233 - cos_loss: 0.0762 - radii_loss: 1.0526
# (250 / 314) - Loss: 1.0884 - tr_loss: 0.2634 - tcl_loss: 0.4366 - sin_loss: 0.0857 - cos_loss: 0.0873 - radii_loss: 0.2155
# (300 / 314) - Loss: 0.8144 - tr_loss: 0.1912 - tcl_loss: 0.3775 - sin_loss: 0.0405 - cos_loss: 0.0625 - radii_loss: 0.1426
# Training Loss: 1.2998615365688968
# Validation: - Loss: 0.6613 - tr_loss: 0.1163 - tcl_loss: 0.2170 - sin_loss: 0.0116 - cos_loss: 0.0753 - radii_loss: 0.2412
# Validation: - Loss: 1.5608 - tr_loss: 0.1718 - tcl_loss: 0.2849 - sin_loss: 0.0245 - cos_loss: 0.2285 - radii_loss: 0.8512
# Validation Loss: 0.9049208831787109
# Epoch: 34 : LR = 0.0001
# (0 / 314) - Loss: 1.0144 - tr_loss: 0.1554 - tcl_loss: 0.2921 - sin_loss: 0.0190 - cos_loss: 0.0937 - radii_loss: 0.4543
# (50 / 314) - Loss: 1.0127 - tr_loss: 0.2108 - tcl_loss: 0.2906 - sin_loss: 0.0206 - cos_loss: 0.1345 - radii_loss: 0.3562
# (100 / 314) - Loss: 1.0734 - tr_loss: 0.1496 - tcl_loss: 0.2807 - sin_loss: 0.0114 - cos_loss: 0.1546 - radii_loss: 0.4772
# (150 / 314) - Loss: 1.5731 - tr_loss: 0.2000 - tcl_loss: 0.3168 - sin_loss: 0.0220 - cos_loss: 0.0827 - radii_loss: 0.9515
# (200 / 314) - Loss: 1.3813 - tr_loss: 0.3503 - tcl_loss: 0.3869 - sin_loss: 0.0429 - cos_loss: 0.0837 - radii_loss: 0.5176
# (250 / 314) - Loss: 1.1535 - tr_loss: 0.4177 - tcl_loss: 0.3158 - sin_loss: 0.0449 - cos_loss: 0.1074 - radii_loss: 0.2677
# (300 / 314) - Loss: 1.4859 - tr_loss: 0.5280 - tcl_loss: 0.3579 - sin_loss: 0.0235 - cos_loss: 0.1895 - radii_loss: 0.3869
# Training Loss: 1.3641364480469638
# Validation: - Loss: 0.6880 - tr_loss: 0.1268 - tcl_loss: 0.2326 - sin_loss: 0.0126 - cos_loss: 0.0751 - radii_loss: 0.2410
# Validation: - Loss: 1.6488 - tr_loss: 0.2462 - tcl_loss: 0.2980 - sin_loss: 0.0228 - cos_loss: 0.2301 - radii_loss: 0.8518
# Validation Loss: 0.9188035535812378
# Epoch: 35 : LR = 0.0001
# (0 / 314) - Loss: 0.8317 - tr_loss: 0.2919 - tcl_loss: 0.3483 - sin_loss: 0.0532 - cos_loss: 0.0824 - radii_loss: 0.0560
# (50 / 314) - Loss: 1.4925 - tr_loss: 0.2037 - tcl_loss: 0.3761 - sin_loss: 0.0552 - cos_loss: 0.1918 - radii_loss: 0.6656
# (100 / 314) - Loss: 1.2886 - tr_loss: 0.1075 - tcl_loss: 0.2124 - sin_loss: 0.0150 - cos_loss: 0.0705 - radii_loss: 0.8832
# (150 / 314) - Loss: 0.5792 - tr_loss: 0.1325 - tcl_loss: 0.2560 - sin_loss: 0.0180 - cos_loss: 0.0542 - radii_loss: 0.1184
# (200 / 314) - Loss: 0.6602 - tr_loss: 0.1516 - tcl_loss: 0.2889 - sin_loss: 0.0164 - cos_loss: 0.0601 - radii_loss: 0.1432
# (250 / 314) - Loss: 1.1282 - tr_loss: 0.1560 - tcl_loss: 0.2685 - sin_loss: 0.0220 - cos_loss: 0.0382 - radii_loss: 0.6435
# (300 / 314) - Loss: 2.5024 - tr_loss: 0.4474 - tcl_loss: 0.4861 - sin_loss: 0.1558 - cos_loss: 0.1580 - radii_loss: 1.2550
# Training Loss: 1.3504339498319444
# Validation: - Loss: 0.7071 - tr_loss: 0.1304 - tcl_loss: 0.2425 - sin_loss: 0.0137 - cos_loss: 0.0792 - radii_loss: 0.2412
# Validation: - Loss: 1.6073 - tr_loss: 0.1936 - tcl_loss: 0.2971 - sin_loss: 0.0326 - cos_loss: 0.2333 - radii_loss: 0.8507
# Validation Loss: 0.953752349615097
# Epoch: 36 : LR = 0.0001
# (0 / 314) - Loss: 1.2492 - tr_loss: 0.2140 - tcl_loss: 0.3197 - sin_loss: 0.0469 - cos_loss: 0.1898 - radii_loss: 0.4788
# (50 / 314) - Loss: 1.6713 - tr_loss: 0.2091 - tcl_loss: 0.2597 - sin_loss: 0.0095 - cos_loss: 0.0800 - radii_loss: 1.1130
# (100 / 314) - Loss: 1.5957 - tr_loss: 0.1905 - tcl_loss: 0.2556 - sin_loss: 0.0098 - cos_loss: 0.0850 - radii_loss: 1.0548
# (150 / 314) - Loss: 1.2208 - tr_loss: 0.1807 - tcl_loss: 0.3297 - sin_loss: 0.0140 - cos_loss: 0.1984 - radii_loss: 0.4981
# (200 / 314) - Loss: 1.6429 - tr_loss: 0.2235 - tcl_loss: 0.3258 - sin_loss: 0.0401 - cos_loss: 0.0761 - radii_loss: 0.9775
# (250 / 314) - Loss: 1.6929 - tr_loss: 0.1765 - tcl_loss: 0.3482 - sin_loss: 0.0261 - cos_loss: 0.0373 - radii_loss: 1.1046
# (300 / 314) - Loss: 1.8592 - tr_loss: 0.1745 - tcl_loss: 0.2687 - sin_loss: 0.0231 - cos_loss: 0.0558 - radii_loss: 1.3372
# Training Loss: 1.3805249510866822
# Validation: - Loss: 0.6178 - tr_loss: 0.1014 - tcl_loss: 0.1910 - sin_loss: 0.0079 - cos_loss: 0.0764 - radii_loss: 0.2412
# Validation: - Loss: 1.5625 - tr_loss: 0.1762 - tcl_loss: 0.2897 - sin_loss: 0.0189 - cos_loss: 0.2252 - radii_loss: 0.8525
# Validation Loss: 0.9004395588239034
# Epoch: 37 : LR = 0.0001
# (0 / 314) - Loss: 1.2499 - tr_loss: 0.2665 - tcl_loss: 0.4352 - sin_loss: 0.0611 - cos_loss: 0.1229 - radii_loss: 0.3643
# (50 / 314) - Loss: 1.5744 - tr_loss: 0.1847 - tcl_loss: 0.2673 - sin_loss: 0.0155 - cos_loss: 0.1391 - radii_loss: 0.9677
# (100 / 314) - Loss: 0.6925 - tr_loss: 0.2291 - tcl_loss: 0.2348 - sin_loss: 0.0332 - cos_loss: 0.1069 - radii_loss: 0.0885
# (150 / 314) - Loss: 1.2501 - tr_loss: 0.1931 - tcl_loss: 0.3069 - sin_loss: 0.0388 - cos_loss: 0.1827 - radii_loss: 0.5285
# (200 / 314) - Loss: 1.5831 - tr_loss: 0.2097 - tcl_loss: 0.2995 - sin_loss: 0.0220 - cos_loss: 0.1338 - radii_loss: 0.9182
# (250 / 314) - Loss: 0.6128 - tr_loss: 0.1787 - tcl_loss: 0.2582 - sin_loss: 0.0101 - cos_loss: 0.0628 - radii_loss: 0.1030
# (300 / 314) - Loss: 1.7710 - tr_loss: 0.1623 - tcl_loss: 0.2645 - sin_loss: 0.0239 - cos_loss: 0.0583 - radii_loss: 1.2620
# Training Loss: 1.3468949968457982
# Validation: - Loss: 0.6664 - tr_loss: 0.1305 - tcl_loss: 0.2066 - sin_loss: 0.0116 - cos_loss: 0.0764 - radii_loss: 0.2413
# Validation: - Loss: 1.6053 - tr_loss: 0.2225 - tcl_loss: 0.2845 - sin_loss: 0.0245 - cos_loss: 0.2210 - radii_loss: 0.8528
# Validation Loss: 0.9255442333221435
# Epoch: 38 : LR = 0.0001
# (0 / 314) - Loss: 1.3564 - tr_loss: 0.2180 - tcl_loss: 0.2740 - sin_loss: 0.0386 - cos_loss: 0.0236 - radii_loss: 0.8022
# (50 / 314) - Loss: 1.6729 - tr_loss: 0.1935 - tcl_loss: 0.4195 - sin_loss: 0.0461 - cos_loss: 0.0595 - radii_loss: 0.9543
# (100 / 314) - Loss: 1.4381 - tr_loss: 0.1271 - tcl_loss: 0.2442 - sin_loss: 0.0237 - cos_loss: 0.0760 - radii_loss: 0.9671
# (150 / 314) - Loss: 1.3505 - tr_loss: 0.1516 - tcl_loss: 0.2810 - sin_loss: 0.0369 - cos_loss: 0.0976 - radii_loss: 0.7834
# (200 / 314) - Loss: 0.5495 - tr_loss: 0.1741 - tcl_loss: 0.2261 - sin_loss: 0.0116 - cos_loss: 0.0519 - radii_loss: 0.0857
# (250 / 314) - Loss: 1.7929 - tr_loss: 0.2215 - tcl_loss: 0.3892 - sin_loss: 0.0478 - cos_loss: 0.1897 - radii_loss: 0.9447
# (300 / 314) - Loss: 1.2225 - tr_loss: 0.2777 - tcl_loss: 0.4304 - sin_loss: 0.0173 - cos_loss: 0.1282 - radii_loss: 0.3689
# Training Loss: 1.3196725166717154
# Validation: - Loss: 0.6468 - tr_loss: 0.1140 - tcl_loss: 0.2019 - sin_loss: 0.0143 - cos_loss: 0.0754 - radii_loss: 0.2411
# Validation: - Loss: 1.6182 - tr_loss: 0.1999 - tcl_loss: 0.3161 - sin_loss: 0.0196 - cos_loss: 0.2272 - radii_loss: 0.8554
# Validation Loss: 0.9116955510775249
# Epoch: 39 : LR = 0.0001
# (0 / 314) - Loss: 1.0031 - tr_loss: 0.1275 - tcl_loss: 0.2427 - sin_loss: 0.0156 - cos_loss: 0.1607 - radii_loss: 0.4566
# (50 / 314) - Loss: 2.0631 - tr_loss: 0.2776 - tcl_loss: 0.2797 - sin_loss: 0.0569 - cos_loss: 0.0268 - radii_loss: 1.4220
# ...
# Training Loss: 1.0588930601337154
# Validation: - Loss: 0.6988 - tr_loss: 0.0993 - tcl_loss: 0.1886 - sin_loss: 0.0074 - cos_loss: 0.0813 - radii_loss: 0.3223
# Validation: - Loss: 1.5557 - tr_loss: 0.1598 - tcl_loss: 0.2794 - sin_loss: 0.0160 - cos_loss: 0.2972 - radii_loss: 0.8033
# Validation Loss: 1.0836898537476858
# Epoch: 188 : LR = 0.0001
# (0 / 314) - Loss: 1.1516 - tr_loss: 0.2459 - tcl_loss: 0.2751 - sin_loss: 0.0259 - cos_loss: 0.1869 - radii_loss: 0.4179
# (50 / 314) - Loss: 1.2028 - tr_loss: 0.1124 - tcl_loss: 0.2465 - sin_loss: 0.0120 - cos_loss: 0.1995 - radii_loss: 0.6323
# (100 / 314) - Loss: 1.1693 - tr_loss: 0.1054 - tcl_loss: 0.2153 - sin_loss: 0.0093 - cos_loss: 0.1608 - radii_loss: 0.6785
# (150 / 314) - Loss: 1.1866 - tr_loss: 0.1180 - tcl_loss: 0.2460 - sin_loss: 0.0160 - cos_loss: 0.1295 - radii_loss: 0.6771
# (200 / 314) - Loss: 1.2939 - tr_loss: 0.3023 - tcl_loss: 0.3771 - sin_loss: 0.0311 - cos_loss: 0.0573 - radii_loss: 0.5259
# (250 / 314) - Loss: 0.9740 - tr_loss: 0.1744 - tcl_loss: 0.3305 - sin_loss: 0.0518 - cos_loss: 0.2265 - radii_loss: 0.1908
# (300 / 314) - Loss: 1.0133 - tr_loss: 0.1804 - tcl_loss: 0.2700 - sin_loss: 0.0184 - cos_loss: 0.1031 - radii_loss: 0.4413
# Training Loss: 1.0563278161226564
# Validation: - Loss: 0.7637 - tr_loss: 0.0987 - tcl_loss: 0.1917 - sin_loss: 0.0073 - cos_loss: 0.0826 - radii_loss: 0.3835
# Validation: - Loss: 1.5903 - tr_loss: 0.1587 - tcl_loss: 0.2827 - sin_loss: 0.0170 - cos_loss: 0.2865 - radii_loss: 0.8455
# Validation Loss: 1.194224552710851
# Epoch: 189 : LR = 0.0001
# (0 / 314) - Loss: 1.0705 - tr_loss: 0.1521 - tcl_loss: 0.2819 - sin_loss: 0.0213 - cos_loss: 0.0754 - radii_loss: 0.5397
# (50 / 314) - Loss: 1.3360 - tr_loss: 0.2591 - tcl_loss: 0.3096 - sin_loss: 0.0442 - cos_loss: 0.1607 - radii_loss: 0.5624
# (100 / 314) - Loss: 1.1057 - tr_loss: 0.1323 - tcl_loss: 0.2589 - sin_loss: 0.0100 - cos_loss: 0.0502 - radii_loss: 0.6543
# (150 / 314) - Loss: 0.7591 - tr_loss: 0.1307 - tcl_loss: 0.2569 - sin_loss: 0.0153 - cos_loss: 0.0653 - radii_loss: 0.2909
# (200 / 314) - Loss: 1.0374 - tr_loss: 0.1488 - tcl_loss: 0.2481 - sin_loss: 0.0155 - cos_loss: 0.1019 - radii_loss: 0.5231
# (250 / 314) - Loss: 0.7099 - tr_loss: 0.1000 - tcl_loss: 0.1705 - sin_loss: 0.0078 - cos_loss: 0.0326 - radii_loss: 0.3991
# (300 / 314) - Loss: 0.7442 - tr_loss: 0.0831 - tcl_loss: 0.2076 - sin_loss: 0.0113 - cos_loss: 0.0403 - radii_loss: 0.4019
# Training Loss: 1.0370465590126197
# Validation: - Loss: 0.7591 - tr_loss: 0.0993 - tcl_loss: 0.1876 - sin_loss: 0.0078 - cos_loss: 0.0831 - radii_loss: 0.3814
# Validation: - Loss: 1.5689 - tr_loss: 0.1587 - tcl_loss: 0.2790 - sin_loss: 0.0143 - cos_loss: 0.2995 - radii_loss: 0.8175
# Validation Loss: 1.1524794356028238
# Epoch: 190 : LR = 0.0001
# (0 / 314) - Loss: 1.6734 - tr_loss: 0.1858 - tcl_loss: 0.3346 - sin_loss: 0.0170 - cos_loss: 0.0815 - radii_loss: 1.0546
# (50 / 314) - Loss: 1.6949 - tr_loss: 0.1210 - tcl_loss: 0.2883 - sin_loss: 0.0406 - cos_loss: 0.1853 - radii_loss: 1.0597
# (100 / 314) - Loss: 1.1322 - tr_loss: 0.1421 - tcl_loss: 0.3189 - sin_loss: 0.0150 - cos_loss: 0.0522 - radii_loss: 0.6039
# (150 / 314) - Loss: 1.6733 - tr_loss: 0.1942 - tcl_loss: 0.3499 - sin_loss: 0.0316 - cos_loss: 0.2180 - radii_loss: 0.8795
# (200 / 314) - Loss: 1.1612 - tr_loss: 0.2010 - tcl_loss: 0.2857 - sin_loss: 0.0145 - cos_loss: 0.1321 - radii_loss: 0.5278
# (250 / 314) - Loss: 0.8541 - tr_loss: 0.1182 - tcl_loss: 0.2096 - sin_loss: 0.0084 - cos_loss: 0.0221 - radii_loss: 0.4957
# (300 / 314) - Loss: 0.7537 - tr_loss: 0.1033 - tcl_loss: 0.2091 - sin_loss: 0.0117 - cos_loss: 0.0811 - radii_loss: 0.3486
# Training Loss: 1.0312193408133878
# Validation: - Loss: 0.7843 - tr_loss: 0.1020 - tcl_loss: 0.1899 - sin_loss: 0.0075 - cos_loss: 0.0883 - radii_loss: 0.3966
# Validation: - Loss: 1.5414 - tr_loss: 0.1560 - tcl_loss: 0.2800 - sin_loss: 0.0153 - cos_loss: 0.3203 - radii_loss: 0.7698
# Validation Loss: 1.236820182800293
# Epoch: 191 : LR = 0.0001
# (0 / 314) - Loss: 0.5675 - tr_loss: 0.0936 - tcl_loss: 0.1799 - sin_loss: 0.0131 - cos_loss: 0.0519 - radii_loss: 0.2289
# (50 / 314) - Loss: 1.2911 - tr_loss: 0.1416 - tcl_loss: 0.2506 - sin_loss: 0.0176 - cos_loss: 0.1447 - radii_loss: 0.7366
# (100 / 314) - Loss: 0.9480 - tr_loss: 0.2704 - tcl_loss: 0.2924 - sin_loss: 0.0106 - cos_loss: 0.1736 - radii_loss: 0.2010
# (150 / 314) - Loss: 0.8062 - tr_loss: 0.1355 - tcl_loss: 0.2233 - sin_loss: 0.0148 - cos_loss: 0.0926 - radii_loss: 0.3401
# (200 / 314) - Loss: 0.4939 - tr_loss: 0.0948 - tcl_loss: 0.2002 - sin_loss: 0.0079 - cos_loss: 0.0782 - radii_loss: 0.1128
# (250 / 314) - Loss: 1.4137 - tr_loss: 0.2118 - tcl_loss: 0.2639 - sin_loss: 0.0520 - cos_loss: 0.2223 - radii_loss: 0.6638
# (300 / 314) - Loss: 0.7482 - tr_loss: 0.1165 - tcl_loss: 0.2660 - sin_loss: 0.0177 - cos_loss: 0.0860 - radii_loss: 0.2621
# Training Loss: 1.0470867290808137
# Validation: - Loss: 0.7205 - tr_loss: 0.0991 - tcl_loss: 0.1882 - sin_loss: 0.0072 - cos_loss: 0.0827 - radii_loss: 0.3433
# Validation: - Loss: 1.5688 - tr_loss: 0.1598 - tcl_loss: 0.2777 - sin_loss: 0.0167 - cos_loss: 0.2882 - radii_loss: 0.8263
# Validation Loss: 1.0852442602316539
# Epoch: 192 : LR = 0.0001
# (0 / 314) - Loss: 0.9607 - tr_loss: 0.1229 - tcl_loss: 0.2952 - sin_loss: 0.0305 - cos_loss: 0.1921 - radii_loss: 0.3201
# (50 / 314) - Loss: 0.8391 - tr_loss: 0.1418 - tcl_loss: 0.2187 - sin_loss: 0.0120 - cos_loss: 0.1293 - radii_loss: 0.3373
# (100 / 314) - Loss: 0.7221 - tr_loss: 0.1128 - tcl_loss: 0.2082 - sin_loss: 0.0106 - cos_loss: 0.0415 - radii_loss: 0.3490
# (150 / 314) - Loss: 0.7656 - tr_loss: 0.1353 - tcl_loss: 0.2361 - sin_loss: 0.0092 - cos_loss: 0.0736 - radii_loss: 0.3114
# (200 / 314) - Loss: 1.0388 - tr_loss: 0.2735 - tcl_loss: 0.2813 - sin_loss: 0.0154 - cos_loss: 0.0619 - radii_loss: 0.4068
# (250 / 314) - Loss: 1.2493 - tr_loss: 0.1653 - tcl_loss: 0.2556 - sin_loss: 0.0130 - cos_loss: 0.0828 - radii_loss: 0.7327
# (300 / 314) - Loss: 0.9103 - tr_loss: 0.1417 - tcl_loss: 0.3157 - sin_loss: 0.0209 - cos_loss: 0.0406 - radii_loss: 0.3914
# Training Loss: 1.0095528792233983
# Validation: - Loss: 0.6833 - tr_loss: 0.1003 - tcl_loss: 0.1858 - sin_loss: 0.0068 - cos_loss: 0.0807 - radii_loss: 0.3099
# Validation: - Loss: 1.5601 - tr_loss: 0.1589 - tcl_loss: 0.2772 - sin_loss: 0.0142 - cos_loss: 0.2877 - radii_loss: 0.8221
# Validation Loss: 1.0418480396270753
# Epoch: 193 : LR = 0.0001
# (0 / 314) - Loss: 1.1484 - tr_loss: 0.1034 - tcl_loss: 0.2319 - sin_loss: 0.0130 - cos_loss: 0.0849 - radii_loss: 0.7152
# (50 / 314) - Loss: 1.0358 - tr_loss: 0.1476 - tcl_loss: 0.2627 - sin_loss: 0.0152 - cos_loss: 0.1264 - radii_loss: 0.4840
# (100 / 314) - Loss: 1.3160 - tr_loss: 0.1542 - tcl_loss: 0.3450 - sin_loss: 0.0565 - cos_loss: 0.1833 - radii_loss: 0.5770
# (150 / 314) - Loss: 0.9640 - tr_loss: 0.1421 - tcl_loss: 0.2197 - sin_loss: 0.0158 - cos_loss: 0.0731 - radii_loss: 0.5133
# (200 / 314) - Loss: 0.6659 - tr_loss: 0.1161 - tcl_loss: 0.2251 - sin_loss: 0.0148 - cos_loss: 0.1498 - radii_loss: 0.1601
# (250 / 314) - Loss: 0.9771 - tr_loss: 0.1323 - tcl_loss: 0.2787 - sin_loss: 0.0115 - cos_loss: 0.1755 - radii_loss: 0.3791
# (300 / 314) - Loss: 0.8730 - tr_loss: 0.0989 - tcl_loss: 0.2319 - sin_loss: 0.0146 - cos_loss: 0.1065 - radii_loss: 0.4211
# Training Loss: 1.029306028299271
# Validation: - Loss: 0.7621 - tr_loss: 0.0954 - tcl_loss: 0.1900 - sin_loss: 0.0065 - cos_loss: 0.0819 - radii_loss: 0.3884
# Validation: - Loss: 1.4990 - tr_loss: 0.1573 - tcl_loss: 0.2771 - sin_loss: 0.0176 - cos_loss: 0.2918 - radii_loss: 0.7552
# Validation Loss: 1.2056389458974202
# Epoch: 194 : LR = 0.0001
# (0 / 314) - Loss: 1.0555 - tr_loss: 0.1315 - tcl_loss: 0.2383 - sin_loss: 0.0146 - cos_loss: 0.1441 - radii_loss: 0.5270
# (50 / 314) - Loss: 1.3114 - tr_loss: 0.1911 - tcl_loss: 0.2452 - sin_loss: 0.0134 - cos_loss: 0.0753 - radii_loss: 0.7864
# (100 / 314) - Loss: 1.4837 - tr_loss: 0.1931 - tcl_loss: 0.1686 - sin_loss: 0.0092 - cos_loss: 0.0604 - radii_loss: 1.0523
# (150 / 314) - Loss: 0.9815 - tr_loss: 0.1203 - tcl_loss: 0.2542 - sin_loss: 0.0088 - cos_loss: 0.1357 - radii_loss: 0.4625
# (200 / 314) - Loss: 1.3086 - tr_loss: 0.2252 - tcl_loss: 0.3686 - sin_loss: 0.1000 - cos_loss: 0.1205 - radii_loss: 0.4943
# (250 / 314) - Loss: 0.8232 - tr_loss: 0.1508 - tcl_loss: 0.2166 - sin_loss: 0.0119 - cos_loss: 0.0305 - radii_loss: 0.4134
# (300 / 314) - Loss: 1.1332 - tr_loss: 0.1524 - tcl_loss: 0.2691 - sin_loss: 0.0164 - cos_loss: 0.0755 - radii_loss: 0.6198
# Training Loss: 1.0241621153749478
# Validation: - Loss: 0.6187 - tr_loss: 0.0964 - tcl_loss: 0.1862 - sin_loss: 0.0072 - cos_loss: 0.0780 - radii_loss: 0.2509
# Validation: - Loss: 1.5312 - tr_loss: 0.1671 - tcl_loss: 0.2708 - sin_loss: 0.0145 - cos_loss: 0.2878 - radii_loss: 0.7910
# Validation Loss: 1.0788107148806254
# Epoch: 195 : LR = 0.0001
# (0 / 314) - Loss: 0.8777 - tr_loss: 0.1195 - tcl_loss: 0.2448 - sin_loss: 0.0139 - cos_loss: 0.1585 - radii_loss: 0.3410
# (50 / 314) - Loss: 1.6027 - tr_loss: 0.1741 - tcl_loss: 0.2713 - sin_loss: 0.0126 - cos_loss: 0.4243 - radii_loss: 0.7204
# (100 / 314) - Loss: 1.4427 - tr_loss: 0.1049 - tcl_loss: 0.2122 - sin_loss: 0.0083 - cos_loss: 0.0951 - radii_loss: 1.0222
# (150 / 314) - Loss: 1.1182 - tr_loss: 0.2140 - tcl_loss: 0.3979 - sin_loss: 0.0667 - cos_loss: 0.1757 - radii_loss: 0.2638
# (200 / 314) - Loss: 1.0044 - tr_loss: 0.1207 - tcl_loss: 0.2313 - sin_loss: 0.0129 - cos_loss: 0.1340 - radii_loss: 0.5056
# (250 / 314) - Loss: 1.0300 - tr_loss: 0.1764 - tcl_loss: 0.2599 - sin_loss: 0.0138 - cos_loss: 0.2577 - radii_loss: 0.3222
# (300 / 314) - Loss: 1.6131 - tr_loss: 0.1500 - tcl_loss: 0.3767 - sin_loss: 0.0649 - cos_loss: 0.1865 - radii_loss: 0.8349
# Training Loss: 1.0537028933406636
# Validation: - Loss: 0.6500 - tr_loss: 0.0967 - tcl_loss: 0.1847 - sin_loss: 0.0066 - cos_loss: 0.0787 - radii_loss: 0.2833
# Validation: - Loss: 1.5250 - tr_loss: 0.1634 - tcl_loss: 0.2743 - sin_loss: 0.0172 - cos_loss: 0.2858 - radii_loss: 0.7844
# Validation Loss: 1.091041395664215
# Epoch: 196 : LR = 0.0001
# (0 / 314) - Loss: 1.6798 - tr_loss: 0.1945 - tcl_loss: 0.3405 - sin_loss: 0.0258 - cos_loss: 0.1496 - radii_loss: 0.9695
# (50 / 314) - Loss: 1.2429 - tr_loss: 0.1407 - tcl_loss: 0.2510 - sin_loss: 0.0160 - cos_loss: 0.1422 - radii_loss: 0.6931
# (100 / 314) - Loss: 0.8107 - tr_loss: 0.1081 - tcl_loss: 0.2464 - sin_loss: 0.0108 - cos_loss: 0.0867 - radii_loss: 0.3586
# (150 / 314) - Loss: 0.9705 - tr_loss: 0.1251 - tcl_loss: 0.2234 - sin_loss: 0.0127 - cos_loss: 0.1002 - radii_loss: 0.5091
# (200 / 314) - Loss: 1.1500 - tr_loss: 0.1439 - tcl_loss: 0.3131 - sin_loss: 0.0225 - cos_loss: 0.1250 - radii_loss: 0.5455
# (250 / 314) - Loss: 1.0339 - tr_loss: 0.1742 - tcl_loss: 0.2348 - sin_loss: 0.0085 - cos_loss: 0.0836 - radii_loss: 0.5327
# (300 / 314) - Loss: 0.5520 - tr_loss: 0.1163 - tcl_loss: 0.2143 - sin_loss: 0.0136 - cos_loss: 0.0941 - radii_loss: 0.1137
# Training Loss: 1.044794721303472
# Validation: - Loss: 0.6501 - tr_loss: 0.0931 - tcl_loss: 0.1841 - sin_loss: 0.0064 - cos_loss: 0.0788 - radii_loss: 0.2878
# Validation: - Loss: 1.5400 - tr_loss: 0.1672 - tcl_loss: 0.2775 - sin_loss: 0.0169 - cos_loss: 0.2830 - radii_loss: 0.7955
# Validation Loss: 1.0811545125643411
# Epoch: 197 : LR = 0.0001
# (0 / 314) - Loss: 1.3062 - tr_loss: 0.1438 - tcl_loss: 0.2335 - sin_loss: 0.0228 - cos_loss: 0.1222 - radii_loss: 0.7838
# (50 / 314) - Loss: 1.3764 - tr_loss: 0.1521 - tcl_loss: 0.2533 - sin_loss: 0.0167 - cos_loss: 0.0475 - radii_loss: 0.9068
# (100 / 314) - Loss: 0.7639 - tr_loss: 0.1459 - tcl_loss: 0.2534 - sin_loss: 0.0123 - cos_loss: 0.1088 - radii_loss: 0.2434
# (150 / 314) - Loss: 0.5587 - tr_loss: 0.1173 - tcl_loss: 0.2217 - sin_loss: 0.0094 - cos_loss: 0.1022 - radii_loss: 0.1081
# (200 / 314) - Loss: 0.5093 - tr_loss: 0.0937 - tcl_loss: 0.1977 - sin_loss: 0.0089 - cos_loss: 0.1221 - radii_loss: 0.0869
# (250 / 314) - Loss: 1.1526 - tr_loss: 0.2200 - tcl_loss: 0.2835 - sin_loss: 0.0171 - cos_loss: 0.1214 - radii_loss: 0.5106
# (300 / 314) - Loss: 1.5563 - tr_loss: 0.2278 - tcl_loss: 0.3460 - sin_loss: 0.0769 - cos_loss: 0.0737 - radii_loss: 0.8318
# Training Loss: 1.033152267621581
# Validation: - Loss: 0.7518 - tr_loss: 0.0981 - tcl_loss: 0.1844 - sin_loss: 0.0071 - cos_loss: 0.0805 - radii_loss: 0.3817
# Validation: - Loss: 1.5537 - tr_loss: 0.1597 - tcl_loss: 0.2763 - sin_loss: 0.0147 - cos_loss: 0.3056 - radii_loss: 0.7975
# Validation Loss: 1.165272250175476
# Epoch: 198 : LR = 0.0001
# (0 / 314) - Loss: 0.7399 - tr_loss: 0.1645 - tcl_loss: 0.2867 - sin_loss: 0.0296 - cos_loss: 0.0254 - radii_loss: 0.2337
# (50 / 314) - Loss: 1.2551 - tr_loss: 0.2318 - tcl_loss: 0.2600 - sin_loss: 0.0173 - cos_loss: 0.0687 - radii_loss: 0.6773
# (100 / 314) - Loss: 0.8595 - tr_loss: 0.1196 - tcl_loss: 0.2523 - sin_loss: 0.0088 - cos_loss: 0.1520 - radii_loss: 0.3267
# (150 / 314) - Loss: 0.9247 - tr_loss: 0.1106 - tcl_loss: 0.2404 - sin_loss: 0.0216 - cos_loss: 0.0856 - radii_loss: 0.4665
# (200 / 314) - Loss: 1.0194 - tr_loss: 0.1884 - tcl_loss: 0.2621 - sin_loss: 0.0209 - cos_loss: 0.0874 - radii_loss: 0.4606
# (250 / 314) - Loss: 0.6003 - tr_loss: 0.1202 - tcl_loss: 0.2047 - sin_loss: 0.0144 - cos_loss: 0.0595 - radii_loss: 0.2015
# (300 / 314) - Loss: 1.0269 - tr_loss: 0.1170 - tcl_loss: 0.2496 - sin_loss: 0.0176 - cos_loss: 0.1123 - radii_loss: 0.5303
# Training Loss: 1.0490232551363623
# Validation: - Loss: 0.7300 - tr_loss: 0.0976 - tcl_loss: 0.1837 - sin_loss: 0.0070 - cos_loss: 0.0834 - radii_loss: 0.3584
# Validation: - Loss: 1.5886 - tr_loss: 0.1622 - tcl_loss: 0.2756 - sin_loss: 0.0161 - cos_loss: 0.2940 - radii_loss: 0.8407
# Validation Loss: 1.0756948761145273
# Epoch: 199 : LR = 0.0001
# (0 / 314) - Loss: 1.6397 - tr_loss: 0.1715 - tcl_loss: 0.2951 - sin_loss: 0.0131 - cos_loss: 0.1370 - radii_loss: 1.0230
# (50 / 314) - Loss: 1.1063 - tr_loss: 0.1187 - tcl_loss: 0.2047 - sin_loss: 0.0098 - cos_loss: 0.0643 - radii_loss: 0.7089
# (100 / 314) - Loss: 0.6683 - tr_loss: 0.1268 - tcl_loss: 0.2021 - sin_loss: 0.0096 - cos_loss: 0.0613 - radii_loss: 0.2686
# (150 / 314) - Loss: 0.5612 - tr_loss: 0.0827 - tcl_loss: 0.2004 - sin_loss: 0.0280 - cos_loss: 0.0436 - radii_loss: 0.2066
# (200 / 314) - Loss: 1.4103 - tr_loss: 0.1198 - tcl_loss: 0.2315 - sin_loss: 0.0123 - cos_loss: 0.1631 - radii_loss: 0.8835
# (250 / 314) - Loss: 1.1251 - tr_loss: 0.1495 - tcl_loss: 0.2683 - sin_loss: 0.0250 - cos_loss: 0.1273 - radii_loss: 0.5550
# (300 / 314) - Loss: 1.1491 - tr_loss: 0.1151 - tcl_loss: 0.2706 - sin_loss: 0.0174 - cos_loss: 0.1759 - radii_loss: 0.5702
# Training Loss: 1.0187767558986214
# Validation: - Loss: 0.7390 - tr_loss: 0.0955 - tcl_loss: 0.1840 - sin_loss: 0.0068 - cos_loss: 0.0815 - radii_loss: 0.3712
# Validation: - Loss: 1.5718 - tr_loss: 0.1572 - tcl_loss: 0.2764 - sin_loss: 0.0165 - cos_loss: 0.3001 - radii_loss: 0.8217
# Validation Loss: 1.144497723976771
# Epoch: 200 : LR = 0.0001
# (0 / 314) - Loss: 1.0027 - tr_loss: 0.1930 - tcl_loss: 0.3305 - sin_loss: 0.0432 - cos_loss: 0.1699 - radii_loss: 0.2660
# (50 / 314) - Loss: 1.0057 - tr_loss: 0.1020 - tcl_loss: 0.2487 - sin_loss: 0.0090 - cos_loss: 0.1031 - radii_loss: 0.5429
# (100 / 314) - Loss: 1.4462 - tr_loss: 0.2665 - tcl_loss: 0.3121 - sin_loss: 0.0768 - cos_loss: 0.1237 - radii_loss: 0.6670
# (150 / 314) - Loss: 0.8267 - tr_loss: 0.1379 - tcl_loss: 0.2137 - sin_loss: 0.0065 - cos_loss: 0.1262 - radii_loss: 0.3424
# (200 / 314) - Loss: 0.9894 - tr_loss: 0.1303 - tcl_loss: 0.2661 - sin_loss: 0.0146 - cos_loss: 0.2462 - radii_loss: 0.3322
# (250 / 314) - Loss: 1.3110 - tr_loss: 0.1140 - tcl_loss: 0.2383 - sin_loss: 0.0099 - cos_loss: 0.1126 - radii_loss: 0.8362
# (300 / 314) - Loss: 1.3084 - tr_loss: 0.2961 - tcl_loss: 0.3557 - sin_loss: 0.0419 - cos_loss: 0.1854 - radii_loss: 0.4293
# Saving to ./save/resnet_STN_LATE/textsnake_resnet_200.pth.
# Training Loss: 1.0246897024713504
# Validation: - Loss: 0.7460 - tr_loss: 0.0971 - tcl_loss: 0.1838 - sin_loss: 0.0070 - cos_loss: 0.0816 - radii_loss: 0.3765
# Validation: - Loss: 1.5740 - tr_loss: 0.1599 - tcl_loss: 0.2774 - sin_loss: 0.0165 - cos_loss: 0.2940 - radii_loss: 0.8262
# Validation Loss: 1.13791752298673
# End.

# %%
# plot_losses(train_losses, val_losses)

# %%
import os
import time
import cv2
import numpy as np
import torch
import subprocess
import torch.backends.cudnn as cudnn
import torch.utils.data as data

import multiprocessing

from util.detection import TextDetector
from util.augmentation import BaseTransform
from util.option import BaseOptions
from util.visualize import visualize_detection
from util.misc import rescale_result

# %%
def write_to_file(contours, file_path):
    # according to total-text evaluation method, output file shoud be formatted to: y0,x0, ..... yn,xn
    with open(file_path, 'w') as f:
        for cont in contours:
            cont = np.stack([cont[:, 1], cont[:, 0]], 1)
            cont = cont.flatten().astype(str).tolist()
            cont = ','.join(cont)
            f.write(cont + '\n')

# %%
def inference(detector, test_loader, output_dir):
    total_time = 0.

    for i, (image, train_mask, tr_mask, tcl_mask, radius_map, sin_map, cos_map, meta) in enumerate(test_loader):

        image, train_mask, tr_mask, tcl_mask, radius_map, sin_map, cos_map = to_device(
            image, train_mask, tr_mask, tcl_mask, radius_map, sin_map, cos_map)

        torch.cuda.synchronize()
        start = time.time()

        idx = 0 # test mode can only run with batch_size == 1

        # get detection result
        contours, output = detector.detect(image)

        torch.cuda.synchronize()
        end = time.time()
        total_time += end - start
        fps = (i + 1) / total_time
        print('detect {} / {} images: {}. ({:.2f} fps)'.format(i + 1, len(test_loader), meta['image_id'][idx], fps))

        # visualization
        tr_pred, tcl_pred = output['tr'], output['tcl']
        img_show = image[idx].permute(1, 2, 0).cpu().numpy()
        img_show = ((img_show * cfg.stds + cfg.means) * 255).astype(np.uint8)

        pred_vis = visualize_detection(img_show, contours, tr_pred[1], tcl_pred[1])
        gt_contour = []
        for annot, n_annot in zip(meta['annotation'][idx], meta['n_annotation'][idx]):
            if n_annot.item() > 0:
                gt_contour.append(annot[:n_annot].int().cpu().numpy())
        gt_vis = visualize_detection(img_show, gt_contour, tr_mask[idx].cpu().numpy(), tcl_mask[idx].cpu().numpy())
        im_vis = np.concatenate([pred_vis, gt_vis], axis=0)
        path = os.path.join(cfg.vis_dir, '{}_test'.format(cfg.exp_name), meta['image_id'][idx])
        cv2.imwrite(path, im_vis)

        H, W = meta['Height'][idx].item(), meta['Width'][idx].item()
        img_show, contours = rescale_result(img_show, contours, H, W)

        # write to file
        mkdirs(output_dir)
        write_to_file(contours, os.path.join(output_dir, meta['image_id'][idx].replace('jpg', 'txt')))

# %%
def main():     
    if multiprocessing.get_start_method(allow_none=True) is None:
        multiprocessing.set_start_method('spawn')
    
    testset = TotalText(
        data_root='data/total-text',
        ignore_list=None,
        is_training=False,
        transform=BaseTransform(size=cfg.input_size, mean=cfg.means, std=cfg.stds)
    )
    test_loader = data.DataLoader(testset, batch_size=1, shuffle=False, num_workers=cfg.num_workers)

    # Model
    model = TextNet(is_training=False, backbone=cfg.net)
    model_path = os.path.join(cfg.save_dir, cfg.exp_name, \
              'textsnake_{}_{}.pth'.format(model.backbone_name, cfg.checkepoch))
    load_model(model,model_path)

    # copy to cuda
    model = model.to(cfg.device)
    if cfg.cuda:
        cudnn.benchmark = True
    detector = TextDetector(model, tr_thresh=cfg.tr_thresh, tcl_thresh=cfg.tcl_thresh)

    print('Start testing TextSnake.')
    output_dir = os.path.join(cfg.output_dir, cfg.exp_name)
    inference(detector, test_loader, output_dir)

    # compute DetEval
    print('Computing DetEval in {}/{}'.format(cfg.output_dir, cfg.exp_name))
    subprocess.call(['python', 'dataset/total_text/Evaluation_Protocol/Python_scripts/Deteval.py', args.exp_name, '--tr', '0.6', '--tp', '0.4'])
    subprocess.call(['python', 'dataset/total_text/Evaluation_Protocol/Python_scripts/Deteval.py', args.exp_name, '--tr', '0.8', '--tp', '0.4'])
    print('End.')

# %%
# parse arguments
option = BaseOptions()

command_line_args = ["resnet_STN_LATE", "--net", "resnet", "--checkepoch", "150"]  
args = option.initialize(command_line_args)

update_config(cfg, args)
print_config(cfg)

vis_dir = os.path.join(cfg.vis_dir, '{}_test'.format(cfg.exp_name))
if not os.path.exists(vis_dir):
    mkdirs(vis_dir)
# main
main()
# Out:
# total-text
# ==========Options============
# num_workers: 8
# batch_size: 4
# max_epoch: 201
# start_epoch: 0
# lr: 0.0001
# cuda: True
# n_disk: 15
# output_dir: output
# input_size: 512
# max_annotation: 200
# max_points: 20
# use_hard: True
# tr_thresh: 0.6
# tcl_thresh: 0.4
# post_process_expand: 0.3
# post_process_merge: False
# dataset: total-text
# device: cuda
# vis_dir: ./vis/
# save_dir: ./save/
# data_custom: False
# data_root: data/total-text
# exp_name: resnet_STN_LATE
# net: resnet
# resume: None
# mgpu: False
# log_dir: ./logs/
# loss: CrossEntropyLoss
# input_channel: 1
# pretrain: False
# verbose: True
# viz: False
# start_iter: 0
# lr_adjust: fix
# stepvalues: []
# weight_decay: 0.0
# gamma: 0.1
# momentum: 0.9
# optim: SGD
# display_freq: 50
# viz_freq: 50
# save_freq: 50
# log_freq: 100
# val_freq: 100
# rescale: 255.0
# means: [0.485, 0.456, 0.406]
# stds: [0.229, 0.224, 0.225]
# checkepoch: 150
# img_root: None
# =============End=============
# Loading from ./save/resnet_STN_LATE/textsnake_resnet_150.pth
# Start testing TextSnake.
# detect 1 / 300 images: img541.jpg. (3.54 fps)
# detect 2 / 300 images: img619.jpg. (4.55 fps)
# detect 3 / 300 images: img1547.jpg. (5.68 fps)
# detect 4 / 300 images: img584.jpg. (6.35 fps)
# detect 5 / 300 images: img93.jpg. (6.84 fps)
# detect 6 / 300 images: img994.jpg. (7.49 fps)
# detect 7 / 300 images: img1191.jpg. (7.71 fps)
# detect 8 / 300 images: img1544.jpg. (7.96 fps)
# detect 9 / 300 images: img646.jpg. (8.36 fps)
# detect 10 / 300 images: img893.jpg. (8.18 fps)
# detect 11 / 300 images: img634.jpg. (8.63 fps)
# detect 12 / 300 images: img669.jpg. (8.83 fps)
# detect 13 / 300 images: img1095.jpg. (9.01 fps)
# detect 14 / 300 images: img617.jpg. (9.03 fps)
# detect 15 / 300 images: img5.jpg. (9.28 fps)
# detect 16 / 300 images: img585.jpg. (9.43 fps)
# detect 17 / 300 images: img643.jpg. (9.24 fps)
# detect 18 / 300 images: img676.jpg. (9.30 fps)
# detect 19 / 300 images: img568.jpg. (9.42 fps)
# detect 20 / 300 images: img587.jpg. (9.44 fps)
# detect 21 / 300 images: img649.jpg. (9.46 fps)
# detect 22 / 300 images: img1198.jpg. (9.68 fps)
# detect 23 / 300 images: img294.jpg. (9.89 fps)
# detect 24 / 300 images: img548.jpg. (10.01 fps)
# detect 25 / 300 images: img598.jpg. (10.13 fps)
# detect 26 / 300 images: img1394.jpg. (10.23 fps)
# detect 27 / 300 images: img602.jpg. (10.30 fps)
# detect 28 / 300 images: img1094.jpg. (10.46 fps)
# detect 29 / 300 images: img667.jpg. (10.61 fps)
# detect 30 / 300 images: img193.jpg. (10.66 fps)
# detect 31 / 300 images: img544.jpg. (10.71 fps)
# detect 32 / 300 images: img566.jpg. (10.75 fps)
# detect 33 / 300 images: img1348.jpg. (10.77 fps)
# detect 34 / 300 images: img200.jpg. (10.79 fps)
# detect 35 / 300 images: img1540.jpg. (10.84 fps)
# detect 36 / 300 images: img393.jpg. (10.70 fps)
# detect 37 / 300 images: img554.jpg. (10.75 fps)
# detect 38 / 300 images: img610.jpg. (10.80 fps)
# detect 39 / 300 images: img572.jpg. (10.79 fps)
# detect 40 / 300 images: img674.jpg. (10.77 fps)
# detect 41 / 300 images: img998.jpg. (10.74 fps)
# detect 42 / 300 images: img7.jpg. (10.80 fps)
# detect 43 / 300 images: img1553.jpg. (10.79 fps)
# detect 44 / 300 images: img575.jpg. (10.85 fps)
# detect 45 / 300 images: img612.jpg. (10.89 fps)
# detect 46 / 300 images: img657.jpg. (11.00 fps)
# detect 47 / 300 images: img992.jpg. (11.09 fps)
# detect 48 / 300 images: img1395.jpg. (11.10 fps)
# detect 49 / 300 images: img583.jpg. (11.13 fps)
# detect 50 / 300 images: img629.jpg. (11.16 fps)
# detect 51 / 300 images: img797.jpg. (11.27 fps)
# detect 52 / 300 images: img1393.jpg. (11.34 fps)
# detect 53 / 300 images: img635.jpg. (11.23 fps)
# detect 54 / 300 images: img593.jpg. (11.26 fps)
# detect 55 / 300 images: img603.jpg. (11.30 fps)
# detect 56 / 300 images: img1296.jpg. (11.32 fps)
# detect 57 / 300 images: img642.jpg. (11.27 fps)
# detect 58 / 300 images: img1396.jpg. (11.29 fps)
# detect 59 / 300 images: img398.jpg. (11.27 fps)
# detect 60 / 300 images: img627.jpg. (11.33 fps)
# detect 61 / 300 images: img618.jpg. (11.33 fps)
# detect 62 / 300 images: img100.jpg. (11.40 fps)
# detect 63 / 300 images: img565.jpg. (11.47 fps)
# detect 64 / 300 images: img92.jpg. (11.47 fps)
# detect 65 / 300 images: img1291.jpg. (11.50 fps)
# detect 66 / 300 images: img624.jpg. (11.51 fps)
# detect 67 / 300 images: img582.jpg. (11.52 fps)
# detect 68 / 300 images: img655.jpg. (11.56 fps)
# detect 69 / 300 images: img533.jpg. (11.52 fps)
# detect 70 / 300 images: img570.jpg. (11.52 fps)
# detect 71 / 300 images: img588.jpg. (11.56 fps)
# detect 72 / 300 images: img399.jpg. (11.62 fps)
# detect 73 / 300 images: img559.jpg. (11.50 fps)
# detect 74 / 300 images: img898.jpg. (11.46 fps)
# detect 75 / 300 images: img800.jpg. (11.44 fps)
# detect 76 / 300 images: img538.jpg. (11.47 fps)
# detect 77 / 300 images: img1295.jpg. (11.47 fps)
# detect 78 / 300 images: img1292.jpg. (11.45 fps)
# detect 79 / 300 images: img658.jpg. (11.46 fps)
# detect 80 / 300 images: img91.jpg. (11.50 fps)
# detect 81 / 300 images: img633.jpg. (11.55 fps)
# detect 82 / 300 images: img993.jpg. (11.55 fps)
# detect 83 / 300 images: img1398.jpg. (11.54 fps)
# detect 84 / 300 images: img616.jpg. (11.51 fps)
# detect 85 / 300 images: img391.jpg. (11.57 fps)
# detect 86 / 300 images: img794.jpg. (11.60 fps)
# detect 87 / 300 images: img615.jpg. (11.61 fps)
# detect 88 / 300 images: img607.jpg. (11.65 fps)
# detect 89 / 300 images: img295.jpg. (11.62 fps)
# detect 90 / 300 images: img539.jpg. (11.64 fps)
# detect 91 / 300 images: img637.jpg. (11.67 fps)
# detect 92 / 300 images: img540.jpg. (11.54 fps)
# detect 93 / 300 images: img1299.jpg. (11.53 fps)
# detect 94 / 300 images: img647.jpg. (11.55 fps)
# detect 95 / 300 images: img793.jpg. (11.42 fps)
# detect 96 / 300 images: img1541.jpg. (11.42 fps)
# detect 97 / 300 images: img600.jpg. (11.40 fps)
# detect 98 / 300 images: img534.jpg. (11.40 fps)
# detect 99 / 300 images: img1098.jpg. (11.37 fps)
# detect 100 / 300 images: img1197.jpg. (11.40 fps)
# detect 101 / 300 images: img590.jpg. (11.42 fps)
# detect 102 / 300 images: img891.jpg. (11.35 fps)
# detect 103 / 300 images: img652.jpg. (11.37 fps)
# detect 104 / 300 images: img894.jpg. (11.38 fps)
# detect 105 / 300 images: img595.jpg. (11.39 fps)
# detect 106 / 300 images: img1400.jpg. (11.40 fps)
# detect 107 / 300 images: img604.jpg. (11.42 fps)
# detect 108 / 300 images: img545.jpg. (11.43 fps)
# detect 109 / 300 images: img625.jpg. (11.45 fps)
# detect 110 / 300 images: img677.jpg. (11.46 fps)
# detect 111 / 300 images: img569.jpg. (11.44 fps)
# detect 112 / 300 images: img1300.jpg. (11.46 fps)
# detect 113 / 300 images: img599.jpg. (11.41 fps)
# detect 114 / 300 images: img3.jpg. (11.45 fps)
# detect 115 / 300 images: img195.jpg. (11.44 fps)
# detect 116 / 300 images: img1192.jpg. (11.43 fps)
# detect 117 / 300 images: img671.jpg. (11.40 fps)
# detect 118 / 300 images: img497.jpg. (11.40 fps)
# detect 119 / 300 images: img795.jpg. (11.34 fps)
# detect 120 / 300 images: img622.jpg. (11.29 fps)
# detect 121 / 300 images: img1392.jpg. (11.31 fps)
# detect 122 / 300 images: img552.jpg. (11.32 fps)
# detect 123 / 300 images: img192.jpg. (11.33 fps)
# detect 124 / 300 images: img558.jpg. (11.27 fps)
# detect 125 / 300 images: img1550.jpg. (11.29 fps)
# detect 126 / 300 images: img395.jpg. (11.26 fps)
# detect 127 / 300 images: img576.jpg. (11.26 fps)
# detect 128 / 300 images: img560.jpg. (11.25 fps)
# detect 129 / 300 images: img1297.jpg. (11.25 fps)
# detect 130 / 300 images: img198.jpg. (11.25 fps)
# detect 131 / 300 images: img892.jpg. (11.23 fps)
# detect 132 / 300 images: img641.jpg. (11.25 fps)
# detect 133 / 300 images: img549.jpg. (11.22 fps)
# detect 134 / 300 images: img1546.jpg. (11.23 fps)
# detect 135 / 300 images: img659.jpg. (11.19 fps)
# detect 136 / 300 images: img95.jpg. (11.19 fps)
# detect 137 / 300 images: img596.jpg. (11.21 fps)
# detect 138 / 300 images: img494.jpg. (11.19 fps)
# detect 139 / 300 images: img96.jpg. (11.19 fps)
# detect 140 / 300 images: img1097.jpg. (11.21 fps)
# detect 141 / 300 images: img1092.jpg. (11.19 fps)
# detect 142 / 300 images: img555.jpg. (11.19 fps)
# detect 143 / 300 images: img614.jpg. (11.19 fps)
# detect 144 / 300 images: img609.jpg. (11.20 fps)
# detect 145 / 300 images: img651.jpg. (11.19 fps)
# detect 146 / 300 images: img798.jpg. (11.19 fps)
# detect 147 / 300 images: img866.jpg. (11.19 fps)
# detect 148 / 300 images: img630.jpg. (11.19 fps)
# detect 149 / 300 images: img291.jpg. (11.20 fps)
# detect 150 / 300 images: img298.jpg. (11.21 fps)
# detect 151 / 300 images: img1093.jpg. (11.20 fps)
# detect 152 / 300 images: img897.jpg. (11.20 fps)
# detect 153 / 300 images: img551.jpg. (11.20 fps)
# detect 154 / 300 images: img999.jpg. (11.20 fps)
# detect 155 / 300 images: img574.jpg. (11.14 fps)
# detect 156 / 300 images: img1055.jpg. (11.15 fps)
# detect 157 / 300 images: img498.jpg. (11.18 fps)
# detect 158 / 300 images: img1555.jpg. (11.19 fps)
# detect 159 / 300 images: img899.jpg. (11.20 fps)
# detect 160 / 300 images: img660.jpg. (11.23 fps)
# detect 161 / 300 images: img397.jpg. (11.24 fps)
# detect 162 / 300 images: img293.jpg. (11.25 fps)
# detect 163 / 300 images: img670.jpg. (11.24 fps)
# detect 164 / 300 images: img577.jpg. (11.25 fps)
# detect 165 / 300 images: img903.jpg. (11.23 fps)
# detect 166 / 300 images: img94.jpg. (11.24 fps)
# detect 167 / 300 images: img644.jpg. (11.26 fps)
# detect 168 / 300 images: img611.jpg. (11.26 fps)
# detect 169 / 300 images: img556.jpg. (11.28 fps)
# detect 170 / 300 images: img400.jpg. (11.28 fps)
# detect 171 / 300 images: img594.jpg. (11.27 fps)
# detect 172 / 300 images: img900.jpg. (11.28 fps)
# detect 173 / 300 images: img1.jpg. (11.29 fps)
# detect 174 / 300 images: img542.jpg. (11.32 fps)
# detect 175 / 300 images: img623.jpg. (11.34 fps)
# detect 176 / 300 images: img1554.jpg. (11.35 fps)
# detect 177 / 300 images: img638.jpg. (11.35 fps)
# detect 178 / 300 images: img561.jpg. (11.35 fps)
# detect 179 / 300 images: img194.jpg. (11.31 fps)
# detect 180 / 300 images: img620.jpg. (11.33 fps)
# detect 181 / 300 images: img586.jpg. (11.34 fps)
# detect 182 / 300 images: img537.jpg. (11.34 fps)
# detect 183 / 300 images: img1294.jpg. (11.34 fps)
# detect 184 / 300 images: img1298.jpg. (11.34 fps)
# detect 185 / 300 images: img199.jpg. (11.33 fps)
# detect 186 / 300 images: img1552.jpg. (11.29 fps)
# detect 187 / 300 images: img601.jpg. (11.31 fps)
# detect 188 / 300 images: img613.jpg. (11.31 fps)
# detect 189 / 300 images: img1091.jpg. (11.32 fps)
# detect 190 / 300 images: img605.jpg. (11.34 fps)
# detect 191 / 300 images: img535.jpg. (11.34 fps)
# detect 192 / 300 images: img500.jpg. (11.34 fps)
# detect 193 / 300 images: img1391.jpg. (11.35 fps)
# detect 194 / 300 images: img591.jpg. (11.35 fps)
# detect 195 / 300 images: img567.jpg. (11.35 fps)
# detect 196 / 300 images: img196.jpg. (11.38 fps)
# detect 197 / 300 images: img99.jpg. (11.40 fps)
# detect 198 / 300 images: img661.jpg. (11.37 fps)
# detect 199 / 300 images: img581.jpg. (11.36 fps)
# detect 200 / 300 images: img579.jpg. (11.35 fps)
# detect 201 / 300 images: img10.jpg. (11.37 fps)
# detect 202 / 300 images: img296.jpg. (11.38 fps)
# detect 203 / 300 images: img639.jpg. (11.37 fps)
# detect 204 / 300 images: img1193.jpg. (11.12 fps)
# detect 205 / 300 images: img496.jpg. (11.12 fps)
# detect 206 / 300 images: img672.jpg. (11.10 fps)
# detect 207 / 300 images: img632.jpg. (11.10 fps)
# detect 208 / 300 images: img995.jpg. (11.12 fps)
# detect 209 / 300 images: img2.jpg. (11.12 fps)
# detect 210 / 300 images: img550.jpg. (11.14 fps)
# detect 211 / 300 images: img668.jpg. (11.15 fps)
# detect 212 / 300 images: img299.jpg. (11.16 fps)
# detect 213 / 300 images: img896.jpg. (11.17 fps)
# detect 214 / 300 images: img394.jpg. (11.17 fps)
# detect 215 / 300 images: img1539.jpg. (11.20 fps)
# detect 216 / 300 images: img300.jpg. (11.21 fps)
# detect 217 / 300 images: img191.jpg. (11.22 fps)
# detect 218 / 300 images: img1397.jpg. (11.21 fps)
# detect 219 / 300 images: img664.jpg. (11.21 fps)
# detect 220 / 300 images: img640.jpg. (11.23 fps)
# detect 221 / 300 images: img675.jpg. (11.24 fps)
# detect 222 / 300 images: img97.jpg. (11.24 fps)
# detect 223 / 300 images: img650.jpg. (11.24 fps)
# detect 224 / 300 images: img791.jpg. (11.20 fps)
# detect 225 / 300 images: img492.jpg. (11.22 fps)
# detect 226 / 300 images: img679.jpg. (11.22 fps)
# detect 227 / 300 images: img563.jpg. (11.23 fps)
# detect 228 / 300 images: img493.jpg. (11.25 fps)
# detect 229 / 300 images: img626.jpg. (11.22 fps)
# detect 230 / 300 images: img1100.jpg. (11.21 fps)
# detect 231 / 300 images: img580.jpg. (11.22 fps)
# detect 232 / 300 images: img1543.jpg. (11.23 fps)
# detect 233 / 300 images: img543.jpg. (11.23 fps)
# detect 234 / 300 images: img654.jpg. (11.23 fps)
# detect 235 / 300 images: img1549.jpg. (11.20 fps)
# detect 236 / 300 images: img1000.jpg. (11.20 fps)
# detect 237 / 300 images: img573.jpg. (11.20 fps)
# detect 238 / 300 images: img663.jpg. (11.20 fps)
# detect 239 / 300 images: img396.jpg. (11.22 fps)
# detect 240 / 300 images: img1542.jpg. (11.22 fps)
# detect 241 / 300 images: img392.jpg. (11.23 fps)
# detect 242 / 300 images: img796.jpg. (11.24 fps)
# detect 243 / 300 images: img621.jpg. (11.24 fps)
# detect 244 / 300 images: img631.jpg. (11.24 fps)
# detect 245 / 300 images: img997.jpg. (11.25 fps)
# detect 246 / 300 images: img628.jpg. (11.27 fps)
# detect 247 / 300 images: img297.jpg. (11.28 fps)
# detect 248 / 300 images: img895.jpg. (11.29 fps)
# detect 249 / 300 images: img645.jpg. (11.31 fps)
# detect 250 / 300 images: img546.jpg. (11.31 fps)
# detect 251 / 300 images: img197.jpg. (11.31 fps)
# detect 252 / 300 images: img996.jpg. (11.31 fps)
# detect 253 / 300 images: img557.jpg. (11.31 fps)
# detect 254 / 300 images: img1548.jpg. (11.30 fps)
# detect 255 / 300 images: img1399.jpg. (11.29 fps)
# detect 256 / 300 images: img592.jpg. (11.29 fps)
# detect 257 / 300 images: img991.jpg. (11.29 fps)
# detect 258 / 300 images: img792.jpg. (11.29 fps)
# detect 259 / 300 images: img578.jpg. (11.29 fps)
# detect 260 / 300 images: img1194.jpg. (11.31 fps)
# detect 261 / 300 images: img1200.jpg. (11.32 fps)
# detect 262 / 300 images: img589.jpg. (11.33 fps)
# detect 263 / 300 images: img8.jpg. (11.34 fps)
# detect 264 / 300 images: img1099.jpg. (11.35 fps)
# detect 265 / 300 images: img606.jpg. (11.34 fps)
# detect 266 / 300 images: img1196.jpg. (11.35 fps)
# detect 267 / 300 images: img662.jpg. (11.36 fps)
# detect 268 / 300 images: img1195.jpg. (11.36 fps)
# detect 269 / 300 images: img4.jpg. (11.36 fps)
# detect 270 / 300 images: img9.jpg. (11.36 fps)
# detect 271 / 300 images: img608.jpg. (11.36 fps)
# detect 272 / 300 images: img491.jpg. (11.38 fps)
# detect 273 / 300 images: img1551.jpg. (11.39 fps)
# detect 274 / 300 images: img292.jpg. (11.41 fps)
# detect 275 / 300 images: img597.jpg. (11.41 fps)
# detect 276 / 300 images: img536.jpg. (11.43 fps)
# detect 277 / 300 images: img666.jpg. (11.42 fps)
# detect 278 / 300 images: img665.jpg. (11.43 fps)
# detect 279 / 300 images: img1199.jpg. (11.45 fps)
# detect 280 / 300 images: img1096.jpg. (11.42 fps)
# detect 281 / 300 images: img553.jpg. (11.43 fps)
# detect 282 / 300 images: img648.jpg. (11.43 fps)
# detect 283 / 300 images: img562.jpg. (11.45 fps)
# detect 284 / 300 images: img547.jpg. (11.43 fps)
# detect 285 / 300 images: img636.jpg. (11.28 fps)
# detect 286 / 300 images: img564.jpg. (11.26 fps)
# detect 287 / 300 images: img656.jpg. (11.26 fps)
# detect 288 / 300 images: img6.jpg. (11.25 fps)
# detect 289 / 300 images: img673.jpg. (11.24 fps)
# detect 290 / 300 images: img532.jpg. (11.24 fps)
# detect 291 / 300 images: img571.jpg. (11.24 fps)
# detect 292 / 300 images: img495.jpg. (11.24 fps)
# detect 293 / 300 images: img499.jpg. (11.24 fps)
# detect 294 / 300 images: img98.jpg. (11.26 fps)
# detect 295 / 300 images: img531.jpg. (11.26 fps)
# detect 296 / 300 images: img678.jpg. (11.27 fps)
# detect 297 / 300 images: img653.jpg. (11.28 fps)
# detect 298 / 300 images: img1293.jpg. (11.28 fps)
# detect 299 / 300 images: img799.jpg. (11.28 fps)
# detect 300 / 300 images: img1545.jpg. (11.29 fps)
# Computing DetEval in output/resnet_STN_LATE
#   0%|          | 0/300 [00:00<?, ?it/s]/usr/local/lib/python3.9/dist-packages/shapely/set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
#  12%|█▏        | 35/300 [00:05<00:22, 11.66it/s]/notebooks/dataset/total_text/Evaluation_Protocol/Python_scripts/Deteval.py:78: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if (gt[5] == '#') and (gt[1].shape[1] > 1):
# /notebooks/dataset/total_text/Evaluation_Protocol/Python_scripts/Deteval.py:134: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   dc_id = np.where(groundtruths[:, 5] == '#')
# 100%|██████████| 300/300 [00:53<00:00,  5.56it/s]
# Input: output/resnet_STN_LATE
# Config: tr: 0.6 - tp: 0.4
# Precision = 0.8440 - Recall = 0.7181 - Fscore = 0.7760
#
# Done.
#   0%|          | 0/300 [00:00<?, ?it/s]/usr/local/lib/python3.9/dist-packages/shapely/set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
#  12%|█▏        | 35/300 [00:05<00:23, 11.33it/s]/notebooks/dataset/total_text/Evaluation_Protocol/Python_scripts/Deteval.py:78: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if (gt[5] == '#') and (gt[1].shape[1] > 1):
# /notebooks/dataset/total_text/Evaluation_Protocol/Python_scripts/Deteval.py:134: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   dc_id = np.where(groundtruths[:, 5] == '#')
#  99%|█████████▊| 296/300 [00:47<00:00, 10.35it/s]
# Input: output/resnet_STN_LATE
# Config: tr: 0.8 - tp: 0.4
# Precision = 0.7906 - Recall = 0.6819 - Fscore = 0.7322
#
# Done.
# End.
# 100%|██████████| 300/300 [00:47<00:00,  6.30it/s]
